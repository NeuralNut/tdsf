# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Aug 29 15:39:51 2023

This script trains PINN model for TDSF supplied by AFTAC-CRADA
Inputs: yield (w), depth (h), time (t)
Output: displacement (S)

@author: shhong
"""

#%% Load Moduels

import os
root = os.path.abspath('')
# root = '/home/ubuntu/tdsf'

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import scipy.io as sio
import matplotlib.pyplot as plt

from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from timeit import default_timer as timer
from sklearn.preprocessing import MinMaxScaler

# from sklearn.metrics import confusion_matrix
# from sklearn.preprocessing import OneHotEncoder

# device = torch.device('cuda:0')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

study = 'noise_study_ood_phy_domain'

#%% Load Data

# path = 'E:\Hong\Research Projects\PINN\Data'
path = f'{root}/data'

filename = 'tdsf_002_train.pickle'
df_train_all = pd.read_pickle(path + '/' + filename)

filename = 'tdsf_002_val.pickle'
df_test_all = pd.read_pickle(path + '/' + filename)

df_data_all = pd.concat([df_train_all, df_test_all], axis=0)


#%% Select Material

# [Tuff-Rhyolite, Granite, Shale, Salt, Wet-Granite, Wet-Tuff]

name_prefix = '_FAR.'
name_material = 'Tuff-Rhyolite'

df_data = df_data_all[df_data_all['material'] == name_prefix + name_material]
df_data = df_data.reset_index(drop=True)

# splits df into train and test by yield and depth quantiles
qnts = [.1, .9]
ylds, dpths = df_data.YIELD.quantile(qnts, interpolation='nearest'), df_data.DEPTH.quantile(qnts, interpolation='nearest')
train_qnt = (df_data.YIELD >= ylds.min()) & (df_data.YIELD <= ylds.max()) & (df_data.DEPTH >= dpths.min()) & (df_data.DEPTH <= dpths.max())
df_train = df_data.reset_index(drop=True)
df_data_phy_domain = df_data[train_qnt].reset_index(drop=True)
df_test = df_data[~train_qnt].reset_index(drop=True)

# plot train and test yields and depths
plt.figure()
plt.scatter(df_train.YIELD, df_train.DEPTH, label='phy loss', color='red', alpha=0.2)
plt.scatter(df_data_phy_domain.YIELD, df_data_phy_domain.DEPTH, label='data+phy loss', color='blue', alpha=0.2)
plt.xlabel('Yield')
plt.ylabel('Depth')
plt.legend()
plt.title('Loss domains')
plt.savefig(f'{root}/results/{study}/loss_domains.png')
# plt.close('all')
plt.show()

#%% Data Arrangement

trunc = 1000
ds = 10
dt = 0.001

tv = np.arange(1,trunc+1)*dt
tv = tv[::ds]

# Define Train Set
tdsf = df_train.DATA
wvec = df_train.YIELD
hvec = df_train.DEPTH
t_tdsf = tdsf[0][:trunc]
Xtrain = np.concatenate((wvec[0]*np.ones((tv.size,1)), hvec[0]*np.ones((tv.size,1)), np.reshape(tv,(-1,1))), axis=1)
Ytrain = np.reshape(t_tdsf[::ds], (-1,1))
for ndx in range(1, df_train.shape[0]):
    t_tdsf = tdsf[ndx][:trunc]
    Xtemp = np.concatenate((wvec[ndx]*np.ones((tv.size,1)), hvec[ndx]*np.ones((tv.size,1)), np.reshape(tv,(-1,1))), axis=1)        
    Xtrain = np.concatenate((Xtrain, Xtemp), axis=0)
    Ytrain = np.concatenate((Ytrain, np.reshape(t_tdsf[::ds], (-1,1))), axis=0)
Xtrain = Xtrain.astype(np.float32)
Ytrain = Ytrain.astype(np.float32)

# Define Test Set
tdsf = df_test.DATA
wvec = df_test.YIELD
hvec = df_test.DEPTH
t_tdsf = tdsf[0][:trunc]
Xtest = np.concatenate((wvec[0]*np.ones((tv.size,1)), hvec[0]*np.ones((tv.size,1)), np.reshape(tv,(-1,1))), axis=1)
Ytest = np.reshape(t_tdsf[::ds], (-1,1))
for ndx in range(1, df_test.shape[0]):
    t_tdsf = tdsf[ndx][:trunc]
    Xtemp = np.concatenate((wvec[ndx]*np.ones((tv.size,1)), hvec[ndx]*np.ones((tv.size,1)), np.reshape(tv,(-1,1))), axis=1)        
    Xtest = np.concatenate((Xtest, Xtemp), axis=0)
    Ytest = np.concatenate((Ytest, np.reshape(t_tdsf[::ds], (-1,1))), axis=0)
Xtest = Xtest.astype(np.float32)
Ytest = Ytest.astype(np.float32)


#%% Preprocessing

# Min-Max Normalization
Xscaler = MinMaxScaler()
Xscaler.fit(Xtrain)
MaxX = Xscaler.data_max_
MinX = Xscaler.data_min_

Yscaler = MinMaxScaler()
Yscaler.fit(Ytrain)
MaxY = Yscaler.data_max_
MinY = Yscaler.data_min_

Ztrain = Yscaler.transform(Ytrain)
Ztest = Yscaler.transform(Ytest)

# Shuffle Data
numdata = Xtrain.shape[0]
np.random.seed(0)
randperm = np.random.permutation(numdata)
Utrain = Xtrain[randperm,:]
Ztrain_base = Ztrain[randperm,:]
# Out:
# /tmp/ipykernel_365915/2927923308.py:20: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
Xtrain.shape
# Out:
# (958600, 3)

# %%
noise = [0.00, 0.01, 0.1, 0.2, 0.5]
for sigma in noise:

    path = f'{root}/results/{study}/{sigma}'
    if not os.path.exists(path): os.makedirs(path)
    else:
        print(f'{root}/results/{study}/{sigma} exists, skipping')
        continue

    # Gaussian Noise
    # sigma = 0.00
    mu = 0.00
    np.random.seed(1)
    Ztrain = (Ztrain_base + sigma*np.random.randn(numdata,1) + mu).astype(np.float32)

    numIn = Utrain.shape[1]
    numOut = Ztrain.shape[1]


    #%% Define Classes

    class ANN_Dataset(Dataset):    

        # Initialize your data
        def __init__(self, x, y):        
            self.len = x.shape[0]
            self.x_data = torch.from_numpy(x)
            self.y_data = torch.from_numpy(y)

        def __getitem__(self, index):
            return self.x_data[index], self.y_data[index]

        def __len__(self):
            return self.len


    # Fully Connected NN
    class FCNN_Net(nn.Module):

        def __init__(self, numIn, numOut):
            super(FCNN_Net, self).__init__()
            self.fc1 = nn.Linear(numIn, 24)
            self.fc2 = nn.Linear(24, 6)
            self.fc3 = nn.Linear(6, numOut)
            
        def forward(self, w, h, t):        
            inputs = torch.cat([w,h,t],axis=1) # combined two arrays of 1 columns each to one array of 2 columns        
            # in_size = x.size(0)
            # inputs = x.view(in_size, -1)
            layer1_out = torch.tanh(self.fc1(inputs))
            layer2_out = torch.tanh(self.fc2(layer1_out))
            output = (self.fc3(layer2_out))
            return output


    #%% Defined Functions


    ## PDE as loss function. Thus would use the network which we call as u_theta
    def f_partial(data, net, MaxX, MinX, MaxY, MinY):
        
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
        xmax = torch.from_numpy(MaxX).to(device)
        xmin = torch.from_numpy(MinX).to(device)
        ymax = torch.from_numpy(MaxY).to(device)
        ymin = torch.from_numpy(MinY).to(device)
        
        wvec = Variable(torch.reshape(data[:,0], (-1,1)), requires_grad=True).to(device)
        hvec = Variable(torch.reshape(data[:,1], (-1,1)), requires_grad=True).to(device)
        tvec = Variable(torch.reshape(data[:,2], (-1,1)), requires_grad=True).to(device)
            
        # applying normalized input
        # x = torch.cat([(wvec-xmin[0])/(xmax[0]-xmin[0]),(hvec-xmin[1])/(xmax[1]-xmin[1]),(tvec-xmin[2])/(xmax[2]-xmin[2])],axis=1)    
        s = net((wvec-xmin[0])/(xmax[0]-xmin[0]), (hvec-xmin[1])/(xmax[1]-xmin[1]), (tvec-xmin[2])/(xmax[2]-xmin[2])) # the dependent variable s is given by the network based on independent variables w, h, t

        # remove normalization
        s = s*(ymax-ymin) + ymin
        
        s_w = torch.autograd.grad(s.sum(), wvec, create_graph=True)[0]
        s_h = torch.autograd.grad(s.sum(), hvec, create_graph=True)[0] 
            
        ww = torch.reshape(data[:,0], (-1,1))
        hh = torch.reshape(data[:,1], (-1,1))
        tt = torch.reshape(data[:,2], (-1,1))
        
        # define parameters
        ho = 122
        Ro = 202
        go = 26
        P1 = 3.6*1e6
        P2 = 5.0*1e6
        n = 2.4
        pv = 3500
        sv = 2021
        rho = 2000
        
        dsdR = torch.zeros(ww.shape).to(device)

        Rel = Ro*((ho/hh)**(1/n))*(ww**(1/3))
        ga = go*Ro/Rel

        mu = rho*(sv**2)
        lam = rho*(pv**2)-2*mu    
        wo = pv/Rel
        bet = (lam+2*mu)/(4*mu)
        alp = wo/(2*bet)
        p = wo*(1/2/bet-1/4/bet**2)**(1/2)

        def dF_(tau):
            return (Rel*pv**2)/(4*mu*bet*p)*(-alp*torch.exp(-alp*tau)*torch.sin(p*tau) + p*torch.exp(-alp*tau)*torch.cos(p*tau))

        def dBdR_(tau):
            return (tt-tau)*ga*torch.exp(-ga*(tt-tau))/Rel*P1*(hh/ho) - ((tt-tau)*ga*torch.exp(-ga*(tt-tau))+3*(1-torch.exp(-ga*(tt-tau))))/Rel*P2*((ho/hh)**(1/3))*((Ro/Rel)**3)*(ww**(0.87))

        dtau = 0.001
        tau = torch.tensor(np.arange(0,1,dtau)).to(device).float()
        
        dF = dF_(tau)
        dBdR = dBdR_(tau)
        
        temp = dF*dBdR*dtau
        mask = (tt - tau) < 0
        temp[mask] = 0
        dsdR += temp.sum(axis=-1).unsqueeze(-1)

        dRdw = 1/3*Ro*((ho/hh)**(1/n))*(ww**(-2/3))
        dRdh = -1/n*((ho/hh)**(1/n))*(1/hh)*(ww**(1/3))
        dsdw = dsdR*dRdw
        dsdh = dsdR*dRdh
            
        return s_w, dsdw, s_h, dsdh


    def train(model, loader, optimizer, MaxX, MinX, MaxY, MinY, lam1, lam2):
        
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        model.train()
        total_loss = 0
        
        xmax = torch.from_numpy(MaxX).to(device)
        xmin = torch.from_numpy(MinX).to(device)
        
        for batch_idx, (data, target) in enumerate(loader):

            
            # get a batch of unnormlized data
            data, target = Variable(data, requires_grad=True).to(device), Variable(target, requires_grad=True).to(device)

            # create Y-D quantile mask for data loss
            mask = (data[:,0] >= ylds.min()) & (data[:,0] <= ylds.max()) & (data[:,1] >= dpths.min()) & (data[:,1] <= dpths.max())
            # all_zeros = torch.zeros(target.shape).to(device)
            # print(target.shape)
            
            # normalization
            dataN = (data-xmin)/(xmax-xmin)
                    
            def closure():
                optimizer.zero_grad()
                output = model(torch.reshape(dataN[:,0], (-1,1)), torch.reshape(dataN[:,1], (-1,1)), torch.reshape(dataN[:,2], (-1,1)))
                
                # mask the output and target in the data loss calculation
                mse_d = criterion(output[mask],target[mask])    
                
                # physics loss spans the entire domain
                s_w, dsdw, s_h, dsdh = f_partial(data, model, MaxX, MinX, MaxY, MinY)
                # print(s_w)
                # print(dsdw)
                
                mse_sw = criterion(s_w,dsdw)
                mse_sh = criterion(s_h,dsdh)
                
                # print(mse_d)
                # print(mse_sw)
                # print(mse_sh)
                
                loss = mse_d + lam1*mse_sw + lam2*mse_sh
                # loss = mse_d
                
                loss.backward()
                return loss
            
            loss = optimizer.step(closure=closure)
            total_loss += loss.item()*len(data)
        
        total_loss /= len(loader.dataset)
        
        return total_loss
        

    def test(model, loader, MaxX, MinX, MaxY, MinY):
        
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        model.eval()
        test_loss = 0
        
        xmax = torch.from_numpy(MaxX).to(device)
        xmin = torch.from_numpy(MinX).to(device)
        
        for data, target in loader:

            data = data.requires_grad_(False).to(device)
            target = target.requires_grad_(False).to(device)
            
            # normalization
            dataN = (data-xmin)/(xmax-xmin)
            
            output = model(torch.reshape(dataN[:,0], (-1,1)), torch.reshape(dataN[:,1], (-1,1)), torch.reshape(dataN[:,2], (-1,1)))
            
            loss = criterion(output,target)
            test_loss += loss.item()*len(data)
            # print(len(data))

        test_loss /= len(loader.dataset)

        return test_loss


    #%% Hyperparameter Selection

    max_epoch = 1000
    max_fail = 8
    batch_size = 4096
    val_ratio = 0.2
    train_ratio = 0.8

    lamda1 = 1e-9 # PDE loss weight
    lamda2 = 1

    train_num = int(numdata*train_ratio)
    val_num = numdata - train_num

    train_dataset = ANN_Dataset(Utrain[:train_num,:], Ztrain[:train_num,:])
    val_dataset = ANN_Dataset(Utrain[train_num:,:], Ztrain[train_num:,:])
    test_dataset = ANN_Dataset(Xtest, Ztest)

    # Data Loader (Input Pipeline)
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    
    #%% Training

    # Define Network to Train
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = FCNN_Net(numIn, numOut).to(device)
    # model.double()

    # Select Optimizer and Loss Criterion
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.999), eps=1e-8,
                            weight_decay=0, amsgrad=False)

    fail_count = 0
    min_cost = float('inf')

    timevec = np.zeros((max_epoch, 1))
    for epoch in range(1, max_epoch):
        
        start = timer()    
        train(model, train_loader, optimizer, MaxX, MinX, MaxY, MinY, lamda1, lamda2)    
        RMSE_val = np.sqrt(test(model, val_loader, MaxX, MinX, MaxY, MinY))
        print('\n Epoch: {}  Val set RMSE = {:.8f} \n'.format(epoch, RMSE_val))
            
        if RMSE_val < min_cost:
            min_cost = RMSE_val
            fail_count = 0
        elif fail_count >= max_fail:
            print('Stopping... Maximum number of validation failures exceeded')
            break
        else:
            fail_count += 1
                
        timevec[epoch] = timer() - start
            
    time_avg = timevec[:epoch].mean()
    print('Average time taken for a single epoch is %f seconds.' % time_avg)

    RMSE_test = np.sqrt(test(model, test_loader, MaxX, MinX, MaxY, MinY))
    print('\n Test set RMSE = {:.8f}\n'.format(RMSE_test))



    #%% Validation

    

    model.to('cpu')

    Xin = (Xtest-MinX)/(MaxX-MinX)
    Xt = torch.from_numpy(Xin)
    Zhat = model(torch.reshape(Xt[:,0], (-1,1)), torch.reshape(Xt[:,1], (-1,1)), torch.reshape(Xt[:,2], (-1,1)))
    Zhat = Zhat.detach().numpy()
    Yhat = Yscaler.inverse_transform(Zhat)

    RMSE_norm = np.sqrt(np.mean((Ytest-Yhat)**2))
    print(RMSE_norm)


    line = np.arange(0, MaxY, 1e-4)
    plt.plot(Ytest[:,0], Yhat[:,0], 'bo')
    plt.plot(line, line, 'k')
    plt.xlabel('true')
    plt.ylabel('predicted')
    plt.title('displacement')
    plt.savefig(path + '/disp_true_v_pred.png')
    # plt.show()
    plt.close('all')



    plt.plot(Xtest[:,2], Yhat[:,0], 'bo')
    plt.plot(Xtest[:,2], Ytest[:,0], 'r')
    plt.xlabel('time')
    plt.ylabel('displacement')
    plt.savefig(path + '/disp_err_v_time.png')
    # plt.show()
    plt.close('all')




    #%% Save Data and Model

    # v1: lamda1 = 1e-9, lamda2 = 1 (noise 0) RMSE: 0.0001379581


    modelname = 'SeismicWave_TDSF_forward_PGNN_v1.pth'
    ANNmodel = {'model': FCNN_Net(numIn, numOut),
            'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict()}
    torch.save(ANNmodel, path + '/' + modelname)


    filename = 'SeismicWave_TDSF_forward_PGNN_v1_result.mat'
    sio.savemat(path + '/' + filename, 
                {'Yhat':Yhat, 'Ytest':Ytest, 'Xtest':Xtest,
                'Ymax':MaxY, 'Ymin':MinY, 'Xmax':MaxX, 'Xmin':MinX})


    #%% Result Comparison

    modelname = 'SeismicWave_TDSF_forward_PGNN_v1.pth'
    model_data1 = torch.load(path + '/' + modelname)

    model1 = model_data1['model']
    model1.load_state_dict(model_data1['state_dict'])
    model1.eval()


    TI = 2
    Ind1 = int((TI-1)*100)
    Ind2 = int(TI*100)
    tv = Xtest[Ind1:Ind2,2]
    Yreal = np.squeeze(Ytest[Ind1:Ind2])

    Xin = (Xtest-MinX)/(MaxX-MinX)

    Ztemp1 = model1(torch.from_numpy(np.reshape(Xin[Ind1:Ind2,0],(-1,1))),
                    torch.from_numpy(np.reshape(Xin[Ind1:Ind2,1],(-1,1))),
                    torch.from_numpy(np.reshape(Xin[Ind1:Ind2,2],(-1,1)))).detach().numpy()
    Ytemp1 = np.squeeze(Yscaler.inverse_transform(Ztemp1))




    #%%

    # Plot desired concentration    
    plt.plot(tv, Yreal, 'k')
    plt.plot(tv, Ytemp1, 'b')
    plt.xlabel('time')
    plt.ylabel('displacement')
    plt.legend(('Truth',f'{sigma}% Noise'))
    plt.savefig(path + '/t_v_d.png')
    # plt.show()
    plt.close('all')



    # Plot desired concentration    
    plt.plot(tv, np.abs(Ytemp1-Yreal), 'b')
    plt.xlabel('time')
    plt.ylabel('displacement error')
    plt.legend((f'{sigma}% Noise'))
    plt.savefig(path + '/t_v_d_err.png')
    plt.close('all')
    # plt.show()




    #%% Correlation Check

    from scipy import signal
    import matplotlib.pyplot as plt

    corr1 = signal.correlate(Ytemp1, Yreal, mode='full', method='auto')
    corr1 /= np.max(corr1)
    lags1 = signal.correlation_lags(len(Ytemp1), len(Yreal))

    plt.plot(lags1, corr1, 'b')
    plt.xlabel('lags')
    plt.ylabel('cross-correlation')
    plt.legend((f'{sigma}% Noise'))
    plt.savefig(path + '/cross_corr.png')
    plt.close('all')
    # plt.show()
# Out:
#  Epoch: 1  Val set RMSE = 0.11030795
#
#
#  Epoch: 2  Val set RMSE = 0.11016774
#
#
#  Epoch: 3  Val set RMSE = 0.11009112
#
#
#  Epoch: 4  Val set RMSE = 0.10997739
#
#
#  Epoch: 5  Val set RMSE = 0.10982220
#
#
#  Epoch: 6  Val set RMSE = 0.10961446
#
#
#  Epoch: 7  Val set RMSE = 0.10933255
#
#
#  Epoch: 8  Val set RMSE = 0.10894820
#
#
#  Epoch: 9  Val set RMSE = 0.10849203
#
#
#  Epoch: 10  Val set RMSE = 0.10806863
#
#
#  Epoch: 11  Val set RMSE = 0.10773086
#
#
#  Epoch: 12  Val set RMSE = 0.10742085
#
#
#  Epoch: 13  Val set RMSE = 0.10708433
#
#
#  Epoch: 14  Val set RMSE = 0.10668322
#
#
#  Epoch: 15  Val set RMSE = 0.10614231
#
#
#  Epoch: 16  Val set RMSE = 0.10518167
#
#
#  Epoch: 17  Val set RMSE = 0.10257722
#
#
#  Epoch: 18  Val set RMSE = 0.09283774
#
#
#  Epoch: 19  Val set RMSE = 0.07430562
#
#
#  Epoch: 20  Val set RMSE = 0.06564377
#
#
#  Epoch: 21  Val set RMSE = 0.05971714
#
#
#  Epoch: 22  Val set RMSE = 0.05266671
#
#
#  Epoch: 23  Val set RMSE = 0.04494124
#
#
#  Epoch: 24  Val set RMSE = 0.03902333
#
#
#  Epoch: 25  Val set RMSE = 0.03597425
#
#
#  Epoch: 26  Val set RMSE = 0.03454658
#
#
#  Epoch: 27  Val set RMSE = 0.03372314
#
#
#  Epoch: 28  Val set RMSE = 0.03303870
#
#
#  Epoch: 29  Val set RMSE = 0.03232844
#
#
#  Epoch: 30  Val set RMSE = 0.03153714
#
#
#  Epoch: 31  Val set RMSE = 0.03063776
#
#
#  Epoch: 32  Val set RMSE = 0.02960385
#
#
#  Epoch: 33  Val set RMSE = 0.02843680
#
#
#  Epoch: 34  Val set RMSE = 0.02714591
#
#
#  Epoch: 35  Val set RMSE = 0.02577010
#
#
#  Epoch: 36  Val set RMSE = 0.02437855
#
#
#  Epoch: 37  Val set RMSE = 0.02310946
#
#
#  Epoch: 38  Val set RMSE = 0.02209232
#
#
#  Epoch: 39  Val set RMSE = 0.02134763
#
#
#  Epoch: 40  Val set RMSE = 0.02080167
#
#
#  Epoch: 41  Val set RMSE = 0.02037455
#
#
#  Epoch: 42  Val set RMSE = 0.02001668
#
#
#  Epoch: 43  Val set RMSE = 0.01969927
#
#
#  Epoch: 44  Val set RMSE = 0.01940524
#
#
#  Epoch: 45  Val set RMSE = 0.01912568
#
#
#  Epoch: 46  Val set RMSE = 0.01885603
#
#
#  Epoch: 47  Val set RMSE = 0.01859273
#
#
#  Epoch: 48  Val set RMSE = 0.01833473
#
#
#  Epoch: 49  Val set RMSE = 0.01808315
#
#
#  Epoch: 50  Val set RMSE = 0.01783941
#
#
#  Epoch: 51  Val set RMSE = 0.01760462
#
#
#  Epoch: 52  Val set RMSE = 0.01737927
#
#
#  Epoch: 53  Val set RMSE = 0.01716312
#
#
#  Epoch: 54  Val set RMSE = 0.01695551
#
#
#  Epoch: 55  Val set RMSE = 0.01675555
#
#
#  Epoch: 56  Val set RMSE = 0.01656242
#
#
#  Epoch: 57  Val set RMSE = 0.01637550
#
#
#  Epoch: 58  Val set RMSE = 0.01619439
#
#
#  Epoch: 59  Val set RMSE = 0.01601878
#
#
#  Epoch: 60  Val set RMSE = 0.01584852
#
#
#  Epoch: 61  Val set RMSE = 0.01568352
#
#
#  Epoch: 62  Val set RMSE = 0.01552371
#
#
#  Epoch: 63  Val set RMSE = 0.01536899
#
#
#  Epoch: 64  Val set RMSE = 0.01521923
#
#
#  Epoch: 65  Val set RMSE = 0.01507423
#
#
#  Epoch: 66  Val set RMSE = 0.01493374
#
#
#  Epoch: 67  Val set RMSE = 0.01479748
#
#
#  Epoch: 68  Val set RMSE = 0.01466515
#
#
#  Epoch: 69  Val set RMSE = 0.01453652
#
#
#  Epoch: 70  Val set RMSE = 0.01441138
#
#
#  Epoch: 71  Val set RMSE = 0.01428958
#
#
#  Epoch: 72  Val set RMSE = 0.01417109
#
#
#  Epoch: 73  Val set RMSE = 0.01405596
#
#
#  Epoch: 74  Val set RMSE = 0.01394435
#
#
#  Epoch: 75  Val set RMSE = 0.01383643
#
#
#  Epoch: 76  Val set RMSE = 0.01373242
#
#
#  Epoch: 77  Val set RMSE = 0.01363247
#
#
#  Epoch: 78  Val set RMSE = 0.01353665
#
#
#  Epoch: 79  Val set RMSE = 0.01344493
#
#
#  Epoch: 80  Val set RMSE = 0.01335720
#
#
#  Epoch: 81  Val set RMSE = 0.01327326
#
#
#  Epoch: 82  Val set RMSE = 0.01319288
#
#
#  Epoch: 83  Val set RMSE = 0.01311577
#
#
#  Epoch: 84  Val set RMSE = 0.01304162
#
#
#  Epoch: 85  Val set RMSE = 0.01297012
#
#
#  Epoch: 86  Val set RMSE = 0.01290093
#
#
#  Epoch: 87  Val set RMSE = 0.01283376
#
#
#  Epoch: 88  Val set RMSE = 0.01276832
#
#
#  Epoch: 89  Val set RMSE = 0.01270435
#
#
#  Epoch: 90  Val set RMSE = 0.01264164
#
#
#  Epoch: 91  Val set RMSE = 0.01257998
#
#
#  Epoch: 92  Val set RMSE = 0.01251923
#
#
#  Epoch: 93  Val set RMSE = 0.01245923
#
#
#  Epoch: 94  Val set RMSE = 0.01239986
#
#
#  Epoch: 95  Val set RMSE = 0.01234104
#
#
#  Epoch: 96  Val set RMSE = 0.01228269
#
#
#  Epoch: 97  Val set RMSE = 0.01222475
#
#
#  Epoch: 98  Val set RMSE = 0.01216715
#
#
#  Epoch: 99  Val set RMSE = 0.01210982
#
#
#  Epoch: 100  Val set RMSE = 0.01205267
#
#
#  Epoch: 101  Val set RMSE = 0.01199554
#
#
#  Epoch: 102  Val set RMSE = 0.01193827
#
#
#  Epoch: 103  Val set RMSE = 0.01188077
#
#
#  Epoch: 104  Val set RMSE = 0.01182314
#
#
#  Epoch: 105  Val set RMSE = 0.01176571
#
#
#  Epoch: 106  Val set RMSE = 0.01170889
#
#
#  Epoch: 107  Val set RMSE = 0.01165295
#
#
#  Epoch: 108  Val set RMSE = 0.01159795
#
#
#  Epoch: 109  Val set RMSE = 0.01154333
#
#
#  Epoch: 110  Val set RMSE = 0.01148848
#
#
#  Epoch: 111  Val set RMSE = 0.01143330
#
#
#  Epoch: 112  Val set RMSE = 0.01137798
#
#
#  Epoch: 113  Val set RMSE = 0.01132272
#
#
#  Epoch: 114  Val set RMSE = 0.01126763
#
#
#  Epoch: 115  Val set RMSE = 0.01121285
#
#
#  Epoch: 116  Val set RMSE = 0.01115847
#
#
#  Epoch: 117  Val set RMSE = 0.01110479
#
#
#  Epoch: 118  Val set RMSE = 0.01105241
#
#
#  Epoch: 119  Val set RMSE = 0.01100253
#
#
#  Epoch: 120  Val set RMSE = 0.01095613
#
#
#  Epoch: 121  Val set RMSE = 0.01091177
#
#
#  Epoch: 122  Val set RMSE = 0.01086709
#
#
#  Epoch: 123  Val set RMSE = 0.01082205
#
#
#  Epoch: 124  Val set RMSE = 0.01077737
#
#
#  Epoch: 125  Val set RMSE = 0.01073353
#
#
#  Epoch: 126  Val set RMSE = 0.01069082
#
#
#  Epoch: 127  Val set RMSE = 0.01064931
#
#
#  Epoch: 128  Val set RMSE = 0.01060912
#
#
#  Epoch: 129  Val set RMSE = 0.01057025
#
#
#  Epoch: 130  Val set RMSE = 0.01053273
#
#
#  Epoch: 131  Val set RMSE = 0.01049658
#
#
#  Epoch: 132  Val set RMSE = 0.01046173
#
#
#  Epoch: 133  Val set RMSE = 0.01042819
#
#
#  Epoch: 134  Val set RMSE = 0.01039596
#
#
#  Epoch: 135  Val set RMSE = 0.01036500
#
#
#  Epoch: 136  Val set RMSE = 0.01033524
#
#
#  Epoch: 137  Val set RMSE = 0.01030665
#
#
#  Epoch: 138  Val set RMSE = 0.01027920
#
#
#  Epoch: 139  Val set RMSE = 0.01025288
#
#
#  Epoch: 140  Val set RMSE = 0.01022760
#
#
#  Epoch: 141  Val set RMSE = 0.01020331
#
#
#  Epoch: 142  Val set RMSE = 0.01018002
#
#
#  Epoch: 143  Val set RMSE = 0.01015765
#
#
#  Epoch: 144  Val set RMSE = 0.01013617
#
#
#  Epoch: 145  Val set RMSE = 0.01011556
#
#
#  Epoch: 146  Val set RMSE = 0.01009578
#
#
#  Epoch: 147  Val set RMSE = 0.01007678
#
#
#  Epoch: 148  Val set RMSE = 0.01005858
#
#
#  Epoch: 149  Val set RMSE = 0.01004111
#
#
#  Epoch: 150  Val set RMSE = 0.01002436
#
#
#  Epoch: 151  Val set RMSE = 0.01000834
#
#
#  Epoch: 152  Val set RMSE = 0.00999298
#
#
#  Epoch: 153  Val set RMSE = 0.00997833
#
#
#  Epoch: 154  Val set RMSE = 0.00996435
#
#
#  Epoch: 155  Val set RMSE = 0.00995103
#
#
#  Epoch: 156  Val set RMSE = 0.00993838
#
#
#  Epoch: 157  Val set RMSE = 0.00992638
#
#
#  Epoch: 158  Val set RMSE = 0.00991502
#
#
#  Epoch: 159  Val set RMSE = 0.00990428
#
#
#  Epoch: 160  Val set RMSE = 0.00989412
#
#
#  Epoch: 161  Val set RMSE = 0.00988454
#
#
#  Epoch: 162  Val set RMSE = 0.00987549
#
#
#  Epoch: 163  Val set RMSE = 0.00986695
#
#
#  Epoch: 164  Val set RMSE = 0.00985885
#
#
#  Epoch: 165  Val set RMSE = 0.00985118
#
#
#  Epoch: 166  Val set RMSE = 0.00984385
#
#
#  Epoch: 167  Val set RMSE = 0.00983682
#
#
#  Epoch: 168  Val set RMSE = 0.00983003
#
#
#  Epoch: 169  Val set RMSE = 0.00982346
#
#
#  Epoch: 170  Val set RMSE = 0.00981702
#
#
#  Epoch: 171  Val set RMSE = 0.00981069
#
#
#  Epoch: 172  Val set RMSE = 0.00980443
#
#
#  Epoch: 173  Val set RMSE = 0.00979819
#
#
#  Epoch: 174  Val set RMSE = 0.00979196
#
#
#  Epoch: 175  Val set RMSE = 0.00978573
#
#
#  Epoch: 176  Val set RMSE = 0.00977949
#
#
#  Epoch: 177  Val set RMSE = 0.00977325
#
#
#  Epoch: 178  Val set RMSE = 0.00976701
#
#
#  Epoch: 179  Val set RMSE = 0.00976082
#
#
#  Epoch: 180  Val set RMSE = 0.00975469
#
#
#  Epoch: 181  Val set RMSE = 0.00974870
#
#
#  Epoch: 182  Val set RMSE = 0.00974282
#
#
#  Epoch: 183  Val set RMSE = 0.00973709
#
#
#  Epoch: 184  Val set RMSE = 0.00973144
#
#
#  Epoch: 185  Val set RMSE = 0.00972581
#
#
#  Epoch: 186  Val set RMSE = 0.00972017
#
#
#  Epoch: 187  Val set RMSE = 0.00971442
#
#
#  Epoch: 188  Val set RMSE = 0.00970850
#
#
#  Epoch: 189  Val set RMSE = 0.00970237
#
#
#  Epoch: 190  Val set RMSE = 0.00969597
#
#
#  Epoch: 191  Val set RMSE = 0.00968932
#
#
#  Epoch: 192  Val set RMSE = 0.00968242
#
#
#  Epoch: 193  Val set RMSE = 0.00967527
#
#
#  Epoch: 194  Val set RMSE = 0.00966792
#
#
#  Epoch: 195  Val set RMSE = 0.00966037
#
#
#  Epoch: 196  Val set RMSE = 0.00965263
#
#
#  Epoch: 197  Val set RMSE = 0.00964474
#
#
#  Epoch: 198  Val set RMSE = 0.00963674
#
#
#  Epoch: 199  Val set RMSE = 0.00962861
#
#
#  Epoch: 200  Val set RMSE = 0.00962038
#
#
#  Epoch: 201  Val set RMSE = 0.00961206
#
#
#  Epoch: 202  Val set RMSE = 0.00960364
#
#
#  Epoch: 203  Val set RMSE = 0.00959515
#
#
#  Epoch: 204  Val set RMSE = 0.00958657
#
#
#  Epoch: 205  Val set RMSE = 0.00957790
#
#
#  Epoch: 206  Val set RMSE = 0.00956917
#
#
#  Epoch: 207  Val set RMSE = 0.00956036
#
#
#  Epoch: 208  Val set RMSE = 0.00955147
#
#
#  Epoch: 209  Val set RMSE = 0.00954250
#
#
#  Epoch: 210  Val set RMSE = 0.00953348
#
#
#  Epoch: 211  Val set RMSE = 0.00952440
#
#
#  Epoch: 212  Val set RMSE = 0.00951523
#
#
#  Epoch: 213  Val set RMSE = 0.00950602
#
#
#  Epoch: 214  Val set RMSE = 0.00949675
#
#
#  Epoch: 215  Val set RMSE = 0.00948740
#
#
#  Epoch: 216  Val set RMSE = 0.00947803
#
#
#  Epoch: 217  Val set RMSE = 0.00946858
#
#
#  Epoch: 218  Val set RMSE = 0.00945908
#
#
#  Epoch: 219  Val set RMSE = 0.00944954
#
#
#  Epoch: 220  Val set RMSE = 0.00943996
#
#
#  Epoch: 221  Val set RMSE = 0.00943032
#
#
#  Epoch: 222  Val set RMSE = 0.00942063
#
#
#  Epoch: 223  Val set RMSE = 0.00941091
#
#
#  Epoch: 224  Val set RMSE = 0.00940114
#
#
#  Epoch: 225  Val set RMSE = 0.00939131
#
#
#  Epoch: 226  Val set RMSE = 0.00938146
#
#
#  Epoch: 227  Val set RMSE = 0.00937157
#
#
#  Epoch: 228  Val set RMSE = 0.00936163
#
#
#  Epoch: 229  Val set RMSE = 0.00935165
#
#
#  Epoch: 230  Val set RMSE = 0.00934164
#
#
#  Epoch: 231  Val set RMSE = 0.00933161
#
#
#  Epoch: 232  Val set RMSE = 0.00932151
#
#
#  Epoch: 233  Val set RMSE = 0.00931142
#
#
#  Epoch: 234  Val set RMSE = 0.00930127
#
#
#  Epoch: 235  Val set RMSE = 0.00929108
#
#
#  Epoch: 236  Val set RMSE = 0.00928086
#
#
#  Epoch: 237  Val set RMSE = 0.00927063
#
#
#  Epoch: 238  Val set RMSE = 0.00926036
#
#
#  Epoch: 239  Val set RMSE = 0.00925007
#
#
#  Epoch: 240  Val set RMSE = 0.00923974
#
#
#  Epoch: 241  Val set RMSE = 0.00922941
#
#
#  Epoch: 242  Val set RMSE = 0.00921904
#
#
#  Epoch: 243  Val set RMSE = 0.00920864
#
#
#  Epoch: 244  Val set RMSE = 0.00919822
#
#
#  Epoch: 245  Val set RMSE = 0.00918780
#
#
#  Epoch: 246  Val set RMSE = 0.00917734
#
#
#  Epoch: 247  Val set RMSE = 0.00916687
#
#
#  Epoch: 248  Val set RMSE = 0.00915638
#
#
#  Epoch: 249  Val set RMSE = 0.00914586
#
#
#  Epoch: 250  Val set RMSE = 0.00913535
#
#
#  Epoch: 251  Val set RMSE = 0.00912481
#
#
#  Epoch: 252  Val set RMSE = 0.00911427
#
#
#  Epoch: 253  Val set RMSE = 0.00910371
#
#
#  Epoch: 254  Val set RMSE = 0.00909314
#
#
#  Epoch: 255  Val set RMSE = 0.00908255
#
#
#  Epoch: 256  Val set RMSE = 0.00907195
#
#
#  Epoch: 257  Val set RMSE = 0.00906136
#
#
#  Epoch: 258  Val set RMSE = 0.00905076
#
#
#  Epoch: 259  Val set RMSE = 0.00904014
#
#
#  Epoch: 260  Val set RMSE = 0.00902954
#
#
#  Epoch: 261  Val set RMSE = 0.00901891
#
#
#  Epoch: 262  Val set RMSE = 0.00900828
#
#
#  Epoch: 263  Val set RMSE = 0.00899766
#
#
#  Epoch: 264  Val set RMSE = 0.00898702
#
#
#  Epoch: 265  Val set RMSE = 0.00897640
#
#
#  Epoch: 266  Val set RMSE = 0.00896577
#
#
#  Epoch: 267  Val set RMSE = 0.00895513
#
#
#  Epoch: 268  Val set RMSE = 0.00894452
#
#
#  Epoch: 269  Val set RMSE = 0.00893389
#
#
#  Epoch: 270  Val set RMSE = 0.00892326
#
#
#  Epoch: 271  Val set RMSE = 0.00891263
#
#
#  Epoch: 272  Val set RMSE = 0.00890201
#
#
#  Epoch: 273  Val set RMSE = 0.00889138
#
#
#  Epoch: 274  Val set RMSE = 0.00888078
#
#
#  Epoch: 275  Val set RMSE = 0.00887016
#
#
#  Epoch: 276  Val set RMSE = 0.00885954
#
#
#  Epoch: 277  Val set RMSE = 0.00884893
#
#
#  Epoch: 278  Val set RMSE = 0.00883832
#
#
#  Epoch: 279  Val set RMSE = 0.00882771
#
#
#  Epoch: 280  Val set RMSE = 0.00881711
#
#
#  Epoch: 281  Val set RMSE = 0.00880653
#
#
#  Epoch: 282  Val set RMSE = 0.00879592
#
#
#  Epoch: 283  Val set RMSE = 0.00878532
#
#
#  Epoch: 284  Val set RMSE = 0.00877474
#
#
#  Epoch: 285  Val set RMSE = 0.00876417
#
#
#  Epoch: 286  Val set RMSE = 0.00875356
#
#
#  Epoch: 287  Val set RMSE = 0.00874300
#
#
#  Epoch: 288  Val set RMSE = 0.00873243
#
#
#  Epoch: 289  Val set RMSE = 0.00872185
#
#
#  Epoch: 290  Val set RMSE = 0.00871128
#
#
#  Epoch: 291  Val set RMSE = 0.00870072
#
#
#  Epoch: 292  Val set RMSE = 0.00869016
#
#
#  Epoch: 293  Val set RMSE = 0.00867960
#
#
#  Epoch: 294  Val set RMSE = 0.00866904
#
#
#  Epoch: 295  Val set RMSE = 0.00865847
#
#
#  Epoch: 296  Val set RMSE = 0.00864792
#
#
#  Epoch: 297  Val set RMSE = 0.00863736
#
#
#  Epoch: 298  Val set RMSE = 0.00862682
#
#
#  Epoch: 299  Val set RMSE = 0.00861626
#
#
#  Epoch: 300  Val set RMSE = 0.00860571
#
#
#  Epoch: 301  Val set RMSE = 0.00859516
#
#
#  Epoch: 302  Val set RMSE = 0.00858460
#
#
#  Epoch: 303  Val set RMSE = 0.00857405
#
#
#  Epoch: 304  Val set RMSE = 0.00856351
#
#
#  Epoch: 305  Val set RMSE = 0.00855294
#
#
#  Epoch: 306  Val set RMSE = 0.00854238
#
#
#  Epoch: 307  Val set RMSE = 0.00853180
#
#
#  Epoch: 308  Val set RMSE = 0.00852127
#
#
#  Epoch: 309  Val set RMSE = 0.00851067
#
#
#  Epoch: 310  Val set RMSE = 0.00850011
#
#
#  Epoch: 311  Val set RMSE = 0.00848951
#
#
#  Epoch: 312  Val set RMSE = 0.00847892
#
#
#  Epoch: 313  Val set RMSE = 0.00846833
#
#
#  Epoch: 314  Val set RMSE = 0.00845772
#
#
#  Epoch: 315  Val set RMSE = 0.00844710
#
#
#  Epoch: 316  Val set RMSE = 0.00843649
#
#
#  Epoch: 317  Val set RMSE = 0.00842585
#
#
#  Epoch: 318  Val set RMSE = 0.00841522
#
#
#  Epoch: 319  Val set RMSE = 0.00840454
#
#
#  Epoch: 320  Val set RMSE = 0.00839388
#
#
#  Epoch: 321  Val set RMSE = 0.00838319
#
#
#  Epoch: 322  Val set RMSE = 0.00837249
#
#
#  Epoch: 323  Val set RMSE = 0.00836179
#
#
#  Epoch: 324  Val set RMSE = 0.00835108
#
#
#  Epoch: 325  Val set RMSE = 0.00834032
#
#
#  Epoch: 326  Val set RMSE = 0.00832956
#
#
#  Epoch: 327  Val set RMSE = 0.00831879
#
#
#  Epoch: 328  Val set RMSE = 0.00830800
#
#
#  Epoch: 329  Val set RMSE = 0.00829718
#
#
#  Epoch: 330  Val set RMSE = 0.00828634
#
#
#  Epoch: 331  Val set RMSE = 0.00827547
#
#
#  Epoch: 332  Val set RMSE = 0.00826460
#
#
#  Epoch: 333  Val set RMSE = 0.00825369
#
#
#  Epoch: 334  Val set RMSE = 0.00824277
#
#
#  Epoch: 335  Val set RMSE = 0.00823180
#
#
#  Epoch: 336  Val set RMSE = 0.00822079
#
#
#  Epoch: 337  Val set RMSE = 0.00820978
#
#
#  Epoch: 338  Val set RMSE = 0.00819873
#
#
#  Epoch: 339  Val set RMSE = 0.00818764
#
#
#  Epoch: 340  Val set RMSE = 0.00817649
#
#
#  Epoch: 341  Val set RMSE = 0.00816531
#
#
#  Epoch: 342  Val set RMSE = 0.00815409
#
#
#  Epoch: 343  Val set RMSE = 0.00814283
#
#
#  Epoch: 344  Val set RMSE = 0.00813150
#
#
#  Epoch: 345  Val set RMSE = 0.00812011
#
#
#  Epoch: 346  Val set RMSE = 0.00810865
#
#
#  Epoch: 347  Val set RMSE = 0.00809716
#
#
#  Epoch: 348  Val set RMSE = 0.00808557
#
#
#  Epoch: 349  Val set RMSE = 0.00807392
#
#
#  Epoch: 350  Val set RMSE = 0.00806221
#
#
#  Epoch: 351  Val set RMSE = 0.00805046
#
#
#  Epoch: 352  Val set RMSE = 0.00803862
#
#
#  Epoch: 353  Val set RMSE = 0.00802675
#
#
#  Epoch: 354  Val set RMSE = 0.00801486
#
#
#  Epoch: 355  Val set RMSE = 0.00800291
#
#
#  Epoch: 356  Val set RMSE = 0.00799099
#
#
#  Epoch: 357  Val set RMSE = 0.00797907
#
#
#  Epoch: 358  Val set RMSE = 0.00796718
#
#
#  Epoch: 359  Val set RMSE = 0.00795534
#
#
#  Epoch: 360  Val set RMSE = 0.00794354
#
#
#  Epoch: 361  Val set RMSE = 0.00793180
#
#
#  Epoch: 362  Val set RMSE = 0.00792011
#
#
#  Epoch: 363  Val set RMSE = 0.00790848
#
#
#  Epoch: 364  Val set RMSE = 0.00789694
#
#
#  Epoch: 365  Val set RMSE = 0.00788546
#
#
#  Epoch: 366  Val set RMSE = 0.00787404
#
#
#  Epoch: 367  Val set RMSE = 0.00786271
#
#
#  Epoch: 368  Val set RMSE = 0.00785143
#
#
#  Epoch: 369  Val set RMSE = 0.00784025
#
#
#  Epoch: 370  Val set RMSE = 0.00782913
#
#
#  Epoch: 371  Val set RMSE = 0.00781810
#
#
#  Epoch: 372  Val set RMSE = 0.00780713
#
#
#  Epoch: 373  Val set RMSE = 0.00779627
#
#
#  Epoch: 374  Val set RMSE = 0.00778545
#
#
#  Epoch: 375  Val set RMSE = 0.00777476
#
#
#  Epoch: 376  Val set RMSE = 0.00776411
#
#
#  Epoch: 377  Val set RMSE = 0.00775361
#
#
#  Epoch: 378  Val set RMSE = 0.00774317
#
#
#  Epoch: 379  Val set RMSE = 0.00773283
#
#
#  Epoch: 380  Val set RMSE = 0.00772257
#
#
#  Epoch: 381  Val set RMSE = 0.00771241
#
#
#  Epoch: 382  Val set RMSE = 0.00770235
#
#
#  Epoch: 383  Val set RMSE = 0.00769241
#
#
#  Epoch: 384  Val set RMSE = 0.00768256
#
#
#  Epoch: 385  Val set RMSE = 0.00767282
#
#
#  Epoch: 386  Val set RMSE = 0.00766318
#
#
#  Epoch: 387  Val set RMSE = 0.00765362
#
#
#  Epoch: 388  Val set RMSE = 0.00764419
#
#
#  Epoch: 389  Val set RMSE = 0.00763486
#
#
#  Epoch: 390  Val set RMSE = 0.00762564
#
#
#  Epoch: 391  Val set RMSE = 0.00761651
#
#
#  Epoch: 392  Val set RMSE = 0.00760751
#
#
#  Epoch: 393  Val set RMSE = 0.00759859
#
#
#  Epoch: 394  Val set RMSE = 0.00758979
#
#
#  Epoch: 395  Val set RMSE = 0.00758110
#
#
#  Epoch: 396  Val set RMSE = 0.00757249
#
#
#  Epoch: 397  Val set RMSE = 0.00756401
#
#
#  Epoch: 398  Val set RMSE = 0.00755563
#
#
#  Epoch: 399  Val set RMSE = 0.00754733
#
#
#  Epoch: 400  Val set RMSE = 0.00753916
#
#
#  Epoch: 401  Val set RMSE = 0.00753104
#
#
#  Epoch: 402  Val set RMSE = 0.00752304
#
#
#  Epoch: 403  Val set RMSE = 0.00751516
#
#
#  Epoch: 404  Val set RMSE = 0.00750736
#
#
#  Epoch: 405  Val set RMSE = 0.00749965
#
#
#  Epoch: 406  Val set RMSE = 0.00749204
#
#
#  Epoch: 407  Val set RMSE = 0.00748452
#
#
#  Epoch: 408  Val set RMSE = 0.00747706
#
#
#  Epoch: 409  Val set RMSE = 0.00746973
#
#
#  Epoch: 410  Val set RMSE = 0.00746247
#
#
#  Epoch: 411  Val set RMSE = 0.00745528
#
#
#  Epoch: 412  Val set RMSE = 0.00744820
#
#
#  Epoch: 413  Val set RMSE = 0.00744123
#
#
#  Epoch: 414  Val set RMSE = 0.00743430
#
#
#  Epoch: 415  Val set RMSE = 0.00742748
#
#
#  Epoch: 416  Val set RMSE = 0.00742073
#
#
#  Epoch: 417  Val set RMSE = 0.00741406
#
#
#  Epoch: 418  Val set RMSE = 0.00740749
#
#
#  Epoch: 419  Val set RMSE = 0.00740096
#
#
#  Epoch: 420  Val set RMSE = 0.00739457
#
#
#  Epoch: 421  Val set RMSE = 0.00738822
#
#
#  Epoch: 422  Val set RMSE = 0.00738197
#
#
#  Epoch: 423  Val set RMSE = 0.00737577
#
#
#  Epoch: 424  Val set RMSE = 0.00736966
#
#
#  Epoch: 425  Val set RMSE = 0.00736365
#
#
#  Epoch: 426  Val set RMSE = 0.00735770
#
#
#  Epoch: 427  Val set RMSE = 0.00735182
#
#
#  Epoch: 428  Val set RMSE = 0.00734602
#
#
#  Epoch: 429  Val set RMSE = 0.00734032
#
#
#  Epoch: 430  Val set RMSE = 0.00733469
#
#
#  Epoch: 431  Val set RMSE = 0.00732912
#
#
#  Epoch: 432  Val set RMSE = 0.00732365
#
#
#  Epoch: 433  Val set RMSE = 0.00731824
#
#
#  Epoch: 434  Val set RMSE = 0.00731291
#
#
#  Epoch: 435  Val set RMSE = 0.00730767
#
#
#  Epoch: 436  Val set RMSE = 0.00730250
#
#
#  Epoch: 437  Val set RMSE = 0.00729741
#
#
#  Epoch: 438  Val set RMSE = 0.00729241
#
#
#  Epoch: 439  Val set RMSE = 0.00728748
#
#
#  Epoch: 440  Val set RMSE = 0.00728262
#
#
#  Epoch: 441  Val set RMSE = 0.00727784
#
#
#  Epoch: 442  Val set RMSE = 0.00727315
#
#
#  Epoch: 443  Val set RMSE = 0.00726852
#
#
#  Epoch: 444  Val set RMSE = 0.00726400
#
#
#  Epoch: 445  Val set RMSE = 0.00725953
#
#
#  Epoch: 446  Val set RMSE = 0.00725511
#
#
#  Epoch: 447  Val set RMSE = 0.00725079
#
#
#  Epoch: 448  Val set RMSE = 0.00724653
#
#
#  Epoch: 449  Val set RMSE = 0.00724237
#
#
#  Epoch: 450  Val set RMSE = 0.00723825
#
#
#  Epoch: 451  Val set RMSE = 0.00723421
#
#
#  Epoch: 452  Val set RMSE = 0.00723021
#
#
#  Epoch: 453  Val set RMSE = 0.00722631
#
#
#  Epoch: 454  Val set RMSE = 0.00722244
#
#
#  Epoch: 455  Val set RMSE = 0.00721862
#
#
#  Epoch: 456  Val set RMSE = 0.00721494
#
#
#  Epoch: 457  Val set RMSE = 0.00721126
#
#
#  Epoch: 458  Val set RMSE = 0.00720764
#
#
#  Epoch: 459  Val set RMSE = 0.00720409
#
#
#  Epoch: 460  Val set RMSE = 0.00720058
#
#
#  Epoch: 461  Val set RMSE = 0.00719714
#
#
#  Epoch: 462  Val set RMSE = 0.00719373
#
#
#  Epoch: 463  Val set RMSE = 0.00719044
#
#
#  Epoch: 464  Val set RMSE = 0.00718713
#
#
#  Epoch: 465  Val set RMSE = 0.00718388
#
#
#  Epoch: 466  Val set RMSE = 0.00718069
#
#
#  Epoch: 467  Val set RMSE = 0.00717755
#
#
#  Epoch: 468  Val set RMSE = 0.00717446
#
#
#  Epoch: 469  Val set RMSE = 0.00717140
#
#
#  Epoch: 470  Val set RMSE = 0.00716841
#
#
#  Epoch: 471  Val set RMSE = 0.00716543
#
#
#  Epoch: 472  Val set RMSE = 0.00716252
#
#
#  Epoch: 473  Val set RMSE = 0.00715963
#
#
#  Epoch: 474  Val set RMSE = 0.00715676
#
#
#  Epoch: 475  Val set RMSE = 0.00715396
#
#
#  Epoch: 476  Val set RMSE = 0.00715120
#
#
#  Epoch: 477  Val set RMSE = 0.00714848
#
#
#  Epoch: 478  Val set RMSE = 0.00714575
#
#
#  Epoch: 479  Val set RMSE = 0.00714306
#
#
#  Epoch: 480  Val set RMSE = 0.00714041
#
#
#  Epoch: 481  Val set RMSE = 0.00713782
#
#
#  Epoch: 482  Val set RMSE = 0.00713524
#
#
#  Epoch: 483  Val set RMSE = 0.00713267
#
#
#  Epoch: 484  Val set RMSE = 0.00713016
#
#
#  Epoch: 485  Val set RMSE = 0.00712765
#
#
#  Epoch: 486  Val set RMSE = 0.00712520
#
#
#  Epoch: 487  Val set RMSE = 0.00712278
#
#
#  Epoch: 488  Val set RMSE = 0.00712037
#
#
#  Epoch: 489  Val set RMSE = 0.00711795
#
#
#  Epoch: 490  Val set RMSE = 0.00711562
#
#
#  Epoch: 491  Val set RMSE = 0.00711329
#
#
#  Epoch: 492  Val set RMSE = 0.00711099
#
#
#  Epoch: 493  Val set RMSE = 0.00710872
#
#
#  Epoch: 494  Val set RMSE = 0.00710645
#
#
#  Epoch: 495  Val set RMSE = 0.00710425
#
#
#  Epoch: 496  Val set RMSE = 0.00710206
#
#
#  Epoch: 497  Val set RMSE = 0.00709989
#
#
#  Epoch: 498  Val set RMSE = 0.00709770
#
#
#  Epoch: 499  Val set RMSE = 0.00709558
#
#
#  Epoch: 500  Val set RMSE = 0.00709349
#
#
#  Epoch: 501  Val set RMSE = 0.00709139
#
#
#  Epoch: 502  Val set RMSE = 0.00708936
#
#
#  Epoch: 503  Val set RMSE = 0.00708733
#
#
#  Epoch: 504  Val set RMSE = 0.00708530
#
#
#  Epoch: 505  Val set RMSE = 0.00708332
#
#
#  Epoch: 506  Val set RMSE = 0.00708132
#
#
#  Epoch: 507  Val set RMSE = 0.00707939
#
#
#  Epoch: 508  Val set RMSE = 0.00707746
#
#
#  Epoch: 509  Val set RMSE = 0.00707554
#
#
#  Epoch: 510  Val set RMSE = 0.00707360
#
#
#  Epoch: 511  Val set RMSE = 0.00707174
#
#
#  Epoch: 512  Val set RMSE = 0.00706984
#
#
#  Epoch: 513  Val set RMSE = 0.00706804
#
#
#  Epoch: 514  Val set RMSE = 0.00706618
#
#
#  Epoch: 515  Val set RMSE = 0.00706437
#
#
#  Epoch: 516  Val set RMSE = 0.00706259
#
#
#  Epoch: 517  Val set RMSE = 0.00706080
#
#
#  Epoch: 518  Val set RMSE = 0.00705903
#
#
#  Epoch: 519  Val set RMSE = 0.00705724
#
#
#  Epoch: 520  Val set RMSE = 0.00705548
#
#
#  Epoch: 521  Val set RMSE = 0.00705374
#
#
#  Epoch: 522  Val set RMSE = 0.00705202
#
#
#  Epoch: 523  Val set RMSE = 0.00705032
#
#
#  Epoch: 524  Val set RMSE = 0.00704858
#
#
#  Epoch: 525  Val set RMSE = 0.00704688
#
#
#  Epoch: 526  Val set RMSE = 0.00704520
#
#
#  Epoch: 527  Val set RMSE = 0.00704350
#
#
#  Epoch: 528  Val set RMSE = 0.00704184
#
#
#  Epoch: 529  Val set RMSE = 0.00704017
#
#
#  Epoch: 530  Val set RMSE = 0.00703850
#
#
#  Epoch: 531  Val set RMSE = 0.00703684
#
#
#  Epoch: 532  Val set RMSE = 0.00703521
#
#
#  Epoch: 533  Val set RMSE = 0.00703356
#
#
#  Epoch: 534  Val set RMSE = 0.00703190
#
#
#  Epoch: 535  Val set RMSE = 0.00703028
#
#
#  Epoch: 536  Val set RMSE = 0.00702863
#
#
#  Epoch: 537  Val set RMSE = 0.00702700
#
#
#  Epoch: 538  Val set RMSE = 0.00702538
#
#
#  Epoch: 539  Val set RMSE = 0.00702379
#
#
#  Epoch: 540  Val set RMSE = 0.00702217
#
#
#  Epoch: 541  Val set RMSE = 0.00702054
#
#
#  Epoch: 542  Val set RMSE = 0.00701893
#
#
#  Epoch: 543  Val set RMSE = 0.00701731
#
#
#  Epoch: 544  Val set RMSE = 0.00701571
#
#
#  Epoch: 545  Val set RMSE = 0.00701407
#
#
#  Epoch: 546  Val set RMSE = 0.00701246
#
#
#  Epoch: 547  Val set RMSE = 0.00701086
#
#
#  Epoch: 548  Val set RMSE = 0.00700926
#
#
#  Epoch: 549  Val set RMSE = 0.00700764
#
#
#  Epoch: 550  Val set RMSE = 0.00700599
#
#
#  Epoch: 551  Val set RMSE = 0.00700439
#
#
#  Epoch: 552  Val set RMSE = 0.00700276
#
#
#  Epoch: 553  Val set RMSE = 0.00700111
#
#
#  Epoch: 554  Val set RMSE = 0.00699952
#
#
#  Epoch: 555  Val set RMSE = 0.00699786
#
#
#  Epoch: 556  Val set RMSE = 0.00699627
#
#
#  Epoch: 557  Val set RMSE = 0.00699461
#
#
#  Epoch: 558  Val set RMSE = 0.00699298
#
#
#  Epoch: 559  Val set RMSE = 0.00699134
#
#
#  Epoch: 560  Val set RMSE = 0.00698973
#
#
#  Epoch: 561  Val set RMSE = 0.00698806
#
#
#  Epoch: 562  Val set RMSE = 0.00698639
#
#
#  Epoch: 563  Val set RMSE = 0.00698475
#
#
#  Epoch: 564  Val set RMSE = 0.00698310
#
#
#  Epoch: 565  Val set RMSE = 0.00698142
#
#
#  Epoch: 566  Val set RMSE = 0.00697976
#
#
#  Epoch: 567  Val set RMSE = 0.00697806
#
#
#  Epoch: 568  Val set RMSE = 0.00697640
#
#
#  Epoch: 569  Val set RMSE = 0.00697470
#
#
#  Epoch: 570  Val set RMSE = 0.00697302
#
#
#  Epoch: 571  Val set RMSE = 0.00697129
#
#
#  Epoch: 572  Val set RMSE = 0.00696960
#
#
#  Epoch: 573  Val set RMSE = 0.00696788
#
#
#  Epoch: 574  Val set RMSE = 0.00696618
#
#
#  Epoch: 575  Val set RMSE = 0.00696448
#
#
#  Epoch: 576  Val set RMSE = 0.00696276
#
#
#  Epoch: 577  Val set RMSE = 0.00696102
#
#
#  Epoch: 578  Val set RMSE = 0.00695932
#
#
#  Epoch: 579  Val set RMSE = 0.00695755
#
#
#  Epoch: 580  Val set RMSE = 0.00695583
#
#
#  Epoch: 581  Val set RMSE = 0.00695407
#
#
#  Epoch: 582  Val set RMSE = 0.00695231
#
#
#  Epoch: 583  Val set RMSE = 0.00695057
#
#
#  Epoch: 584  Val set RMSE = 0.00694880
#
#
#  Epoch: 585  Val set RMSE = 0.00694705
#
#
#  Epoch: 586  Val set RMSE = 0.00694522
#
#
#  Epoch: 587  Val set RMSE = 0.00694345
#
#
#  Epoch: 588  Val set RMSE = 0.00694165
#
#
#  Epoch: 589  Val set RMSE = 0.00693987
#
#
#  Epoch: 590  Val set RMSE = 0.00693805
#
#
#  Epoch: 591  Val set RMSE = 0.00693626
#
#
#  Epoch: 592  Val set RMSE = 0.00693441
#
#
#  Epoch: 593  Val set RMSE = 0.00693261
#
#
#  Epoch: 594  Val set RMSE = 0.00693077
#
#
#  Epoch: 595  Val set RMSE = 0.00692895
#
#
#  Epoch: 596  Val set RMSE = 0.00692712
#
#
#  Epoch: 597  Val set RMSE = 0.00692527
#
#
#  Epoch: 598  Val set RMSE = 0.00692342
#
#
#  Epoch: 599  Val set RMSE = 0.00692152
#
#
#  Epoch: 600  Val set RMSE = 0.00691967
#
#
#  Epoch: 601  Val set RMSE = 0.00691782
#
#
#  Epoch: 602  Val set RMSE = 0.00691594
#
#
#  Epoch: 603  Val set RMSE = 0.00691408
#
#
#  Epoch: 604  Val set RMSE = 0.00691219
#
#
#  Epoch: 605  Val set RMSE = 0.00691031
#
#
#  Epoch: 606  Val set RMSE = 0.00690840
#
#
#  Epoch: 607  Val set RMSE = 0.00690650
#
#
#  Epoch: 608  Val set RMSE = 0.00690460
#
#
#  Epoch: 609  Val set RMSE = 0.00690266
#
#
#  Epoch: 610  Val set RMSE = 0.00690075
#
#
#  Epoch: 611  Val set RMSE = 0.00689883
#
#
#  Epoch: 612  Val set RMSE = 0.00689694
#
#
#  Epoch: 613  Val set RMSE = 0.00689499
#
#
#  Epoch: 614  Val set RMSE = 0.00689304
#
#
#  Epoch: 615  Val set RMSE = 0.00689107
#
#
#  Epoch: 616  Val set RMSE = 0.00688915
#
#
#  Epoch: 617  Val set RMSE = 0.00688720
#
#
#  Epoch: 618  Val set RMSE = 0.00688524
#
#
#  Epoch: 619  Val set RMSE = 0.00688326
#
#
#  Epoch: 620  Val set RMSE = 0.00688131
#
#
#  Epoch: 621  Val set RMSE = 0.00687931
#
#
#  Epoch: 622  Val set RMSE = 0.00687737
#
#
#  Epoch: 623  Val set RMSE = 0.00687537
#
#
#  Epoch: 624  Val set RMSE = 0.00687338
#
#
#  Epoch: 625  Val set RMSE = 0.00687142
#
#
#  Epoch: 626  Val set RMSE = 0.00686941
#
#
#  Epoch: 627  Val set RMSE = 0.00686742
#
#
#  Epoch: 628  Val set RMSE = 0.00686541
#
#
#  Epoch: 629  Val set RMSE = 0.00686338
#
#
#  Epoch: 630  Val set RMSE = 0.00686137
#
#
#  Epoch: 631  Val set RMSE = 0.00685935
#
#
#  Epoch: 632  Val set RMSE = 0.00685736
#
#
#  Epoch: 633  Val set RMSE = 0.00685535
#
#
#  Epoch: 634  Val set RMSE = 0.00685330
#
#
#  Epoch: 635  Val set RMSE = 0.00685127
#
#
#  Epoch: 636  Val set RMSE = 0.00684925
#
#
#  Epoch: 637  Val set RMSE = 0.00684720
#
#
#  Epoch: 638  Val set RMSE = 0.00684516
#
#
#  Epoch: 639  Val set RMSE = 0.00684312
#
#
#  Epoch: 640  Val set RMSE = 0.00684106
#
#
#  Epoch: 641  Val set RMSE = 0.00683900
#
#
#  Epoch: 642  Val set RMSE = 0.00683698
#
#
#  Epoch: 643  Val set RMSE = 0.00683492
#
#
#  Epoch: 644  Val set RMSE = 0.00683284
#
#
#  Epoch: 645  Val set RMSE = 0.00683078
#
#
#  Epoch: 646  Val set RMSE = 0.00682874
#
#
#  Epoch: 647  Val set RMSE = 0.00682665
#
#
#  Epoch: 648  Val set RMSE = 0.00682458
#
#
#  Epoch: 649  Val set RMSE = 0.00682248
#
#
#  Epoch: 650  Val set RMSE = 0.00682045
#
#
#  Epoch: 651  Val set RMSE = 0.00681837
#
#
#  Epoch: 652  Val set RMSE = 0.00681628
#
#
#  Epoch: 653  Val set RMSE = 0.00681423
#
#
#  Epoch: 654  Val set RMSE = 0.00681212
#
#
#  Epoch: 655  Val set RMSE = 0.00681004
#
#
#  Epoch: 656  Val set RMSE = 0.00680793
#
#
#  Epoch: 657  Val set RMSE = 0.00680587
#
#
#  Epoch: 658  Val set RMSE = 0.00680375
#
#
#  Epoch: 659  Val set RMSE = 0.00680169
#
#
#  Epoch: 660  Val set RMSE = 0.00679960
#
#
#  Epoch: 661  Val set RMSE = 0.00679748
#
#
#  Epoch: 662  Val set RMSE = 0.00679538
#
#
#  Epoch: 663  Val set RMSE = 0.00679330
#
#
#  Epoch: 664  Val set RMSE = 0.00679123
#
#
#  Epoch: 665  Val set RMSE = 0.00678909
#
#
#  Epoch: 666  Val set RMSE = 0.00678700
#
#
#  Epoch: 667  Val set RMSE = 0.00678489
#
#
#  Epoch: 668  Val set RMSE = 0.00678278
#
#
#  Epoch: 669  Val set RMSE = 0.00678071
#
#
#  Epoch: 670  Val set RMSE = 0.00677859
#
#
#  Epoch: 671  Val set RMSE = 0.00677650
#
#
#  Epoch: 672  Val set RMSE = 0.00677441
#
#
#  Epoch: 673  Val set RMSE = 0.00677233
#
#
#  Epoch: 674  Val set RMSE = 0.00677021
#
#
#  Epoch: 675  Val set RMSE = 0.00676811
#
#
#  Epoch: 676  Val set RMSE = 0.00676603
#
#
#  Epoch: 677  Val set RMSE = 0.00676391
#
#
#  Epoch: 678  Val set RMSE = 0.00676182
#
#
#  Epoch: 679  Val set RMSE = 0.00675976
#
#
#  Epoch: 680  Val set RMSE = 0.00675764
#
#
#  Epoch: 681  Val set RMSE = 0.00675550
#
#
#  Epoch: 682  Val set RMSE = 0.00675346
#
#
#  Epoch: 683  Val set RMSE = 0.00675137
#
#
#  Epoch: 684  Val set RMSE = 0.00674928
#
#
#  Epoch: 685  Val set RMSE = 0.00674718
#
#
#  Epoch: 686  Val set RMSE = 0.00674510
#
#
#  Epoch: 687  Val set RMSE = 0.00674301
#
#
#  Epoch: 688  Val set RMSE = 0.00674097
#
#
#  Epoch: 689  Val set RMSE = 0.00673886
#
#
#  Epoch: 690  Val set RMSE = 0.00673681
#
#
#  Epoch: 691  Val set RMSE = 0.00673475
#
#
#  Epoch: 692  Val set RMSE = 0.00673268
#
#
#  Epoch: 693  Val set RMSE = 0.00673065
#
#
#  Epoch: 694  Val set RMSE = 0.00672857
#
#
#  Epoch: 695  Val set RMSE = 0.00672651
#
#
#  Epoch: 696  Val set RMSE = 0.00672449
#
#
#  Epoch: 697  Val set RMSE = 0.00672241
#
#
#  Epoch: 698  Val set RMSE = 0.00672040
#
#
#  Epoch: 699  Val set RMSE = 0.00671835
#
#
#  Epoch: 700  Val set RMSE = 0.00671635
#
#
#  Epoch: 701  Val set RMSE = 0.00671430
#
#
#  Epoch: 702  Val set RMSE = 0.00671229
#
#
#  Epoch: 703  Val set RMSE = 0.00671030
#
#
#  Epoch: 704  Val set RMSE = 0.00670826
#
#
#  Epoch: 705  Val set RMSE = 0.00670626
#
#
#  Epoch: 706  Val set RMSE = 0.00670431
#
#
#  Epoch: 707  Val set RMSE = 0.00670235
#
#
#  Epoch: 708  Val set RMSE = 0.00670033
#
#
#  Epoch: 709  Val set RMSE = 0.00669837
#
#
#  Epoch: 710  Val set RMSE = 0.00669643
#
#
#  Epoch: 711  Val set RMSE = 0.00669449
#
#
#  Epoch: 712  Val set RMSE = 0.00669251
#
#
#  Epoch: 713  Val set RMSE = 0.00669059
#
#
#  Epoch: 714  Val set RMSE = 0.00668864
#
#
#  Epoch: 715  Val set RMSE = 0.00668674
#
#
#  Epoch: 716  Val set RMSE = 0.00668483
#
#
#  Epoch: 717  Val set RMSE = 0.00668297
#
#
#  Epoch: 718  Val set RMSE = 0.00668108
#
#
#  Epoch: 719  Val set RMSE = 0.00667922
#
#
#  Epoch: 720  Val set RMSE = 0.00667734
#
#
#  Epoch: 721  Val set RMSE = 0.00667550
#
#
#  Epoch: 722  Val set RMSE = 0.00667367
#
#
#  Epoch: 723  Val set RMSE = 0.00667184
#
#
#  Epoch: 724  Val set RMSE = 0.00667003
#
#
#  Epoch: 725  Val set RMSE = 0.00666822
#
#
#  Epoch: 726  Val set RMSE = 0.00666643
#
#
#  Epoch: 727  Val set RMSE = 0.00666466
#
#
#  Epoch: 728  Val set RMSE = 0.00666290
#
#
#  Epoch: 729  Val set RMSE = 0.00666116
#
#
#  Epoch: 730  Val set RMSE = 0.00665943
#
#
#  Epoch: 731  Val set RMSE = 0.00665771
#
#
#  Epoch: 732  Val set RMSE = 0.00665599
#
#
#  Epoch: 733  Val set RMSE = 0.00665435
#
#
#  Epoch: 734  Val set RMSE = 0.00665269
#
#
#  Epoch: 735  Val set RMSE = 0.00665104
#
#
#  Epoch: 736  Val set RMSE = 0.00664938
#
#
#  Epoch: 737  Val set RMSE = 0.00664777
#
#
#  Epoch: 738  Val set RMSE = 0.00664619
#
#
#  Epoch: 739  Val set RMSE = 0.00664462
#
#
#  Epoch: 740  Val set RMSE = 0.00664306
#
#
#  Epoch: 741  Val set RMSE = 0.00664153
#
#
#  Epoch: 742  Val set RMSE = 0.00664001
#
#
#  Epoch: 743  Val set RMSE = 0.00663852
#
#
#  Epoch: 744  Val set RMSE = 0.00663705
#
#
#  Epoch: 745  Val set RMSE = 0.00663558
#
#
#  Epoch: 746  Val set RMSE = 0.00663414
#
#
#  Epoch: 747  Val set RMSE = 0.00663274
#
#
#  Epoch: 748  Val set RMSE = 0.00663134
#
#
#  Epoch: 749  Val set RMSE = 0.00662997
#
#
#  Epoch: 750  Val set RMSE = 0.00662863
#
#
#  Epoch: 751  Val set RMSE = 0.00662734
#
#
#  Epoch: 752  Val set RMSE = 0.00662607
#
#
#  Epoch: 753  Val set RMSE = 0.00662479
#
#
#  Epoch: 754  Val set RMSE = 0.00662356
#
#
#  Epoch: 755  Val set RMSE = 0.00662232
#
#
#  Epoch: 756  Val set RMSE = 0.00662115
#
#
#  Epoch: 757  Val set RMSE = 0.00661999
#
#
#  Epoch: 758  Val set RMSE = 0.00661883
#
#
#  Epoch: 759  Val set RMSE = 0.00661771
#
#
#  Epoch: 760  Val set RMSE = 0.00661661
#
#
#  Epoch: 761  Val set RMSE = 0.00661556
#
#
#  Epoch: 762  Val set RMSE = 0.00661450
#
#
#  Epoch: 763  Val set RMSE = 0.00661347
#
#
#  Epoch: 764  Val set RMSE = 0.00661248
#
#
#  Epoch: 765  Val set RMSE = 0.00661151
#
#
#  Epoch: 766  Val set RMSE = 0.00661054
#
#
#  Epoch: 767  Val set RMSE = 0.00660959
#
#
#  Epoch: 768  Val set RMSE = 0.00660862
#
#
#  Epoch: 769  Val set RMSE = 0.00660762
#
#
#  Epoch: 770  Val set RMSE = 0.00660662
#
#
#  Epoch: 771  Val set RMSE = 0.00660558
#
#
#  Epoch: 772  Val set RMSE = 0.00660459
#
#
#  Epoch: 773  Val set RMSE = 0.00660406
#
#
#  Epoch: 774  Val set RMSE = 0.00660454
#
#
#  Epoch: 775  Val set RMSE = 0.00660548
#
#
#  Epoch: 776  Val set RMSE = 0.00660636
#
#
#  Epoch: 777  Val set RMSE = 0.00660707
#
#
#  Epoch: 778  Val set RMSE = 0.00660771
#
#
#  Epoch: 779  Val set RMSE = 0.00660835
#
#
#  Epoch: 780  Val set RMSE = 0.00660906
#
#
#  Epoch: 781  Val set RMSE = 0.00660981
#
#
#  Epoch: 782  Val set RMSE = 0.00661062
#
# Stopping... Maximum number of validation failures exceeded
# Average time taken for a single epoch is 9.147392 seconds.
#
#  Test set RMSE = 0.01041110
#
# 0.00063194253
#
#  Epoch: 1  Val set RMSE = 0.11073292
#
#
#  Epoch: 2  Val set RMSE = 0.11060673
#
#
#  Epoch: 3  Val set RMSE = 0.11043361
#
#
#  Epoch: 4  Val set RMSE = 0.11013930
#
#
#  Epoch: 5  Val set RMSE = 0.10957124
#
#
#  Epoch: 6  Val set RMSE = 0.10871815
#
#
#  Epoch: 7  Val set RMSE = 0.10829020
#
#
#  Epoch: 8  Val set RMSE = 0.10811110
#
#
#  Epoch: 9  Val set RMSE = 0.10796127
#
#
#  Epoch: 10  Val set RMSE = 0.10775276
#
#
#  Epoch: 11  Val set RMSE = 0.10734445
#
#
#  Epoch: 12  Val set RMSE = 0.10629732
#
#
#  Epoch: 13  Val set RMSE = 0.10337398
#
#
#  Epoch: 14  Val set RMSE = 0.09235498
#
#
#  Epoch: 15  Val set RMSE = 0.07470654
#
#
#  Epoch: 16  Val set RMSE = 0.06522696
#
#
#  Epoch: 17  Val set RMSE = 0.05760218
#
#
#  Epoch: 18  Val set RMSE = 0.05103314
#
#
#  Epoch: 19  Val set RMSE = 0.04579835
#
#
#  Epoch: 20  Val set RMSE = 0.04179022
#
#
#  Epoch: 21  Val set RMSE = 0.03906754
#
#
#  Epoch: 22  Val set RMSE = 0.03757876
#
#
#  Epoch: 23  Val set RMSE = 0.03656952
#
#
#  Epoch: 24  Val set RMSE = 0.03545762
#
#
#  Epoch: 25  Val set RMSE = 0.03422478
#
#
#  Epoch: 26  Val set RMSE = 0.03288356
#
#
#  Epoch: 27  Val set RMSE = 0.03143953
#
#
#  Epoch: 28  Val set RMSE = 0.03005634
#
#
#  Epoch: 29  Val set RMSE = 0.02903562
#
#
#  Epoch: 30  Val set RMSE = 0.02841779
#
#
#  Epoch: 31  Val set RMSE = 0.02806826
#
#
#  Epoch: 32  Val set RMSE = 0.02783986
#
#
#  Epoch: 33  Val set RMSE = 0.02762588
#
#
#  Epoch: 34  Val set RMSE = 0.02737011
#
#
#  Epoch: 35  Val set RMSE = 0.02705549
#
#
#  Epoch: 36  Val set RMSE = 0.02668728
#
#
#  Epoch: 37  Val set RMSE = 0.02628446
#
#
#  Epoch: 38  Val set RMSE = 0.02587699
#
#
#  Epoch: 39  Val set RMSE = 0.02549662
#
#
#  Epoch: 40  Val set RMSE = 0.02516508
#
#
#  Epoch: 41  Val set RMSE = 0.02488855
#
#
#  Epoch: 42  Val set RMSE = 0.02466169
#
#
#  Epoch: 43  Val set RMSE = 0.02447362
#
#
#  Epoch: 44  Val set RMSE = 0.02431241
#
#
#  Epoch: 45  Val set RMSE = 0.02416785
#
#
#  Epoch: 46  Val set RMSE = 0.02403221
#
#
#  Epoch: 47  Val set RMSE = 0.02390014
#
#
#  Epoch: 48  Val set RMSE = 0.02376800
#
#
#  Epoch: 49  Val set RMSE = 0.02363340
#
#
#  Epoch: 50  Val set RMSE = 0.02349482
#
#
#  Epoch: 51  Val set RMSE = 0.02335147
#
#
#  Epoch: 52  Val set RMSE = 0.02320321
#
#
#  Epoch: 53  Val set RMSE = 0.02305065
#
#
#  Epoch: 54  Val set RMSE = 0.02289486
#
#
#  Epoch: 55  Val set RMSE = 0.02273738
#
#
#  Epoch: 56  Val set RMSE = 0.02257979
#
#
#  Epoch: 57  Val set RMSE = 0.02242354
#
#
#  Epoch: 58  Val set RMSE = 0.02226964
#
#
#  Epoch: 59  Val set RMSE = 0.02211892
#
#
#  Epoch: 60  Val set RMSE = 0.02197178
#
#
#  Epoch: 61  Val set RMSE = 0.02182840
#
#
#  Epoch: 62  Val set RMSE = 0.02168883
#
#
#  Epoch: 63  Val set RMSE = 0.02155299
#
#
#  Epoch: 64  Val set RMSE = 0.02142074
#
#
#  Epoch: 65  Val set RMSE = 0.02129191
#
#
#  Epoch: 66  Val set RMSE = 0.02116620
#
#
#  Epoch: 67  Val set RMSE = 0.02104325
#
#
#  Epoch: 68  Val set RMSE = 0.02092265
#
#
#  Epoch: 69  Val set RMSE = 0.02080382
#
#
#  Epoch: 70  Val set RMSE = 0.02068599
#
#
#  Epoch: 71  Val set RMSE = 0.02056844
#
#
#  Epoch: 72  Val set RMSE = 0.02045054
#
#
#  Epoch: 73  Val set RMSE = 0.02033194
#
#
#  Epoch: 74  Val set RMSE = 0.02021266
#
#
#  Epoch: 75  Val set RMSE = 0.02009315
#
#
#  Epoch: 76  Val set RMSE = 0.01997395
#
#
#  Epoch: 77  Val set RMSE = 0.01985570
#
#
#  Epoch: 78  Val set RMSE = 0.01973880
#
#
#  Epoch: 79  Val set RMSE = 0.01962366
#
#
#  Epoch: 80  Val set RMSE = 0.01951037
#
#
#  Epoch: 81  Val set RMSE = 0.01939897
#
#
#  Epoch: 82  Val set RMSE = 0.01928932
#
#
#  Epoch: 83  Val set RMSE = 0.01918153
#
#
#  Epoch: 84  Val set RMSE = 0.01907564
#
#
#  Epoch: 85  Val set RMSE = 0.01897167
#
#
#  Epoch: 86  Val set RMSE = 0.01886982
#
#
#  Epoch: 87  Val set RMSE = 0.01877036
#
#
#  Epoch: 88  Val set RMSE = 0.01867360
#
#
#  Epoch: 89  Val set RMSE = 0.01857984
#
#
#  Epoch: 90  Val set RMSE = 0.01848950
#
#
#  Epoch: 91  Val set RMSE = 0.01840308
#
#
#  Epoch: 92  Val set RMSE = 0.01832117
#
#
#  Epoch: 93  Val set RMSE = 0.01824422
#
#
#  Epoch: 94  Val set RMSE = 0.01817267
#
#
#  Epoch: 95  Val set RMSE = 0.01810646
#
#
#  Epoch: 96  Val set RMSE = 0.01804532
#
#
#  Epoch: 97  Val set RMSE = 0.01798866
#
#
#  Epoch: 98  Val set RMSE = 0.01793582
#
#
#  Epoch: 99  Val set RMSE = 0.01788640
#
#
#  Epoch: 100  Val set RMSE = 0.01783994
#
#
#  Epoch: 101  Val set RMSE = 0.01779618
#
#
#  Epoch: 102  Val set RMSE = 0.01775480
#
#
#  Epoch: 103  Val set RMSE = 0.01771564
#
#
#  Epoch: 104  Val set RMSE = 0.01767844
#
#
#  Epoch: 105  Val set RMSE = 0.01764299
#
#
#  Epoch: 106  Val set RMSE = 0.01760918
#
#
#  Epoch: 107  Val set RMSE = 0.01757684
#
#
#  Epoch: 108  Val set RMSE = 0.01754577
#
#
#  Epoch: 109  Val set RMSE = 0.01751591
#
#
#  Epoch: 110  Val set RMSE = 0.01748713
#
#
#  Epoch: 111  Val set RMSE = 0.01745932
#
#
#  Epoch: 112  Val set RMSE = 0.01743241
#
#
#  Epoch: 113  Val set RMSE = 0.01740629
#
#
#  Epoch: 114  Val set RMSE = 0.01738100
#
#
#  Epoch: 115  Val set RMSE = 0.01735641
#
#
#  Epoch: 116  Val set RMSE = 0.01733250
#
#
#  Epoch: 117  Val set RMSE = 0.01730927
#
#
#  Epoch: 118  Val set RMSE = 0.01728660
#
#
#  Epoch: 119  Val set RMSE = 0.01726455
#
#
#  Epoch: 120  Val set RMSE = 0.01724302
#
#
#  Epoch: 121  Val set RMSE = 0.01722202
#
#
#  Epoch: 122  Val set RMSE = 0.01720145
#
#
#  Epoch: 123  Val set RMSE = 0.01718137
#
#
#  Epoch: 124  Val set RMSE = 0.01716165
#
#
#  Epoch: 125  Val set RMSE = 0.01714228
#
#
#  Epoch: 126  Val set RMSE = 0.01712326
#
#
#  Epoch: 127  Val set RMSE = 0.01710448
#
#
#  Epoch: 128  Val set RMSE = 0.01708595
#
#
#  Epoch: 129  Val set RMSE = 0.01706758
#
#
#  Epoch: 130  Val set RMSE = 0.01704933
#
#
#  Epoch: 131  Val set RMSE = 0.01703116
#
#
#  Epoch: 132  Val set RMSE = 0.01701302
#
#
#  Epoch: 133  Val set RMSE = 0.01699490
#
#
#  Epoch: 134  Val set RMSE = 0.01697672
#
#
#  Epoch: 135  Val set RMSE = 0.01695852
#
#
#  Epoch: 136  Val set RMSE = 0.01694024
#
#
#  Epoch: 137  Val set RMSE = 0.01692184
#
#
#  Epoch: 138  Val set RMSE = 0.01690341
#
#
#  Epoch: 139  Val set RMSE = 0.01688483
#
#
#  Epoch: 140  Val set RMSE = 0.01686622
#
#
#  Epoch: 141  Val set RMSE = 0.01684758
#
#
#  Epoch: 142  Val set RMSE = 0.01682882
#
#
#  Epoch: 143  Val set RMSE = 0.01681011
#
#
#  Epoch: 144  Val set RMSE = 0.01679139
#
#
#  Epoch: 145  Val set RMSE = 0.01677268
#
#
#  Epoch: 146  Val set RMSE = 0.01675401
#
#
#  Epoch: 147  Val set RMSE = 0.01673541
#
#
#  Epoch: 148  Val set RMSE = 0.01671688
#
#
#  Epoch: 149  Val set RMSE = 0.01669846
#
#
#  Epoch: 150  Val set RMSE = 0.01668018
#
#
#  Epoch: 151  Val set RMSE = 0.01666197
#
#
#  Epoch: 152  Val set RMSE = 0.01664391
#
#
#  Epoch: 153  Val set RMSE = 0.01662593
#
#
#  Epoch: 154  Val set RMSE = 0.01660814
#
#
#  Epoch: 155  Val set RMSE = 0.01659046
#
#
#  Epoch: 156  Val set RMSE = 0.01657289
#
#
#  Epoch: 157  Val set RMSE = 0.01655545
#
#
#  Epoch: 158  Val set RMSE = 0.01653813
#
#
#  Epoch: 159  Val set RMSE = 0.01652090
#
#
#  Epoch: 160  Val set RMSE = 0.01650374
#
#
#  Epoch: 161  Val set RMSE = 0.01648672
#
#
#  Epoch: 162  Val set RMSE = 0.01646972
#
#
#  Epoch: 163  Val set RMSE = 0.01645272
#
#
#  Epoch: 164  Val set RMSE = 0.01643581
#
#
#  Epoch: 165  Val set RMSE = 0.01641892
#
#
#  Epoch: 166  Val set RMSE = 0.01640193
#
#
#  Epoch: 167  Val set RMSE = 0.01638499
#
#
#  Epoch: 168  Val set RMSE = 0.01636796
#
#
#  Epoch: 169  Val set RMSE = 0.01635090
#
#
#  Epoch: 170  Val set RMSE = 0.01633374
#
#
#  Epoch: 171  Val set RMSE = 0.01631654
#
#
#  Epoch: 172  Val set RMSE = 0.01629919
#
#
#  Epoch: 173  Val set RMSE = 0.01628179
#
#
#  Epoch: 174  Val set RMSE = 0.01626430
#
#
#  Epoch: 175  Val set RMSE = 0.01624669
#
#
#  Epoch: 176  Val set RMSE = 0.01622897
#
#
#  Epoch: 177  Val set RMSE = 0.01621120
#
#
#  Epoch: 178  Val set RMSE = 0.01619329
#
#
#  Epoch: 179  Val set RMSE = 0.01617527
#
#
#  Epoch: 180  Val set RMSE = 0.01615722
#
#
#  Epoch: 181  Val set RMSE = 0.01613914
#
#
#  Epoch: 182  Val set RMSE = 0.01612096
#
#
#  Epoch: 183  Val set RMSE = 0.01610280
#
#
#  Epoch: 184  Val set RMSE = 0.01608457
#
#
#  Epoch: 185  Val set RMSE = 0.01606640
#
#
#  Epoch: 186  Val set RMSE = 0.01604828
#
#
#  Epoch: 187  Val set RMSE = 0.01603013
#
#
#  Epoch: 188  Val set RMSE = 0.01601211
#
#
#  Epoch: 189  Val set RMSE = 0.01599419
#
#
#  Epoch: 190  Val set RMSE = 0.01597629
#
#
#  Epoch: 191  Val set RMSE = 0.01595859
#
#
#  Epoch: 192  Val set RMSE = 0.01594098
#
#
#  Epoch: 193  Val set RMSE = 0.01592356
#
#
#  Epoch: 194  Val set RMSE = 0.01590632
#
#
#  Epoch: 195  Val set RMSE = 0.01588925
#
#
#  Epoch: 196  Val set RMSE = 0.01587232
#
#
#  Epoch: 197  Val set RMSE = 0.01585562
#
#
#  Epoch: 198  Val set RMSE = 0.01583908
#
#
#  Epoch: 199  Val set RMSE = 0.01582272
#
#
#  Epoch: 200  Val set RMSE = 0.01580658
#
#
#  Epoch: 201  Val set RMSE = 0.01579057
#
#
#  Epoch: 202  Val set RMSE = 0.01577479
#
#
#  Epoch: 203  Val set RMSE = 0.01575915
#
#
#  Epoch: 204  Val set RMSE = 0.01574370
#
#
#  Epoch: 205  Val set RMSE = 0.01572836
#
#
#  Epoch: 206  Val set RMSE = 0.01571317
#
#
#  Epoch: 207  Val set RMSE = 0.01569811
#
#
#  Epoch: 208  Val set RMSE = 0.01568319
#
#
#  Epoch: 209  Val set RMSE = 0.01566835
#
#
#  Epoch: 210  Val set RMSE = 0.01565366
#
#
#  Epoch: 211  Val set RMSE = 0.01563903
#
#
#  Epoch: 212  Val set RMSE = 0.01562447
#
#
#  Epoch: 213  Val set RMSE = 0.01561003
#
#
#  Epoch: 214  Val set RMSE = 0.01559564
#
#
#  Epoch: 215  Val set RMSE = 0.01558129
#
#
#  Epoch: 216  Val set RMSE = 0.01556701
#
#
#  Epoch: 217  Val set RMSE = 0.01555277
#
#
#  Epoch: 218  Val set RMSE = 0.01553858
#
#
#  Epoch: 219  Val set RMSE = 0.01552444
#
#
#  Epoch: 220  Val set RMSE = 0.01551030
#
#
#  Epoch: 221  Val set RMSE = 0.01549622
#
#
#  Epoch: 222  Val set RMSE = 0.01548215
#
#
#  Epoch: 223  Val set RMSE = 0.01546812
#
#
#  Epoch: 224  Val set RMSE = 0.01545409
#
#
#  Epoch: 225  Val set RMSE = 0.01544011
#
#
#  Epoch: 226  Val set RMSE = 0.01542611
#
#
#  Epoch: 227  Val set RMSE = 0.01541214
#
#
#  Epoch: 228  Val set RMSE = 0.01539817
#
#
#  Epoch: 229  Val set RMSE = 0.01538420
#
#
#  Epoch: 230  Val set RMSE = 0.01537028
#
#
#  Epoch: 231  Val set RMSE = 0.01535626
#
#
#  Epoch: 232  Val set RMSE = 0.01534228
#
#
#  Epoch: 233  Val set RMSE = 0.01532836
#
#
#  Epoch: 234  Val set RMSE = 0.01531437
#
#
#  Epoch: 235  Val set RMSE = 0.01530043
#
#
#  Epoch: 236  Val set RMSE = 0.01528648
#
#
#  Epoch: 237  Val set RMSE = 0.01527248
#
#
#  Epoch: 238  Val set RMSE = 0.01525854
#
#
#  Epoch: 239  Val set RMSE = 0.01524457
#
#
#  Epoch: 240  Val set RMSE = 0.01523058
#
#
#  Epoch: 241  Val set RMSE = 0.01521664
#
#
#  Epoch: 242  Val set RMSE = 0.01520265
#
#
#  Epoch: 243  Val set RMSE = 0.01518865
#
#
#  Epoch: 244  Val set RMSE = 0.01517469
#
#
#  Epoch: 245  Val set RMSE = 0.01516071
#
#
#  Epoch: 246  Val set RMSE = 0.01514675
#
#
#  Epoch: 247  Val set RMSE = 0.01513278
#
#
#  Epoch: 248  Val set RMSE = 0.01511879
#
#
#  Epoch: 249  Val set RMSE = 0.01510484
#
#
#  Epoch: 250  Val set RMSE = 0.01509086
#
#
#  Epoch: 251  Val set RMSE = 0.01507693
#
#
#  Epoch: 252  Val set RMSE = 0.01506298
#
#
#  Epoch: 253  Val set RMSE = 0.01504905
#
#
#  Epoch: 254  Val set RMSE = 0.01503512
#
#
#  Epoch: 255  Val set RMSE = 0.01502120
#
#
#  Epoch: 256  Val set RMSE = 0.01500728
#
#
#  Epoch: 257  Val set RMSE = 0.01499342
#
#
#  Epoch: 258  Val set RMSE = 0.01497956
#
#
#  Epoch: 259  Val set RMSE = 0.01496571
#
#
#  Epoch: 260  Val set RMSE = 0.01495183
#
#
#  Epoch: 261  Val set RMSE = 0.01493808
#
#
#  Epoch: 262  Val set RMSE = 0.01492426
#
#
#  Epoch: 263  Val set RMSE = 0.01491047
#
#
#  Epoch: 264  Val set RMSE = 0.01489674
#
#
#  Epoch: 265  Val set RMSE = 0.01488300
#
#
#  Epoch: 266  Val set RMSE = 0.01486930
#
#
#  Epoch: 267  Val set RMSE = 0.01485564
#
#
#  Epoch: 268  Val set RMSE = 0.01484202
#
#
#  Epoch: 269  Val set RMSE = 0.01482839
#
#
#  Epoch: 270  Val set RMSE = 0.01481484
#
#
#  Epoch: 271  Val set RMSE = 0.01480130
#
#
#  Epoch: 272  Val set RMSE = 0.01478777
#
#
#  Epoch: 273  Val set RMSE = 0.01477430
#
#
#  Epoch: 274  Val set RMSE = 0.01476088
#
#
#  Epoch: 275  Val set RMSE = 0.01474746
#
#
#  Epoch: 276  Val set RMSE = 0.01473411
#
#
#  Epoch: 277  Val set RMSE = 0.01472078
#
#
#  Epoch: 278  Val set RMSE = 0.01470751
#
#
#  Epoch: 279  Val set RMSE = 0.01469429
#
#
#  Epoch: 280  Val set RMSE = 0.01468109
#
#
#  Epoch: 281  Val set RMSE = 0.01466794
#
#
#  Epoch: 282  Val set RMSE = 0.01465482
#
#
#  Epoch: 283  Val set RMSE = 0.01464175
#
#
#  Epoch: 284  Val set RMSE = 0.01462873
#
#
#  Epoch: 285  Val set RMSE = 0.01461575
#
#
#  Epoch: 286  Val set RMSE = 0.01460282
#
#
#  Epoch: 287  Val set RMSE = 0.01458994
#
#
#  Epoch: 288  Val set RMSE = 0.01457711
#
#
#  Epoch: 289  Val set RMSE = 0.01456431
#
#
#  Epoch: 290  Val set RMSE = 0.01455157
#
#
#  Epoch: 291  Val set RMSE = 0.01453888
#
#
#  Epoch: 292  Val set RMSE = 0.01452622
#
#
#  Epoch: 293  Val set RMSE = 0.01451363
#
#
#  Epoch: 294  Val set RMSE = 0.01450107
#
#
#  Epoch: 295  Val set RMSE = 0.01448857
#
#
#  Epoch: 296  Val set RMSE = 0.01447609
#
#
#  Epoch: 297  Val set RMSE = 0.01446370
#
#
#  Epoch: 298  Val set RMSE = 0.01445136
#
#
#  Epoch: 299  Val set RMSE = 0.01443906
#
#
#  Epoch: 300  Val set RMSE = 0.01442675
#
#
#  Epoch: 301  Val set RMSE = 0.01441451
#
#
#  Epoch: 302  Val set RMSE = 0.01440236
#
#
#  Epoch: 303  Val set RMSE = 0.01439023
#
#
#  Epoch: 304  Val set RMSE = 0.01437814
#
#
#  Epoch: 305  Val set RMSE = 0.01436610
#
#
#  Epoch: 306  Val set RMSE = 0.01435413
#
#
#  Epoch: 307  Val set RMSE = 0.01434217
#
#
#  Epoch: 308  Val set RMSE = 0.01433026
#
#
#  Epoch: 309  Val set RMSE = 0.01431840
#
#
#  Epoch: 310  Val set RMSE = 0.01430662
#
#
#  Epoch: 311  Val set RMSE = 0.01429478
#
#
#  Epoch: 312  Val set RMSE = 0.01428302
#
#
#  Epoch: 313  Val set RMSE = 0.01427134
#
#
#  Epoch: 314  Val set RMSE = 0.01425967
#
#
#  Epoch: 315  Val set RMSE = 0.01424804
#
#
#  Epoch: 316  Val set RMSE = 0.01423647
#
#
#  Epoch: 317  Val set RMSE = 0.01422490
#
#
#  Epoch: 318  Val set RMSE = 0.01421339
#
#
#  Epoch: 319  Val set RMSE = 0.01420195
#
#
#  Epoch: 320  Val set RMSE = 0.01419052
#
#
#  Epoch: 321  Val set RMSE = 0.01417910
#
#
#  Epoch: 322  Val set RMSE = 0.01416773
#
#
#  Epoch: 323  Val set RMSE = 0.01415637
#
#
#  Epoch: 324  Val set RMSE = 0.01414508
#
#
#  Epoch: 325  Val set RMSE = 0.01413378
#
#
#  Epoch: 326  Val set RMSE = 0.01412257
#
#
#  Epoch: 327  Val set RMSE = 0.01411137
#
#
#  Epoch: 328  Val set RMSE = 0.01410020
#
#
#  Epoch: 329  Val set RMSE = 0.01408910
#
#
#  Epoch: 330  Val set RMSE = 0.01407799
#
#
#  Epoch: 331  Val set RMSE = 0.01406693
#
#
#  Epoch: 332  Val set RMSE = 0.01405588
#
#
#  Epoch: 333  Val set RMSE = 0.01404491
#
#
#  Epoch: 334  Val set RMSE = 0.01403397
#
#
#  Epoch: 335  Val set RMSE = 0.01402308
#
#
#  Epoch: 336  Val set RMSE = 0.01401218
#
#
#  Epoch: 337  Val set RMSE = 0.01400135
#
#
#  Epoch: 338  Val set RMSE = 0.01399055
#
#
#  Epoch: 339  Val set RMSE = 0.01397985
#
#
#  Epoch: 340  Val set RMSE = 0.01396915
#
#
#  Epoch: 341  Val set RMSE = 0.01395852
#
#
#  Epoch: 342  Val set RMSE = 0.01394794
#
#
#  Epoch: 343  Val set RMSE = 0.01393743
#
#
#  Epoch: 344  Val set RMSE = 0.01392694
#
#
#  Epoch: 345  Val set RMSE = 0.01391658
#
#
#  Epoch: 346  Val set RMSE = 0.01390620
#
#
#  Epoch: 347  Val set RMSE = 0.01389591
#
#
#  Epoch: 348  Val set RMSE = 0.01388572
#
#
#  Epoch: 349  Val set RMSE = 0.01387557
#
#
#  Epoch: 350  Val set RMSE = 0.01386549
#
#
#  Epoch: 351  Val set RMSE = 0.01385552
#
#
#  Epoch: 352  Val set RMSE = 0.01384558
#
#
#  Epoch: 353  Val set RMSE = 0.01383573
#
#
#  Epoch: 354  Val set RMSE = 0.01382597
#
#
#  Epoch: 355  Val set RMSE = 0.01381624
#
#
#  Epoch: 356  Val set RMSE = 0.01380663
#
#
#  Epoch: 357  Val set RMSE = 0.01379702
#
#
#  Epoch: 358  Val set RMSE = 0.01378750
#
#
#  Epoch: 359  Val set RMSE = 0.01377813
#
#
#  Epoch: 360  Val set RMSE = 0.01376875
#
#
#  Epoch: 361  Val set RMSE = 0.01375947
#
#
#  Epoch: 362  Val set RMSE = 0.01375020
#
#
# ...
#
#
#  Epoch: 622  Val set RMSE = 0.50027438
#
#
#  Epoch: 623  Val set RMSE = 0.50027423
#
#
#  Epoch: 624  Val set RMSE = 0.50027409
#
#
#  Epoch: 625  Val set RMSE = 0.50027394
#
#
#  Epoch: 626  Val set RMSE = 0.50027380
#
#
#  Epoch: 627  Val set RMSE = 0.50027366
#
#
#  Epoch: 628  Val set RMSE = 0.50027352
#
#
#  Epoch: 629  Val set RMSE = 0.50027338
#
#
#  Epoch: 630  Val set RMSE = 0.50027324
#
#
#  Epoch: 631  Val set RMSE = 0.50027310
#
#
#  Epoch: 632  Val set RMSE = 0.50027296
#
#
#  Epoch: 633  Val set RMSE = 0.50027282
#
#
#  Epoch: 634  Val set RMSE = 0.50027268
#
#
#  Epoch: 635  Val set RMSE = 0.50027255
#
#
#  Epoch: 636  Val set RMSE = 0.50027241
#
#
#  Epoch: 637  Val set RMSE = 0.50027227
#
#
#  Epoch: 638  Val set RMSE = 0.50027213
#
#
#  Epoch: 639  Val set RMSE = 0.50027199
#
#
#  Epoch: 640  Val set RMSE = 0.50027185
#
#
#  Epoch: 641  Val set RMSE = 0.50027171
#
#
#  Epoch: 642  Val set RMSE = 0.50027157
#
#
#  Epoch: 643  Val set RMSE = 0.50027143
#
#
#  Epoch: 644  Val set RMSE = 0.50027129
#
#
#  Epoch: 645  Val set RMSE = 0.50027115
#
#
#  Epoch: 646  Val set RMSE = 0.50027102
#
#
#  Epoch: 647  Val set RMSE = 0.50027088
#
#
#  Epoch: 648  Val set RMSE = 0.50027074
#
#
#  Epoch: 649  Val set RMSE = 0.50027060
#
#
#  Epoch: 650  Val set RMSE = 0.50027047
#
#
#  Epoch: 651  Val set RMSE = 0.50027033
#
#
#  Epoch: 652  Val set RMSE = 0.50027020
#
#
#  Epoch: 653  Val set RMSE = 0.50027006
#
#
#  Epoch: 654  Val set RMSE = 0.50026993
#
#
#  Epoch: 655  Val set RMSE = 0.50026979
#
#
#  Epoch: 656  Val set RMSE = 0.50026966
#
#
#  Epoch: 657  Val set RMSE = 0.50026953
#
#
#  Epoch: 658  Val set RMSE = 0.50026939
#
#
#  Epoch: 659  Val set RMSE = 0.50026926
#
#
#  Epoch: 660  Val set RMSE = 0.50026912
#
#
#  Epoch: 661  Val set RMSE = 0.50026899
#
#
#  Epoch: 662  Val set RMSE = 0.50026886
#
#
#  Epoch: 663  Val set RMSE = 0.50026872
#
#
#  Epoch: 664  Val set RMSE = 0.50026859
#
#
#  Epoch: 665  Val set RMSE = 0.50026846
#
#
#  Epoch: 666  Val set RMSE = 0.50026832
#
#
#  Epoch: 667  Val set RMSE = 0.50026819
#
#
#  Epoch: 668  Val set RMSE = 0.50026806
#
#
#  Epoch: 669  Val set RMSE = 0.50026793
#
#
#  Epoch: 670  Val set RMSE = 0.50026779
#
#
#  Epoch: 671  Val set RMSE = 0.50026766
#
#
#  Epoch: 672  Val set RMSE = 0.50026753
#
#
#  Epoch: 673  Val set RMSE = 0.50026740
#
#
#  Epoch: 674  Val set RMSE = 0.50026727
#
#
#  Epoch: 675  Val set RMSE = 0.50026714
#
#
#  Epoch: 676  Val set RMSE = 0.50026701
#
#
#  Epoch: 677  Val set RMSE = 0.50026688
#
#
#  Epoch: 678  Val set RMSE = 0.50026675
#
#
#  Epoch: 679  Val set RMSE = 0.50026662
#
#
#  Epoch: 680  Val set RMSE = 0.50026649
#
#
#  Epoch: 681  Val set RMSE = 0.50026636
#
#
#  Epoch: 682  Val set RMSE = 0.50026623
#
#
#  Epoch: 683  Val set RMSE = 0.50026610
#
#
#  Epoch: 684  Val set RMSE = 0.50026597
#
#
#  Epoch: 685  Val set RMSE = 0.50026584
#
#
#  Epoch: 686  Val set RMSE = 0.50026571
#
#
#  Epoch: 687  Val set RMSE = 0.50026559
#
#
#  Epoch: 688  Val set RMSE = 0.50026546
#
#
#  Epoch: 689  Val set RMSE = 0.50026533
#
#
#  Epoch: 690  Val set RMSE = 0.50026520
#
#
#  Epoch: 691  Val set RMSE = 0.50026507
#
#
#  Epoch: 692  Val set RMSE = 0.50026494
#
#
#  Epoch: 693  Val set RMSE = 0.50026482
#
#
#  Epoch: 694  Val set RMSE = 0.50026469
#
#
#  Epoch: 695  Val set RMSE = 0.50026456
#
#
#  Epoch: 696  Val set RMSE = 0.50026444
#
#
#  Epoch: 697  Val set RMSE = 0.50026431
#
#
#  Epoch: 698  Val set RMSE = 0.50026418
#
#
#  Epoch: 699  Val set RMSE = 0.50026406
#
#
#  Epoch: 700  Val set RMSE = 0.50026393
#
#
#  Epoch: 701  Val set RMSE = 0.50026380
#
#
#  Epoch: 702  Val set RMSE = 0.50026367
#
#
#  Epoch: 703  Val set RMSE = 0.50026355
#
#
#  Epoch: 704  Val set RMSE = 0.50026343
#
#
#  Epoch: 705  Val set RMSE = 0.50026330
#
#
#  Epoch: 706  Val set RMSE = 0.50026317
#
#
#  Epoch: 707  Val set RMSE = 0.50026305
#
#
#  Epoch: 708  Val set RMSE = 0.50026292
#
#
#  Epoch: 709  Val set RMSE = 0.50026280
#
#
#  Epoch: 710  Val set RMSE = 0.50026267
#
#
#  Epoch: 711  Val set RMSE = 0.50026254
#
#
#  Epoch: 712  Val set RMSE = 0.50026242
#
#
#  Epoch: 713  Val set RMSE = 0.50026230
#
#
#  Epoch: 714  Val set RMSE = 0.50026217
#
#
#  Epoch: 715  Val set RMSE = 0.50026204
#
#
#  Epoch: 716  Val set RMSE = 0.50026192
#
#
#  Epoch: 717  Val set RMSE = 0.50026179
#
#
#  Epoch: 718  Val set RMSE = 0.50026168
#
#
#  Epoch: 719  Val set RMSE = 0.50026155
#
#
#  Epoch: 720  Val set RMSE = 0.50026143
#
#
#  Epoch: 721  Val set RMSE = 0.50026131
#
#
#  Epoch: 722  Val set RMSE = 0.50026118
#
#
#  Epoch: 723  Val set RMSE = 0.50026105
#
#
#  Epoch: 724  Val set RMSE = 0.50026093
#
#
#  Epoch: 725  Val set RMSE = 0.50026081
#
#
#  Epoch: 726  Val set RMSE = 0.50026068
#
#
#  Epoch: 727  Val set RMSE = 0.50026056
#
#
#  Epoch: 728  Val set RMSE = 0.50026044
#
#
#  Epoch: 729  Val set RMSE = 0.50026032
#
#
#  Epoch: 730  Val set RMSE = 0.50026019
#
#
#  Epoch: 731  Val set RMSE = 0.50026007
#
#
#  Epoch: 732  Val set RMSE = 0.50025995
#
#
#  Epoch: 733  Val set RMSE = 0.50025982
#
#
#  Epoch: 734  Val set RMSE = 0.50025970
#
#
#  Epoch: 735  Val set RMSE = 0.50025958
#
#
#  Epoch: 736  Val set RMSE = 0.50025946
#
#
#  Epoch: 737  Val set RMSE = 0.50025934
#
#
#  Epoch: 738  Val set RMSE = 0.50025921
#
#
#  Epoch: 739  Val set RMSE = 0.50025909
#
#
#  Epoch: 740  Val set RMSE = 0.50025897
#
#
#  Epoch: 741  Val set RMSE = 0.50025885
#
#
#  Epoch: 742  Val set RMSE = 0.50025873
#
#
#  Epoch: 743  Val set RMSE = 0.50025860
#
#
#  Epoch: 744  Val set RMSE = 0.50025848
#
#
#  Epoch: 745  Val set RMSE = 0.50025837
#
#
#  Epoch: 746  Val set RMSE = 0.50025824
#
#
#  Epoch: 747  Val set RMSE = 0.50025812
#
#
#  Epoch: 748  Val set RMSE = 0.50025800
#
#
#  Epoch: 749  Val set RMSE = 0.50025788
#
#
#  Epoch: 750  Val set RMSE = 0.50025776
#
#
#  Epoch: 751  Val set RMSE = 0.50025764
#
#
#  Epoch: 752  Val set RMSE = 0.50025751
#
#
#  Epoch: 753  Val set RMSE = 0.50025740
#
#
#  Epoch: 754  Val set RMSE = 0.50025727
#
#
#  Epoch: 755  Val set RMSE = 0.50025715
#
#
#  Epoch: 756  Val set RMSE = 0.50025704
#
#
#  Epoch: 757  Val set RMSE = 0.50025692
#
#
#  Epoch: 758  Val set RMSE = 0.50025679
#
#
#  Epoch: 759  Val set RMSE = 0.50025668
#
#
#  Epoch: 760  Val set RMSE = 0.50025656
#
#
#  Epoch: 761  Val set RMSE = 0.50025643
#
#
#  Epoch: 762  Val set RMSE = 0.50025631
#
#
#  Epoch: 763  Val set RMSE = 0.50025619
#
#
#  Epoch: 764  Val set RMSE = 0.50025607
#
#
#  Epoch: 765  Val set RMSE = 0.50025595
#
#
#  Epoch: 766  Val set RMSE = 0.50025584
#
#
#  Epoch: 767  Val set RMSE = 0.50025572
#
#
#  Epoch: 768  Val set RMSE = 0.50025560
#
#
#  Epoch: 769  Val set RMSE = 0.50025548
#
#
#  Epoch: 770  Val set RMSE = 0.50025536
#
#
#  Epoch: 771  Val set RMSE = 0.50025524
#
#
#  Epoch: 772  Val set RMSE = 0.50025512
#
#
#  Epoch: 773  Val set RMSE = 0.50025500
#
#
#  Epoch: 774  Val set RMSE = 0.50025488
#
#
#  Epoch: 775  Val set RMSE = 0.50025476
#
#
#  Epoch: 776  Val set RMSE = 0.50025464
#
#
#  Epoch: 777  Val set RMSE = 0.50025452
#
#
#  Epoch: 778  Val set RMSE = 0.50025440
#
#
#  Epoch: 779  Val set RMSE = 0.50025429
#
#
#  Epoch: 780  Val set RMSE = 0.50025417
#
#
#  Epoch: 781  Val set RMSE = 0.50025405
#
#
#  Epoch: 782  Val set RMSE = 0.50025393
#
#
#  Epoch: 783  Val set RMSE = 0.50025381
#
#
#  Epoch: 784  Val set RMSE = 0.50025370
#
#
#  Epoch: 785  Val set RMSE = 0.50025358
#
#
#  Epoch: 786  Val set RMSE = 0.50025346
#
#
#  Epoch: 787  Val set RMSE = 0.50025334
#
#
#  Epoch: 788  Val set RMSE = 0.50025323
#
#
#  Epoch: 789  Val set RMSE = 0.50025311
#
#
#  Epoch: 790  Val set RMSE = 0.50025299
#
#
#  Epoch: 791  Val set RMSE = 0.50025287
#
#
#  Epoch: 792  Val set RMSE = 0.50025275
#
#
#  Epoch: 793  Val set RMSE = 0.50025264
#
#
#  Epoch: 794  Val set RMSE = 0.50025252
#
#
#  Epoch: 795  Val set RMSE = 0.50025240
#
#
#  Epoch: 796  Val set RMSE = 0.50025228
#
#
#  Epoch: 797  Val set RMSE = 0.50025217
#
#
#  Epoch: 798  Val set RMSE = 0.50025205
#
#
#  Epoch: 799  Val set RMSE = 0.50025193
#
#
#  Epoch: 800  Val set RMSE = 0.50025182
#
#
#  Epoch: 801  Val set RMSE = 0.50025170
#
#
#  Epoch: 802  Val set RMSE = 0.50025158
#
#
#  Epoch: 803  Val set RMSE = 0.50025146
#
#
#  Epoch: 804  Val set RMSE = 0.50025135
#
#
#  Epoch: 805  Val set RMSE = 0.50025123
#
#
#  Epoch: 806  Val set RMSE = 0.50025111
#
#
#  Epoch: 807  Val set RMSE = 0.50025099
#
#
#  Epoch: 808  Val set RMSE = 0.50025088
#
#
#  Epoch: 809  Val set RMSE = 0.50025076
#
#
#  Epoch: 810  Val set RMSE = 0.50025064
#
#
#  Epoch: 811  Val set RMSE = 0.50025052
#
#
#  Epoch: 812  Val set RMSE = 0.50025041
#
#
#  Epoch: 813  Val set RMSE = 0.50025029
#
#
#  Epoch: 814  Val set RMSE = 0.50025017
#
#
#  Epoch: 815  Val set RMSE = 0.50025006
#
#
#  Epoch: 816  Val set RMSE = 0.50024995
#
#
#  Epoch: 817  Val set RMSE = 0.50024983
#
#
#  Epoch: 818  Val set RMSE = 0.50024971
#
#
#  Epoch: 819  Val set RMSE = 0.50024960
#
#
#  Epoch: 820  Val set RMSE = 0.50024948
#
#
#  Epoch: 821  Val set RMSE = 0.50024936
#
#
#  Epoch: 822  Val set RMSE = 0.50024925
#
#
#  Epoch: 823  Val set RMSE = 0.50024913
#
#
#  Epoch: 824  Val set RMSE = 0.50024901
#
#
#  Epoch: 825  Val set RMSE = 0.50024890
#
#
#  Epoch: 826  Val set RMSE = 0.50024878
#
#
#  Epoch: 827  Val set RMSE = 0.50024867
#
#
#  Epoch: 828  Val set RMSE = 0.50024855
#
#
#  Epoch: 829  Val set RMSE = 0.50024844
#
#
#  Epoch: 830  Val set RMSE = 0.50024832
#
#
#  Epoch: 831  Val set RMSE = 0.50024821
#
#
#  Epoch: 832  Val set RMSE = 0.50024809
#
#
#  Epoch: 833  Val set RMSE = 0.50024797
#
#
#  Epoch: 834  Val set RMSE = 0.50024786
#
#
#  Epoch: 835  Val set RMSE = 0.50024774
#
#
#  Epoch: 836  Val set RMSE = 0.50024763
#
#
#  Epoch: 837  Val set RMSE = 0.50024751
#
#
#  Epoch: 838  Val set RMSE = 0.50024740
#
#
#  Epoch: 839  Val set RMSE = 0.50024728
#
#
#  Epoch: 840  Val set RMSE = 0.50024717
#
#
#  Epoch: 841  Val set RMSE = 0.50024705
#
#
#  Epoch: 842  Val set RMSE = 0.50024694
#
#
#  Epoch: 843  Val set RMSE = 0.50024682
#
#
#  Epoch: 844  Val set RMSE = 0.50024671
#
#
#  Epoch: 845  Val set RMSE = 0.50024659
#
#
#  Epoch: 846  Val set RMSE = 0.50024647
#
#
#  Epoch: 847  Val set RMSE = 0.50024636
#
#
#  Epoch: 848  Val set RMSE = 0.50024625
#
#
#  Epoch: 849  Val set RMSE = 0.50024613
#
#
#  Epoch: 850  Val set RMSE = 0.50024602
#
#
#  Epoch: 851  Val set RMSE = 0.50024590
#
#
#  Epoch: 852  Val set RMSE = 0.50024579
#
#
#  Epoch: 853  Val set RMSE = 0.50024568
#
#
#  Epoch: 854  Val set RMSE = 0.50024556
#
#
#  Epoch: 855  Val set RMSE = 0.50024545
#
#
#  Epoch: 856  Val set RMSE = 0.50024533
#
#
#  Epoch: 857  Val set RMSE = 0.50024522
#
#
#  Epoch: 858  Val set RMSE = 0.50024510
#
#
#  Epoch: 859  Val set RMSE = 0.50024499
#
#
#  Epoch: 860  Val set RMSE = 0.50024488
#
#
#  Epoch: 861  Val set RMSE = 0.50024476
#
#
#  Epoch: 862  Val set RMSE = 0.50024465
#
#
#  Epoch: 863  Val set RMSE = 0.50024453
#
#
#  Epoch: 864  Val set RMSE = 0.50024442
#
#
#  Epoch: 865  Val set RMSE = 0.50024430
#
#
#  Epoch: 866  Val set RMSE = 0.50024419
#
#
#  Epoch: 867  Val set RMSE = 0.50024408
#
#
#  Epoch: 868  Val set RMSE = 0.50024397
#
#
#  Epoch: 869  Val set RMSE = 0.50024386
#
#
#  Epoch: 870  Val set RMSE = 0.50024374
#
#
#  Epoch: 871  Val set RMSE = 0.50024362
#
#
#  Epoch: 872  Val set RMSE = 0.50024351
#
#
#  Epoch: 873  Val set RMSE = 0.50024340
#
#
#  Epoch: 874  Val set RMSE = 0.50024329
#
#
#  Epoch: 875  Val set RMSE = 0.50024317
#
#
#  Epoch: 876  Val set RMSE = 0.50024306
#
#
#  Epoch: 877  Val set RMSE = 0.50024294
#
#
#  Epoch: 878  Val set RMSE = 0.50024283
#
#
#  Epoch: 879  Val set RMSE = 0.50024271
#
#
#  Epoch: 880  Val set RMSE = 0.50024260
#
#
#  Epoch: 881  Val set RMSE = 0.50024249
#
#
#  Epoch: 882  Val set RMSE = 0.50024237
#
#
#  Epoch: 883  Val set RMSE = 0.50024226
#
#
#  Epoch: 884  Val set RMSE = 0.50024215
#
#
#  Epoch: 885  Val set RMSE = 0.50024203
#
#
#  Epoch: 886  Val set RMSE = 0.50024192
#
#
#  Epoch: 887  Val set RMSE = 0.50024181
#
#
#  Epoch: 888  Val set RMSE = 0.50024170
#
#
#  Epoch: 889  Val set RMSE = 0.50024158
#
#
#  Epoch: 890  Val set RMSE = 0.50024147
#
#
#  Epoch: 891  Val set RMSE = 0.50024136
#
#
#  Epoch: 892  Val set RMSE = 0.50024124
#
#
#  Epoch: 893  Val set RMSE = 0.50024113
#
#
#  Epoch: 894  Val set RMSE = 0.50024102
#
#
#  Epoch: 895  Val set RMSE = 0.50024091
#
#
#  Epoch: 896  Val set RMSE = 0.50024079
#
#
#  Epoch: 897  Val set RMSE = 0.50024068
#
#
#  Epoch: 898  Val set RMSE = 0.50024057
#
#
#  Epoch: 899  Val set RMSE = 0.50024045
#
#
#  Epoch: 900  Val set RMSE = 0.50024034
#
#
#  Epoch: 901  Val set RMSE = 0.50024023
#
#
#  Epoch: 902  Val set RMSE = 0.50024013
#
#
#  Epoch: 903  Val set RMSE = 0.50024001
#
#
#  Epoch: 904  Val set RMSE = 0.50023988
#
#
#  Epoch: 905  Val set RMSE = 0.50023977
#
#
#  Epoch: 906  Val set RMSE = 0.50023966
#
#
#  Epoch: 907  Val set RMSE = 0.50023954
#
#
#  Epoch: 908  Val set RMSE = 0.50023944
#
#
#  Epoch: 909  Val set RMSE = 0.50023933
#
#
#  Epoch: 910  Val set RMSE = 0.50023933
#
#
#  Epoch: 911  Val set RMSE = 0.50023912
#
#
#  Epoch: 912  Val set RMSE = 0.50023898
#
#
#  Epoch: 913  Val set RMSE = 0.50023885
#
#
#  Epoch: 914  Val set RMSE = 0.50023874
#
#
#  Epoch: 915  Val set RMSE = 0.50023863
#
#
#  Epoch: 916  Val set RMSE = 0.50023852
#
#
#  Epoch: 917  Val set RMSE = 0.50023844
#
#
#  Epoch: 918  Val set RMSE = 0.50023835
#
#
#  Epoch: 919  Val set RMSE = 0.50023822
#
#
#  Epoch: 920  Val set RMSE = 0.50023809
#
#
#  Epoch: 921  Val set RMSE = 0.50023796
#
#
#  Epoch: 922  Val set RMSE = 0.50023784
#
#
#  Epoch: 923  Val set RMSE = 0.50023773
#
#
#  Epoch: 924  Val set RMSE = 0.50023765
#
#
#  Epoch: 925  Val set RMSE = 0.50023755
#
#
#  Epoch: 926  Val set RMSE = 0.50023743
#
#
#  Epoch: 927  Val set RMSE = 0.50023730
#
#
#  Epoch: 928  Val set RMSE = 0.50023718
#
#
#  Epoch: 929  Val set RMSE = 0.50023706
#
#
#  Epoch: 930  Val set RMSE = 0.50023695
#
#
#  Epoch: 931  Val set RMSE = 0.50023689
#
#
#  Epoch: 932  Val set RMSE = 0.50023678
#
#
#  Epoch: 933  Val set RMSE = 0.50023664
#
#
#  Epoch: 934  Val set RMSE = 0.50023651
#
#
#  Epoch: 935  Val set RMSE = 0.50023638
#
#
#  Epoch: 936  Val set RMSE = 0.50023627
#
#
#  Epoch: 937  Val set RMSE = 0.50023616
#
#
#  Epoch: 938  Val set RMSE = 0.50023609
#
#
#  Epoch: 939  Val set RMSE = 0.50023598
#
#
#  Epoch: 940  Val set RMSE = 0.50023586
#
#
#  Epoch: 941  Val set RMSE = 0.50023573
#
#
#  Epoch: 942  Val set RMSE = 0.50023561
#
#
#  Epoch: 943  Val set RMSE = 0.50023549
#
#
#  Epoch: 944  Val set RMSE = 0.50023539
#
#
#  Epoch: 945  Val set RMSE = 0.50023533
#
#
#  Epoch: 946  Val set RMSE = 0.50023520
#
#
#  Epoch: 947  Val set RMSE = 0.50023506
#
#
#  Epoch: 948  Val set RMSE = 0.50023494
#
#
#  Epoch: 949  Val set RMSE = 0.50023482
#
#
#  Epoch: 950  Val set RMSE = 0.50023471
#
#
#  Epoch: 951  Val set RMSE = 0.50023462
#
#
#  Epoch: 952  Val set RMSE = 0.50023454
#
#
#  Epoch: 953  Val set RMSE = 0.50023441
#
#
#  Epoch: 954  Val set RMSE = 0.50023428
#
#
#  Epoch: 955  Val set RMSE = 0.50023416
#
#
#  Epoch: 956  Val set RMSE = 0.50023404
#
#
#  Epoch: 957  Val set RMSE = 0.50023393
#
#
#  Epoch: 958  Val set RMSE = 0.50023387
#
#
#  Epoch: 959  Val set RMSE = 0.50023375
#
#
#  Epoch: 960  Val set RMSE = 0.50023362
#
#
#  Epoch: 961  Val set RMSE = 0.50023350
#
#
#  Epoch: 962  Val set RMSE = 0.50023337
#
#
#  Epoch: 963  Val set RMSE = 0.50023326
#
#
#  Epoch: 964  Val set RMSE = 0.50023316
#
#
#  Epoch: 965  Val set RMSE = 0.50023309
#
#
#  Epoch: 966  Val set RMSE = 0.50023297
#
#
#  Epoch: 967  Val set RMSE = 0.50023284
#
#
#  Epoch: 968  Val set RMSE = 0.50023271
#
#
#  Epoch: 969  Val set RMSE = 0.50023259
#
#
#  Epoch: 970  Val set RMSE = 0.50023248
#
#
#  Epoch: 971  Val set RMSE = 0.50023241
#
#
#  Epoch: 972  Val set RMSE = 0.50023231
#
#
#  Epoch: 973  Val set RMSE = 0.50023218
#
#
#  Epoch: 974  Val set RMSE = 0.50023206
#
#
#  Epoch: 975  Val set RMSE = 0.50023194
#
#
#  Epoch: 976  Val set RMSE = 0.50023181
#
#
#  Epoch: 977  Val set RMSE = 0.50023171
#
#
#  Epoch: 978  Val set RMSE = 0.50023165
#
#
#  Epoch: 979  Val set RMSE = 0.50023153
#
#
#  Epoch: 980  Val set RMSE = 0.50023140
#
#
#  Epoch: 981  Val set RMSE = 0.50023127
#
#
#  Epoch: 982  Val set RMSE = 0.50023115
#
#
#  Epoch: 983  Val set RMSE = 0.50023104
#
#
#  Epoch: 984  Val set RMSE = 0.50023096
#
#
#  Epoch: 985  Val set RMSE = 0.50023087
#
#
#  Epoch: 986  Val set RMSE = 0.50023074
#
#
#  Epoch: 987  Val set RMSE = 0.50023062
#
#
#  Epoch: 988  Val set RMSE = 0.50023049
#
#
#  Epoch: 989  Val set RMSE = 0.50023037
#
#
#  Epoch: 990  Val set RMSE = 0.50023027
#
#
#  Epoch: 991  Val set RMSE = 0.50023021
#
#
#  Epoch: 992  Val set RMSE = 0.50023009
#
#
#  Epoch: 993  Val set RMSE = 0.50022996
#
#
#  Epoch: 994  Val set RMSE = 0.50022984
#
#
#  Epoch: 995  Val set RMSE = 0.50022972
#
#
#  Epoch: 996  Val set RMSE = 0.50022961
#
#
#  Epoch: 997  Val set RMSE = 0.50022952
#
#
#  Epoch: 998  Val set RMSE = 0.50022944
#
#
#  Epoch: 999  Val set RMSE = 0.50022931
#
# Average time taken for a single epoch is 7.893594 seconds.
#
#  Test set RMSE = 0.02255052
#
# 0.0013687924
