# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Aug 29 15:39:51 2023

This script trains PINN model for TDSF supplied by AFTAC-CRADA
Inputs: yield (w), depth (h), time (t)
Output: displacement (S)

@author: shhong
"""

#%% Load Moduels

import os
root = os.path.abspath('')
# root = '/home/ubuntu/tdsf'

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import scipy.io as sio
import matplotlib.pyplot as plt

from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from timeit import default_timer as timer
from sklearn.preprocessing import MinMaxScaler

# from sklearn.metrics import confusion_matrix
# from sklearn.preprocessing import OneHotEncoder

# device = torch.device('cuda:0')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

study = 'noise_study_ood'
#%% Load Data

# path = 'E:\Hong\Research Projects\PINN\Data'
path = f'{root}/data'

filename = 'tdsf_002_train.pickle'
df_train_all = pd.read_pickle(path + '/' + filename)

filename = 'tdsf_002_val.pickle'
df_test_all = pd.read_pickle(path + '/' + filename)

df_data_all = pd.concat([df_train_all, df_test_all], axis=0)


#%% Select Material

# [Tuff-Rhyolite, Granite, Shale, Salt, Wet-Granite, Wet-Tuff]

name_prefix = '_FAR.'
name_material = 'Tuff-Rhyolite'

df_data = df_data_all[df_data_all['material'] == name_prefix + name_material]
df_data = df_data.reset_index(drop=True)

# splits df into train and test by yield and depth quantiles
qnts = [.1, .9]
ylds, dpths = df_data.YIELD.quantile(qnts, interpolation='nearest'), df_data.DEPTH.quantile(qnts, interpolation='nearest')
train_qnt = (df_data.YIELD >= ylds.min()) & (df_data.YIELD <= ylds.max()) & (df_data.DEPTH >= dpths.min()) & (df_data.DEPTH <= dpths.max())
df_train = df_data[train_qnt].reset_index(drop=True)
df_test = df_data[~train_qnt].reset_index(drop=True)

# plot train and test yields and depths
plt.figure()
plt.scatter(df_train.YIELD, df_train.DEPTH, label='Train', color='black', alpha=0.2)
plt.scatter(df_test.YIELD, df_test.DEPTH, label='Test', color='red', alpha=0.2)
plt.xlabel('Yield')
plt.ylabel('Depth')
plt.legend()
plt.title('Train and Test domains')
plt.savefig(f'{root}/results/{study}/train_test_domains.png')
plt.close('all')



#%% Data Arrangement

trunc = 1000
ds = 10
dt = 0.001

tv = np.arange(1,trunc+1)*dt
tv = tv[::ds]

# Define Train Set
tdsf = df_train.DATA
wvec = df_train.YIELD
hvec = df_train.DEPTH
t_tdsf = tdsf[0][:trunc]
Xtrain = np.concatenate((wvec[0]*np.ones((tv.size,1)), hvec[0]*np.ones((tv.size,1)), np.reshape(tv,(-1,1))), axis=1)
Ytrain = np.reshape(t_tdsf[::ds], (-1,1))
for ndx in range(1, df_train.shape[0]):
    t_tdsf = tdsf[ndx][:trunc]
    Xtemp = np.concatenate((wvec[ndx]*np.ones((tv.size,1)), hvec[ndx]*np.ones((tv.size,1)), np.reshape(tv,(-1,1))), axis=1)        
    Xtrain = np.concatenate((Xtrain, Xtemp), axis=0)
    Ytrain = np.concatenate((Ytrain, np.reshape(t_tdsf[::ds], (-1,1))), axis=0)
Xtrain = Xtrain.astype(np.float32)
Ytrain = Ytrain.astype(np.float32)

# Define Test Set
tdsf = df_test.DATA
wvec = df_test.YIELD
hvec = df_test.DEPTH
t_tdsf = tdsf[0][:trunc]
Xtest = np.concatenate((wvec[0]*np.ones((tv.size,1)), hvec[0]*np.ones((tv.size,1)), np.reshape(tv,(-1,1))), axis=1)
Ytest = np.reshape(t_tdsf[::ds], (-1,1))
for ndx in range(1, df_test.shape[0]):
    t_tdsf = tdsf[ndx][:trunc]
    Xtemp = np.concatenate((wvec[ndx]*np.ones((tv.size,1)), hvec[ndx]*np.ones((tv.size,1)), np.reshape(tv,(-1,1))), axis=1)        
    Xtest = np.concatenate((Xtest, Xtemp), axis=0)
    Ytest = np.concatenate((Ytest, np.reshape(t_tdsf[::ds], (-1,1))), axis=0)
Xtest = Xtest.astype(np.float32)
Ytest = Ytest.astype(np.float32)


#%% Preprocessing

# Min-Max Normalization
Xscaler = MinMaxScaler()
Xscaler.fit(Xtrain)
MaxX = Xscaler.data_max_
MinX = Xscaler.data_min_

Yscaler = MinMaxScaler()
Yscaler.fit(Ytrain)
MaxY = Yscaler.data_max_
MinY = Yscaler.data_min_

Ztrain = Yscaler.transform(Ytrain)
Ztest = Yscaler.transform(Ytest)

# Shuffle Data
numdata = Xtrain.shape[0]
np.random.seed(0)
randperm = np.random.permutation(numdata)
Utrain = Xtrain[randperm,:]
Ztrain_base = Ztrain[randperm,:]
# Out:
# /tmp/ipykernel_4234/3255806211.py:20: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
noise = [0.00, 0.01, 0.1, 0.2, 0.5]
for sigma in noise:

    path = f'{root}/results/{study}/{sigma}'
    if not os.path.exists(path): os.makedirs(path)
    else:
        print(f'{root}/results/{study}/{sigma} exists, skipping')
        continue

    # Gaussian Noise
    # sigma = 0.00
    mu = 0.00
    np.random.seed(1)
    Ztrain = (Ztrain_base + sigma*np.random.randn(numdata,1) + mu).astype(np.float32)

    numIn = Utrain.shape[1]
    numOut = Ztrain.shape[1]


    #%% Define Classes

    class ANN_Dataset(Dataset):    

        # Initialize your data
        def __init__(self, x, y):        
            self.len = x.shape[0]
            self.x_data = torch.from_numpy(x)
            self.y_data = torch.from_numpy(y)

        def __getitem__(self, index):
            return self.x_data[index], self.y_data[index]

        def __len__(self):
            return self.len


    # Fully Connected NN
    class FCNN_Net(nn.Module):

        def __init__(self, numIn, numOut):
            super(FCNN_Net, self).__init__()
            self.fc1 = nn.Linear(numIn, 24)
            self.fc2 = nn.Linear(24, 6)
            self.fc3 = nn.Linear(6, numOut)
            
        def forward(self, w, h, t):        
            inputs = torch.cat([w,h,t],axis=1) # combined two arrays of 1 columns each to one array of 2 columns        
            # in_size = x.size(0)
            # inputs = x.view(in_size, -1)
            layer1_out = torch.tanh(self.fc1(inputs))
            layer2_out = torch.tanh(self.fc2(layer1_out))
            output = (self.fc3(layer2_out))
            return output


    #%% Defined Functions


    ## PDE as loss function. Thus would use the network which we call as u_theta
    def f_partial(data, net, MaxX, MinX, MaxY, MinY):
        
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
        xmax = torch.from_numpy(MaxX).to(device)
        xmin = torch.from_numpy(MinX).to(device)
        ymax = torch.from_numpy(MaxY).to(device)
        ymin = torch.from_numpy(MinY).to(device)
        
        wvec = Variable(torch.reshape(data[:,0], (-1,1)), requires_grad=True).to(device)
        hvec = Variable(torch.reshape(data[:,1], (-1,1)), requires_grad=True).to(device)
        tvec = Variable(torch.reshape(data[:,2], (-1,1)), requires_grad=True).to(device)
            
        # applying normalized input
        # x = torch.cat([(wvec-xmin[0])/(xmax[0]-xmin[0]),(hvec-xmin[1])/(xmax[1]-xmin[1]),(tvec-xmin[2])/(xmax[2]-xmin[2])],axis=1)    
        s = net((wvec-xmin[0])/(xmax[0]-xmin[0]), (hvec-xmin[1])/(xmax[1]-xmin[1]), (tvec-xmin[2])/(xmax[2]-xmin[2])) # the dependent variable s is given by the network based on independent variables w, h, t

        # remove normalization
        s = s*(ymax-ymin) + ymin
        
        s_w = torch.autograd.grad(s.sum(), wvec, create_graph=True)[0]
        s_h = torch.autograd.grad(s.sum(), hvec, create_graph=True)[0] 
            
        ww = torch.reshape(data[:,0], (-1,1))
        hh = torch.reshape(data[:,1], (-1,1))
        tt = torch.reshape(data[:,2], (-1,1))
        
        # define parameters
        ho = 122
        Ro = 202
        go = 26
        P1 = 3.6*1e6
        P2 = 5.0*1e6
        n = 2.4
        pv = 3500
        sv = 2021
        rho = 2000
        
        dsdR = torch.zeros(ww.shape).to(device)

        Rel = Ro*((ho/hh)**(1/n))*(ww**(1/3))
        ga = go*Ro/Rel

        mu = rho*(sv**2)
        lam = rho*(pv**2)-2*mu    
        wo = pv/Rel
        bet = (lam+2*mu)/(4*mu)
        alp = wo/(2*bet)
        p = wo*(1/2/bet-1/4/bet**2)**(1/2)

        def dF_(tau):
            return (Rel*pv**2)/(4*mu*bet*p)*(-alp*torch.exp(-alp*tau)*torch.sin(p*tau) + p*torch.exp(-alp*tau)*torch.cos(p*tau))

        def dBdR_(tau):
            return (tt-tau)*ga*torch.exp(-ga*(tt-tau))/Rel*P1*(hh/ho) - ((tt-tau)*ga*torch.exp(-ga*(tt-tau))+3*(1-torch.exp(-ga*(tt-tau))))/Rel*P2*((ho/hh)**(1/3))*((Ro/Rel)**3)*(ww**(0.87))

        dtau = 0.001
        tau = torch.tensor(np.arange(0,1,dtau)).to(device).float()
        
        dF = dF_(tau)
        dBdR = dBdR_(tau)
        
        temp = dF*dBdR*dtau
        mask = (tt - tau) < 0
        temp[mask] = 0
        dsdR += temp.sum(axis=-1).unsqueeze(-1)

        dRdw = 1/3*Ro*((ho/hh)**(1/n))*(ww**(-2/3))
        dRdh = -1/n*((ho/hh)**(1/n))*(1/hh)*(ww**(1/3))
        dsdw = dsdR*dRdw
        dsdh = dsdR*dRdh
            
        return s_w, dsdw, s_h, dsdh


    def train(model, loader, optimizer, MaxX, MinX, MaxY, MinY, lam1, lam2):
        
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        model.train()
        total_loss = 0
        
        xmax = torch.from_numpy(MaxX).to(device)
        xmin = torch.from_numpy(MinX).to(device)
        
        for batch_idx, (data, target) in enumerate(loader):
            
            data, target = Variable(data, requires_grad=True).to(device), Variable(target, requires_grad=True).to(device)
            # all_zeros = torch.zeros(target.shape).to(device)
            # print(target.shape)
            
            # normalization
            dataN = (data-xmin)/(xmax-xmin)
                    
            def closure():
                optimizer.zero_grad()
                output = model(torch.reshape(dataN[:,0], (-1,1)), torch.reshape(dataN[:,1], (-1,1)), torch.reshape(dataN[:,2], (-1,1)))
                # print(output.shape)
                mse_d = criterion(output,target)    
                
                s_w, dsdw, s_h, dsdh = f_partial(data, model, MaxX, MinX, MaxY, MinY)
                # print(s_w)
                # print(dsdw)
                
                mse_sw = criterion(s_w,dsdw)
                mse_sh = criterion(s_h,dsdh)
                
                # print(mse_d)
                # print(mse_sw)
                # print(mse_sh)
                
                loss = mse_d + lam1*mse_sw + lam2*mse_sh
                # loss = mse_d
                
                loss.backward()
                return loss
            
            loss = optimizer.step(closure=closure)
            total_loss += loss.item()*len(data)
        
        total_loss /= len(loader.dataset)
        
        return total_loss
        

    def test(model, loader, MaxX, MinX, MaxY, MinY):
        
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        model.eval()
        test_loss = 0
        
        xmax = torch.from_numpy(MaxX).to(device)
        xmin = torch.from_numpy(MinX).to(device)
        
        for data, target in loader:

            data = data.requires_grad_(False).to(device)
            target = target.requires_grad_(False).to(device)
            
            # normalization
            dataN = (data-xmin)/(xmax-xmin)
            
            output = model(torch.reshape(dataN[:,0], (-1,1)), torch.reshape(dataN[:,1], (-1,1)), torch.reshape(dataN[:,2], (-1,1)))
            
            loss = criterion(output,target)
            test_loss += loss.item()*len(data)
            # print(len(data))

        test_loss /= len(loader.dataset)

        return test_loss


    #%% Hyperparameter Selection

    max_epoch = 1000
    max_fail = 8
    batch_size = 4096
    val_ratio = 0.2
    train_ratio = 0.8

    lamda1 = 1e-9 # PDE loss weight
    lamda2 = 1

    train_num = int(numdata*train_ratio)
    val_num = numdata - train_num

    train_dataset = ANN_Dataset(Utrain[:train_num,:], Ztrain[:train_num,:])
    val_dataset = ANN_Dataset(Utrain[train_num:,:], Ztrain[train_num:,:])
    test_dataset = ANN_Dataset(Xtest, Ztest)

    # Data Loader (Input Pipeline)
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)


    #%% Training

    # Define Network to Train
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = FCNN_Net(numIn, numOut).to(device)
    # model.double()

    # Select Optimizer and Loss Criterion
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.999), eps=1e-8,
                            weight_decay=0, amsgrad=False)

    fail_count = 0
    min_cost = float('inf')

    timevec = np.zeros((max_epoch, 1))
    for epoch in range(1, max_epoch):
        
        start = timer()    
        train(model, train_loader, optimizer, MaxX, MinX, MaxY, MinY, lamda1, lamda2)    
        RMSE_val = np.sqrt(test(model, val_loader, MaxX, MinX, MaxY, MinY))
        print('\n Epoch: {}  Val set RMSE = {:.8f} \n'.format(epoch, RMSE_val))
            
        if RMSE_val < min_cost:
            min_cost = RMSE_val
            fail_count = 0
        elif fail_count >= max_fail:
            print('Stopping... Maximum number of validation failures exceeded')
            break
        else:
            fail_count += 1
                
        timevec[epoch] = timer() - start
            
    time_avg = timevec[:epoch].mean()
    print('Average time taken for a single epoch is %f seconds.' % time_avg)

    RMSE_test = np.sqrt(test(model, test_loader, MaxX, MinX, MaxY, MinY))
    print('\n Test set RMSE = {:.8f}\n'.format(RMSE_test))



    #%% Validation

    model.to('cpu')

    Xin = (Xtest-MinX)/(MaxX-MinX)
    Xt = torch.from_numpy(Xin)
    Zhat = model(torch.reshape(Xt[:,0], (-1,1)), torch.reshape(Xt[:,1], (-1,1)), torch.reshape(Xt[:,2], (-1,1)))
    Zhat = Zhat.detach().numpy()
    Yhat = Yscaler.inverse_transform(Zhat)

    RMSE_norm = np.sqrt(np.mean((Ytest-Yhat)**2))
    print(RMSE_norm)


    line = np.arange(0, MaxY, 1e-4)
    plt.plot(Ytest[:,0], Yhat[:,0], 'bo')
    plt.plot(line, line, 'k')
    plt.xlabel('true')
    plt.ylabel('predicted')
    plt.title('displacement')
    plt.savefig(path + '/disp_true_v_pred.png')
    # plt.show()
    plt.close('all')
    


    plt.plot(Xtest[:,2], Yhat[:,0], 'bo')
    plt.plot(Xtest[:,2], Ytest[:,0], 'r')
    plt.xlabel('time')
    plt.ylabel('displacement')
    plt.savefig(path + '/disp_err_v_time.png')
    # plt.show()
    plt.close('all')
    



    #%% Save Data and Model

    # v1: lamda1 = 1e-9, lamda2 = 1 (noise 0) RMSE: 0.0001379581


    modelname = 'SeismicWave_TDSF_forward_PGNN_v1.pth'
    ANNmodel = {'model': FCNN_Net(numIn, numOut),
            'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict()}
    torch.save(ANNmodel, path + '/' + modelname)


    filename = 'SeismicWave_TDSF_forward_PGNN_v1_result.mat'
    sio.savemat(path + '/' + filename, 
                {'Yhat':Yhat, 'Ytest':Ytest, 'Xtest':Xtest,
                'Ymax':MaxY, 'Ymin':MinY, 'Xmax':MaxX, 'Xmin':MinX})


    #%% Result Comparison

    modelname = 'SeismicWave_TDSF_forward_PGNN_v1.pth'
    model_data1 = torch.load(path + '/' + modelname)

    model1 = model_data1['model']
    model1.load_state_dict(model_data1['state_dict'])
    model1.eval()


    TI = 2
    Ind1 = int((TI-1)*100)
    Ind2 = int(TI*100)
    tv = Xtest[Ind1:Ind2,2]
    Yreal = np.squeeze(Ytest[Ind1:Ind2])

    Xin = (Xtest-MinX)/(MaxX-MinX)

    Ztemp1 = model1(torch.from_numpy(np.reshape(Xin[Ind1:Ind2,0],(-1,1))),
                    torch.from_numpy(np.reshape(Xin[Ind1:Ind2,1],(-1,1))),
                    torch.from_numpy(np.reshape(Xin[Ind1:Ind2,2],(-1,1)))).detach().numpy()
    Ytemp1 = np.squeeze(Yscaler.inverse_transform(Ztemp1))




    #%%

    # Plot desired concentration    
    plt.plot(tv, Yreal, 'k')
    plt.plot(tv, Ytemp1, 'b')
    plt.xlabel('time')
    plt.ylabel('displacement')
    plt.legend(('Truth',f'{sigma}% Noise'))
    plt.savefig(path + '/t_v_d.png')
    # plt.show()
    plt.close('all')
    


    # Plot desired concentration    
    plt.plot(tv, np.abs(Ytemp1-Yreal), 'b')
    plt.xlabel('time')
    plt.ylabel('displacement error')
    plt.legend((f'{sigma}% Noise'))
    plt.savefig(path + '/t_v_d_err.png')
    plt.close('all')
    # plt.show()
    
    


    #%% Correlation Check

    from scipy import signal
    import matplotlib.pyplot as plt

    corr1 = signal.correlate(Ytemp1, Yreal, mode='full', method='auto')
    corr1 /= np.max(corr1)
    lags1 = signal.correlation_lags(len(Ytemp1), len(Yreal))

    plt.plot(lags1, corr1, 'b')
    plt.xlabel('lags')
    plt.ylabel('cross-correlation')
    plt.legend((f'{sigma}% Noise'))
    plt.savefig(path + '/cross_corr.png')
    plt.close('all')
    # plt.show()
# Out:
#  Epoch: 1  Val set RMSE = 0.12157073
#
#
#  Epoch: 2  Val set RMSE = 0.12070863
#
#
#  Epoch: 3  Val set RMSE = 0.12062864
#
#
#  Epoch: 4  Val set RMSE = 0.12053712
#
#
#  Epoch: 5  Val set RMSE = 0.12041357
#
#
#  Epoch: 6  Val set RMSE = 0.12024279
#
#
#  Epoch: 7  Val set RMSE = 0.12000464
#
#
#  Epoch: 8  Val set RMSE = 0.11969151
#
#
#  Epoch: 9  Val set RMSE = 0.11932322
#
#
#  Epoch: 10  Val set RMSE = 0.11896518
#
#
#  Epoch: 11  Val set RMSE = 0.11870596
#
#
#  Epoch: 12  Val set RMSE = 0.11853141
#
#
#  Epoch: 13  Val set RMSE = 0.11836685
#
#
#  Epoch: 14  Val set RMSE = 0.11816579
#
#
#  Epoch: 15  Val set RMSE = 0.11789455
#
#
#  Epoch: 16  Val set RMSE = 0.11752114
#
#
#  Epoch: 17  Val set RMSE = 0.11702134
#
#
#  Epoch: 18  Val set RMSE = 0.11633455
#
#
#  Epoch: 19  Val set RMSE = 0.11503009
#
#
#  Epoch: 20  Val set RMSE = 0.10987388
#
#
#  Epoch: 21  Val set RMSE = 0.09279977
#
#
#  Epoch: 22  Val set RMSE = 0.07663156
#
#
#  Epoch: 23  Val set RMSE = 0.06521630
#
#
#  Epoch: 24  Val set RMSE = 0.05627489
#
#
#  Epoch: 25  Val set RMSE = 0.04949330
#
#
#  Epoch: 26  Val set RMSE = 0.04447693
#
#
#  Epoch: 27  Val set RMSE = 0.04084357
#
#
#  Epoch: 28  Val set RMSE = 0.03824817
#
#
#  Epoch: 29  Val set RMSE = 0.03639596
#
#
#  Epoch: 30  Val set RMSE = 0.03505538
#
#
#  Epoch: 31  Val set RMSE = 0.03406098
#
#
#  Epoch: 32  Val set RMSE = 0.03329937
#
#
#  Epoch: 33  Val set RMSE = 0.03268415
#
#
#  Epoch: 34  Val set RMSE = 0.03213503
#
#
#  Epoch: 35  Val set RMSE = 0.03156715
#
#
#  Epoch: 36  Val set RMSE = 0.03089449
#
#
#  Epoch: 37  Val set RMSE = 0.03005181
#
#
#  Epoch: 38  Val set RMSE = 0.02901417
#
#
#  Epoch: 39  Val set RMSE = 0.02780729
#
#
#  Epoch: 40  Val set RMSE = 0.02653043
#
#
#  Epoch: 41  Val set RMSE = 0.02532627
#
#
#  Epoch: 42  Val set RMSE = 0.02429285
#
#
#  Epoch: 43  Val set RMSE = 0.02343632
#
#
#  Epoch: 44  Val set RMSE = 0.02270037
#
#
#  Epoch: 45  Val set RMSE = 0.02202770
#
#
#  Epoch: 46  Val set RMSE = 0.02140200
#
#
#  Epoch: 47  Val set RMSE = 0.02084067
#
#
#  Epoch: 48  Val set RMSE = 0.02036113
#
#
#  Epoch: 49  Val set RMSE = 0.01996654
#
#
#  Epoch: 50  Val set RMSE = 0.01964807
#
#
#  Epoch: 51  Val set RMSE = 0.01939053
#
#
#  Epoch: 52  Val set RMSE = 0.01917781
#
#
#  Epoch: 53  Val set RMSE = 0.01899616
#
#
#  Epoch: 54  Val set RMSE = 0.01883516
#
#
#  Epoch: 55  Val set RMSE = 0.01868768
#
#
#  Epoch: 56  Val set RMSE = 0.01854911
#
#
#  Epoch: 57  Val set RMSE = 0.01841668
#
#
#  Epoch: 58  Val set RMSE = 0.01828876
#
#
#  Epoch: 59  Val set RMSE = 0.01816435
#
#
#  Epoch: 60  Val set RMSE = 0.01804279
#
#
#  Epoch: 61  Val set RMSE = 0.01792346
#
#
#  Epoch: 62  Val set RMSE = 0.01780546
#
#
#  Epoch: 63  Val set RMSE = 0.01768709
#
#
#  Epoch: 64  Val set RMSE = 0.01756507
#
#
#  Epoch: 65  Val set RMSE = 0.01743633
#
#
#  Epoch: 66  Val set RMSE = 0.01730879
#
#
#  Epoch: 67  Val set RMSE = 0.01719604
#
#
#  Epoch: 68  Val set RMSE = 0.01709959
#
#
#  Epoch: 69  Val set RMSE = 0.01701258
#
#
#  Epoch: 70  Val set RMSE = 0.01693139
#
#
#  Epoch: 71  Val set RMSE = 0.01685473
#
#
#  Epoch: 72  Val set RMSE = 0.01678193
#
#
#  Epoch: 73  Val set RMSE = 0.01671244
#
#
#  Epoch: 74  Val set RMSE = 0.01664579
#
#
#  Epoch: 75  Val set RMSE = 0.01658161
#
#
#  Epoch: 76  Val set RMSE = 0.01651958
#
#
#  Epoch: 77  Val set RMSE = 0.01645946
#
#
#  Epoch: 78  Val set RMSE = 0.01640104
#
#
#  Epoch: 79  Val set RMSE = 0.01634417
#
#
#  Epoch: 80  Val set RMSE = 0.01628872
#
#
#  Epoch: 81  Val set RMSE = 0.01623457
#
#
#  Epoch: 82  Val set RMSE = 0.01618161
#
#
#  Epoch: 83  Val set RMSE = 0.01612977
#
#
#  Epoch: 84  Val set RMSE = 0.01607896
#
#
#  Epoch: 85  Val set RMSE = 0.01602909
#
#
#  Epoch: 86  Val set RMSE = 0.01598012
#
#
#  Epoch: 87  Val set RMSE = 0.01593196
#
#
#  Epoch: 88  Val set RMSE = 0.01588455
#
#
#  Epoch: 89  Val set RMSE = 0.01583785
#
#
#  Epoch: 90  Val set RMSE = 0.01579178
#
#
#  Epoch: 91  Val set RMSE = 0.01574631
#
#
#  Epoch: 92  Val set RMSE = 0.01570138
#
#
#  Epoch: 93  Val set RMSE = 0.01565696
#
#
#  Epoch: 94  Val set RMSE = 0.01561298
#
#
#  Epoch: 95  Val set RMSE = 0.01556943
#
#
#  Epoch: 96  Val set RMSE = 0.01552623
#
#
#  Epoch: 97  Val set RMSE = 0.01548336
#
#
#  Epoch: 98  Val set RMSE = 0.01544074
#
#
#  Epoch: 99  Val set RMSE = 0.01539830
#
#
#  Epoch: 100  Val set RMSE = 0.01535595
#
#
#  Epoch: 101  Val set RMSE = 0.01531360
#
#
#  Epoch: 102  Val set RMSE = 0.01527117
#
#
#  Epoch: 103  Val set RMSE = 0.01522857
#
#
#  Epoch: 104  Val set RMSE = 0.01518574
#
#
#  Epoch: 105  Val set RMSE = 0.01514268
#
#
#  Epoch: 106  Val set RMSE = 0.01509940
#
#
#  Epoch: 107  Val set RMSE = 0.01505599
#
#
#  Epoch: 108  Val set RMSE = 0.01501248
#
#
#  Epoch: 109  Val set RMSE = 0.01496896
#
#
#  Epoch: 110  Val set RMSE = 0.01492540
#
#
#  Epoch: 111  Val set RMSE = 0.01488172
#
#
#  Epoch: 112  Val set RMSE = 0.01483772
#
#
#  Epoch: 113  Val set RMSE = 0.01479309
#
#
#  Epoch: 114  Val set RMSE = 0.01474749
#
#
#  Epoch: 115  Val set RMSE = 0.01470058
#
#
#  Epoch: 116  Val set RMSE = 0.01465215
#
#
#  Epoch: 117  Val set RMSE = 0.01460215
#
#
#  Epoch: 118  Val set RMSE = 0.01455072
#
#
#  Epoch: 119  Val set RMSE = 0.01449812
#
#
#  Epoch: 120  Val set RMSE = 0.01444466
#
#
#  Epoch: 121  Val set RMSE = 0.01439066
#
#
#  Epoch: 122  Val set RMSE = 0.01433636
#
#
#  Epoch: 123  Val set RMSE = 0.01428195
#
#
#  Epoch: 124  Val set RMSE = 0.01422752
#
#
#  Epoch: 125  Val set RMSE = 0.01417311
#
#
#  Epoch: 126  Val set RMSE = 0.01411871
#
#
#  Epoch: 127  Val set RMSE = 0.01406437
#
#
#  Epoch: 128  Val set RMSE = 0.01401002
#
#
#  Epoch: 129  Val set RMSE = 0.01395572
#
#
#  Epoch: 130  Val set RMSE = 0.01390149
#
#
#  Epoch: 131  Val set RMSE = 0.01384736
#
#
#  Epoch: 132  Val set RMSE = 0.01379339
#
#
#  Epoch: 133  Val set RMSE = 0.01373963
#
#
#  Epoch: 134  Val set RMSE = 0.01368619
#
#
#  Epoch: 135  Val set RMSE = 0.01363312
#
#
#  Epoch: 136  Val set RMSE = 0.01358055
#
#
#  Epoch: 137  Val set RMSE = 0.01352854
#
#
#  Epoch: 138  Val set RMSE = 0.01347718
#
#
#  Epoch: 139  Val set RMSE = 0.01342649
#
#
#  Epoch: 140  Val set RMSE = 0.01337650
#
#
#  Epoch: 141  Val set RMSE = 0.01332723
#
#
#  Epoch: 142  Val set RMSE = 0.01327867
#
#
#  Epoch: 143  Val set RMSE = 0.01323085
#
#
#  Epoch: 144  Val set RMSE = 0.01318377
#
#
#  Epoch: 145  Val set RMSE = 0.01313742
#
#
#  Epoch: 146  Val set RMSE = 0.01309184
#
#
#  Epoch: 147  Val set RMSE = 0.01304702
#
#
#  Epoch: 148  Val set RMSE = 0.01300297
#
#
#  Epoch: 149  Val set RMSE = 0.01295967
#
#
#  Epoch: 150  Val set RMSE = 0.01291714
#
#
#  Epoch: 151  Val set RMSE = 0.01287536
#
#
#  Epoch: 152  Val set RMSE = 0.01283432
#
#
#  Epoch: 153  Val set RMSE = 0.01279400
#
#
#  Epoch: 154  Val set RMSE = 0.01275437
#
#
#  Epoch: 155  Val set RMSE = 0.01271541
#
#
#  Epoch: 156  Val set RMSE = 0.01267708
#
#
#  Epoch: 157  Val set RMSE = 0.01263937
#
#
#  Epoch: 158  Val set RMSE = 0.01260223
#
#
#  Epoch: 159  Val set RMSE = 0.01256565
#
#
#  Epoch: 160  Val set RMSE = 0.01252958
#
#
#  Epoch: 161  Val set RMSE = 0.01249399
#
#
#  Epoch: 162  Val set RMSE = 0.01245886
#
#
#  Epoch: 163  Val set RMSE = 0.01242415
#
#
#  Epoch: 164  Val set RMSE = 0.01238984
#
#
#  Epoch: 165  Val set RMSE = 0.01235587
#
#
#  Epoch: 166  Val set RMSE = 0.01232225
#
#
#  Epoch: 167  Val set RMSE = 0.01228894
#
#
#  Epoch: 168  Val set RMSE = 0.01225590
#
#
#  Epoch: 169  Val set RMSE = 0.01222311
#
#
#  Epoch: 170  Val set RMSE = 0.01219055
#
#
#  Epoch: 171  Val set RMSE = 0.01215819
#
#
#  Epoch: 172  Val set RMSE = 0.01212600
#
#
#  Epoch: 173  Val set RMSE = 0.01209398
#
#
#  Epoch: 174  Val set RMSE = 0.01206209
#
#
#  Epoch: 175  Val set RMSE = 0.01203031
#
#
#  Epoch: 176  Val set RMSE = 0.01199862
#
#
#  Epoch: 177  Val set RMSE = 0.01196701
#
#
#  Epoch: 178  Val set RMSE = 0.01193546
#
#
#  Epoch: 179  Val set RMSE = 0.01190396
#
#
#  Epoch: 180  Val set RMSE = 0.01187249
#
#
#  Epoch: 181  Val set RMSE = 0.01184102
#
#
#  Epoch: 182  Val set RMSE = 0.01180955
#
#
#  Epoch: 183  Val set RMSE = 0.01177808
#
#
#  Epoch: 184  Val set RMSE = 0.01174659
#
#
#  Epoch: 185  Val set RMSE = 0.01171507
#
#
#  Epoch: 186  Val set RMSE = 0.01168352
#
#
#  Epoch: 187  Val set RMSE = 0.01165191
#
#
#  Epoch: 188  Val set RMSE = 0.01162026
#
#
#  Epoch: 189  Val set RMSE = 0.01158855
#
#
#  Epoch: 190  Val set RMSE = 0.01155678
#
#
#  Epoch: 191  Val set RMSE = 0.01152495
#
#
#  Epoch: 192  Val set RMSE = 0.01149305
#
#
#  Epoch: 193  Val set RMSE = 0.01146108
#
#
#  Epoch: 194  Val set RMSE = 0.01142906
#
#
#  Epoch: 195  Val set RMSE = 0.01139695
#
#
#  Epoch: 196  Val set RMSE = 0.01136479
#
#
#  Epoch: 197  Val set RMSE = 0.01133254
#
#
#  Epoch: 198  Val set RMSE = 0.01130025
#
#
#  Epoch: 199  Val set RMSE = 0.01126789
#
#
#  Epoch: 200  Val set RMSE = 0.01123548
#
#
#  Epoch: 201  Val set RMSE = 0.01120301
#
#
#  Epoch: 202  Val set RMSE = 0.01117048
#
#
#  Epoch: 203  Val set RMSE = 0.01113790
#
#
#  Epoch: 204  Val set RMSE = 0.01110527
#
#
#  Epoch: 205  Val set RMSE = 0.01107261
#
#
#  Epoch: 206  Val set RMSE = 0.01103990
#
#
#  Epoch: 207  Val set RMSE = 0.01100716
#
#
#  Epoch: 208  Val set RMSE = 0.01097439
#
#
#  Epoch: 209  Val set RMSE = 0.01094161
#
#
#  Epoch: 210  Val set RMSE = 0.01090881
#
#
#  Epoch: 211  Val set RMSE = 0.01087599
#
#
#  Epoch: 212  Val set RMSE = 0.01084318
#
#
#  Epoch: 213  Val set RMSE = 0.01081040
#
#
#  Epoch: 214  Val set RMSE = 0.01077762
#
#
#  Epoch: 215  Val set RMSE = 0.01074488
#
#
#  Epoch: 216  Val set RMSE = 0.01071219
#
#
#  Epoch: 217  Val set RMSE = 0.01067956
#
#
#  Epoch: 218  Val set RMSE = 0.01064701
#
#
#  Epoch: 219  Val set RMSE = 0.01061456
#
#
#  Epoch: 220  Val set RMSE = 0.01058222
#
#
#  Epoch: 221  Val set RMSE = 0.01055000
#
#
#  Epoch: 222  Val set RMSE = 0.01051793
#
#
#  Epoch: 223  Val set RMSE = 0.01048600
#
#
#  Epoch: 224  Val set RMSE = 0.01045424
#
#
#  Epoch: 225  Val set RMSE = 0.01042267
#
#
#  Epoch: 226  Val set RMSE = 0.01039128
#
#
#  Epoch: 227  Val set RMSE = 0.01036007
#
#
#  Epoch: 228  Val set RMSE = 0.01032909
#
#
#  Epoch: 229  Val set RMSE = 0.01029832
#
#
#  Epoch: 230  Val set RMSE = 0.01026780
#
#
#  Epoch: 231  Val set RMSE = 0.01023755
#
#
#  Epoch: 232  Val set RMSE = 0.01020759
#
#
#  Epoch: 233  Val set RMSE = 0.01017798
#
#
#  Epoch: 234  Val set RMSE = 0.01014874
#
#
#  Epoch: 235  Val set RMSE = 0.01011988
#
#
#  Epoch: 236  Val set RMSE = 0.01009146
#
#
#  Epoch: 237  Val set RMSE = 0.01006346
#
#
#  Epoch: 238  Val set RMSE = 0.01003589
#
#
#  Epoch: 239  Val set RMSE = 0.01000874
#
#
#  Epoch: 240  Val set RMSE = 0.00998199
#
#
#  Epoch: 241  Val set RMSE = 0.00995562
#
#
#  Epoch: 242  Val set RMSE = 0.00992961
#
#
#  Epoch: 243  Val set RMSE = 0.00990395
#
#
#  Epoch: 244  Val set RMSE = 0.00987861
#
#
#  Epoch: 245  Val set RMSE = 0.00985362
#
#
#  Epoch: 246  Val set RMSE = 0.00982894
#
#
#  Epoch: 247  Val set RMSE = 0.00980458
#
#
#  Epoch: 248  Val set RMSE = 0.00978053
#
#
#  Epoch: 249  Val set RMSE = 0.00975679
#
#
#  Epoch: 250  Val set RMSE = 0.00973337
#
#
#  Epoch: 251  Val set RMSE = 0.00971025
#
#
#  Epoch: 252  Val set RMSE = 0.00968747
#
#
#  Epoch: 253  Val set RMSE = 0.00966499
#
#
#  Epoch: 254  Val set RMSE = 0.00964285
#
#
#  Epoch: 255  Val set RMSE = 0.00962103
#
#
#  Epoch: 256  Val set RMSE = 0.00959953
#
#
#  Epoch: 257  Val set RMSE = 0.00957838
#
#
#  Epoch: 258  Val set RMSE = 0.00955758
#
#
#  Epoch: 259  Val set RMSE = 0.00953710
#
#
#  Epoch: 260  Val set RMSE = 0.00951696
#
#
#  Epoch: 261  Val set RMSE = 0.00949719
#
#
#  Epoch: 262  Val set RMSE = 0.00947775
#
#
#  Epoch: 263  Val set RMSE = 0.00945867
#
#
#  Epoch: 264  Val set RMSE = 0.00943995
#
#
#  Epoch: 265  Val set RMSE = 0.00942156
#
#
#  Epoch: 266  Val set RMSE = 0.00940353
#
#
#  Epoch: 267  Val set RMSE = 0.00938586
#
#
#  Epoch: 268  Val set RMSE = 0.00936852
#
#
#  Epoch: 269  Val set RMSE = 0.00935153
#
#
#  Epoch: 270  Val set RMSE = 0.00933487
#
#
#  Epoch: 271  Val set RMSE = 0.00931856
#
#
#  Epoch: 272  Val set RMSE = 0.00930258
#
#
#  Epoch: 273  Val set RMSE = 0.00928692
#
#
#  Epoch: 274  Val set RMSE = 0.00927159
#
#
#  Epoch: 275  Val set RMSE = 0.00925656
#
#
#  Epoch: 276  Val set RMSE = 0.00924183
#
#
#  Epoch: 277  Val set RMSE = 0.00922741
#
#
#  Epoch: 278  Val set RMSE = 0.00921328
#
#
#  Epoch: 279  Val set RMSE = 0.00919941
#
#
#  Epoch: 280  Val set RMSE = 0.00918583
#
#
#  Epoch: 281  Val set RMSE = 0.00917251
#
#
#  Epoch: 282  Val set RMSE = 0.00915944
#
#
#  Epoch: 283  Val set RMSE = 0.00914659
#
#
#  Epoch: 284  Val set RMSE = 0.00913401
#
#
#  Epoch: 285  Val set RMSE = 0.00912164
#
#
#  Epoch: 286  Val set RMSE = 0.00910949
#
#
#  Epoch: 287  Val set RMSE = 0.00909754
#
#
#  Epoch: 288  Val set RMSE = 0.00908580
#
#
#  Epoch: 289  Val set RMSE = 0.00907424
#
#
#  Epoch: 290  Val set RMSE = 0.00906287
#
#
#  Epoch: 291  Val set RMSE = 0.00905167
#
#
#  Epoch: 292  Val set RMSE = 0.00904064
#
#
#  Epoch: 293  Val set RMSE = 0.00902976
#
#
#  Epoch: 294  Val set RMSE = 0.00901904
#
#
#  Epoch: 295  Val set RMSE = 0.00900845
#
#
#  Epoch: 296  Val set RMSE = 0.00899801
#
#
#  Epoch: 297  Val set RMSE = 0.00898770
#
#
#  Epoch: 298  Val set RMSE = 0.00897751
#
#
#  Epoch: 299  Val set RMSE = 0.00896744
#
#
#  Epoch: 300  Val set RMSE = 0.00895748
#
#
#  Epoch: 301  Val set RMSE = 0.00894762
#
#
#  Epoch: 302  Val set RMSE = 0.00893786
#
#
#  Epoch: 303  Val set RMSE = 0.00892820
#
#
#  Epoch: 304  Val set RMSE = 0.00891863
#
#
#  Epoch: 305  Val set RMSE = 0.00890915
#
#
#  Epoch: 306  Val set RMSE = 0.00889973
#
#
#  Epoch: 307  Val set RMSE = 0.00889038
#
#
#  Epoch: 308  Val set RMSE = 0.00888112
#
#
#  Epoch: 309  Val set RMSE = 0.00887193
#
#
#  Epoch: 310  Val set RMSE = 0.00886278
#
#
#  Epoch: 311  Val set RMSE = 0.00885371
#
#
#  Epoch: 312  Val set RMSE = 0.00884469
#
#
#  Epoch: 313  Val set RMSE = 0.00883569
#
#
#  Epoch: 314  Val set RMSE = 0.00882677
#
#
#  Epoch: 315  Val set RMSE = 0.00881788
#
#
#  Epoch: 316  Val set RMSE = 0.00880903
#
#
#  Epoch: 317  Val set RMSE = 0.00880022
#
#
#  Epoch: 318  Val set RMSE = 0.00879143
#
#
#  Epoch: 319  Val set RMSE = 0.00878266
#
#
#  Epoch: 320  Val set RMSE = 0.00877393
#
#
#  Epoch: 321  Val set RMSE = 0.00876522
#
#
#  Epoch: 322  Val set RMSE = 0.00875652
#
#
#  Epoch: 323  Val set RMSE = 0.00874784
#
#
#  Epoch: 324  Val set RMSE = 0.00873916
#
#
#  Epoch: 325  Val set RMSE = 0.00873050
#
#
#  Epoch: 326  Val set RMSE = 0.00872184
#
#
#  Epoch: 327  Val set RMSE = 0.00871319
#
#
#  Epoch: 328  Val set RMSE = 0.00870454
#
#
#  Epoch: 329  Val set RMSE = 0.00869586
#
#
#  Epoch: 330  Val set RMSE = 0.00868720
#
#
#  Epoch: 331  Val set RMSE = 0.00867853
#
#
#  Epoch: 332  Val set RMSE = 0.00866983
#
#
#  Epoch: 333  Val set RMSE = 0.00866113
#
#
#  Epoch: 334  Val set RMSE = 0.00865240
#
#
#  Epoch: 335  Val set RMSE = 0.00864366
#
#
#  Epoch: 336  Val set RMSE = 0.00863487
#
#
#  Epoch: 337  Val set RMSE = 0.00862608
#
#
#  Epoch: 338  Val set RMSE = 0.00861724
#
#
#  Epoch: 339  Val set RMSE = 0.00860837
#
#
#  Epoch: 340  Val set RMSE = 0.00859944
#
#
#  Epoch: 341  Val set RMSE = 0.00859050
#
#
#  Epoch: 342  Val set RMSE = 0.00858149
#
#
#  Epoch: 343  Val set RMSE = 0.00857242
#
#
#  Epoch: 344  Val set RMSE = 0.00856331
#
#
#  Epoch: 345  Val set RMSE = 0.00855415
#
#
#  Epoch: 346  Val set RMSE = 0.00854492
#
#
#  Epoch: 347  Val set RMSE = 0.00853559
#
#
#  Epoch: 348  Val set RMSE = 0.00852622
#
#
#  Epoch: 349  Val set RMSE = 0.00851674
#
#
#  Epoch: 350  Val set RMSE = 0.00850720
#
#
#  Epoch: 351  Val set RMSE = 0.00849756
#
#
#  Epoch: 352  Val set RMSE = 0.00848782
#
#
#  Epoch: 353  Val set RMSE = 0.00847799
#
#
#  Epoch: 354  Val set RMSE = 0.00846806
#
#
#  Epoch: 355  Val set RMSE = 0.00845800
#
#
#  Epoch: 356  Val set RMSE = 0.00844784
#
#
#  Epoch: 357  Val set RMSE = 0.00843753
#
#
#  Epoch: 358  Val set RMSE = 0.00842711
#
#
#  Epoch: 359  Val set RMSE = 0.00841658
#
#
#  Epoch: 360  Val set RMSE = 0.00840590
#
#
#  Epoch: 361  Val set RMSE = 0.00839507
#
#
#  Epoch: 362  Val set RMSE = 0.00838410
#
#
#  Epoch: 363  Val set RMSE = 0.00837298
#
#
#  Epoch: 364  Val set RMSE = 0.00836171
#
#
#  Epoch: 365  Val set RMSE = 0.00835027
#
#
#  Epoch: 366  Val set RMSE = 0.00833868
#
#
#  Epoch: 367  Val set RMSE = 0.00832692
#
#
#  Epoch: 368  Val set RMSE = 0.00831498
#
#
#  Epoch: 369  Val set RMSE = 0.00830289
#
#
#  Epoch: 370  Val set RMSE = 0.00829062
#
#
#  Epoch: 371  Val set RMSE = 0.00827814
#
#
#  Epoch: 372  Val set RMSE = 0.00826551
#
#
#  Epoch: 373  Val set RMSE = 0.00825267
#
#
#  Epoch: 374  Val set RMSE = 0.00823966
#
#
#  Epoch: 375  Val set RMSE = 0.00822642
#
#
#  Epoch: 376  Val set RMSE = 0.00821301
#
#
#  Epoch: 377  Val set RMSE = 0.00819938
#
#
#  Epoch: 378  Val set RMSE = 0.00818554
#
#
#  Epoch: 379  Val set RMSE = 0.00817148
#
#
#  Epoch: 380  Val set RMSE = 0.00815721
#
#
#  Epoch: 381  Val set RMSE = 0.00814269
#
#
#  Epoch: 382  Val set RMSE = 0.00812794
#
#
#  Epoch: 383  Val set RMSE = 0.00811299
#
#
#  Epoch: 384  Val set RMSE = 0.00809778
#
#
#  Epoch: 385  Val set RMSE = 0.00808234
#
#
#  Epoch: 386  Val set RMSE = 0.00806666
#
#
#  Epoch: 387  Val set RMSE = 0.00805073
#
#
#  Epoch: 388  Val set RMSE = 0.00803458
#
#
#  Epoch: 389  Val set RMSE = 0.00801815
#
#
#  Epoch: 390  Val set RMSE = 0.00800147
#
#
#  Epoch: 391  Val set RMSE = 0.00798457
#
#
#  Epoch: 392  Val set RMSE = 0.00796742
#
#
#  Epoch: 393  Val set RMSE = 0.00795002
#
#
#  Epoch: 394  Val set RMSE = 0.00793234
#
#
#  Epoch: 395  Val set RMSE = 0.00791446
#
#
#  Epoch: 396  Val set RMSE = 0.00789634
#
#
#  Epoch: 397  Val set RMSE = 0.00787799
#
#
#  Epoch: 398  Val set RMSE = 0.00785941
#
#
#  Epoch: 399  Val set RMSE = 0.00784058
#
#
#  Epoch: 400  Val set RMSE = 0.00782155
#
#
#  Epoch: 401  Val set RMSE = 0.00780232
#
#
#  Epoch: 402  Val set RMSE = 0.00778288
#
#
#  Epoch: 403  Val set RMSE = 0.00776324
#
#
#  Epoch: 404  Val set RMSE = 0.00774343
#
#
#  Epoch: 405  Val set RMSE = 0.00772341
#
#
#  Epoch: 406  Val set RMSE = 0.00770324
#
#
#  Epoch: 407  Val set RMSE = 0.00768293
#
#
#  Epoch: 408  Val set RMSE = 0.00766242
#
#
#  Epoch: 409  Val set RMSE = 0.00764182
#
#
#  Epoch: 410  Val set RMSE = 0.00762110
#
#
#  Epoch: 411  Val set RMSE = 0.00760024
#
#
#  Epoch: 412  Val set RMSE = 0.00757928
#
#
#  Epoch: 413  Val set RMSE = 0.00755824
#
#
#  Epoch: 414  Val set RMSE = 0.00753711
#
#
#  Epoch: 415  Val set RMSE = 0.00751593
#
#
#  Epoch: 416  Val set RMSE = 0.00749468
#
#
#  Epoch: 417  Val set RMSE = 0.00747341
#
#
#  Epoch: 418  Val set RMSE = 0.00745209
#
#
#  Epoch: 419  Val set RMSE = 0.00743079
#
#
#  Epoch: 420  Val set RMSE = 0.00740947
#
#
#  Epoch: 421  Val set RMSE = 0.00738815
#
#
#  Epoch: 422  Val set RMSE = 0.00736685
#
#
#  Epoch: 423  Val set RMSE = 0.00734558
#
#
#  Epoch: 424  Val set RMSE = 0.00732437
#
#
#  Epoch: 425  Val set RMSE = 0.00730322
#
#
#  Epoch: 426  Val set RMSE = 0.00728209
#
#
#  Epoch: 427  Val set RMSE = 0.00726106
#
#
#  Epoch: 428  Val set RMSE = 0.00724009
#
#
#  Epoch: 429  Val set RMSE = 0.00721923
#
#
#  Epoch: 430  Val set RMSE = 0.00719848
#
#
#  Epoch: 431  Val set RMSE = 0.00717783
#
#
#  Epoch: 432  Val set RMSE = 0.00715727
#
#
#  Epoch: 433  Val set RMSE = 0.00713683
#
#
#  Epoch: 434  Val set RMSE = 0.00711657
#
#
#  Epoch: 435  Val set RMSE = 0.00709640
#
#
#  Epoch: 436  Val set RMSE = 0.00707637
#
#
#  Epoch: 437  Val set RMSE = 0.00705647
#
#
#  Epoch: 438  Val set RMSE = 0.00703673
#
#
#  Epoch: 439  Val set RMSE = 0.00701712
#
#
#  Epoch: 440  Val set RMSE = 0.00699771
#
#
#  Epoch: 441  Val set RMSE = 0.00697841
#
#
#  Epoch: 442  Val set RMSE = 0.00695928
#
#
#  Epoch: 443  Val set RMSE = 0.00694032
#
#
#  Epoch: 444  Val set RMSE = 0.00692150
#
#
#  Epoch: 445  Val set RMSE = 0.00690283
#
#
#  Epoch: 446  Val set RMSE = 0.00688433
#
#
#  Epoch: 447  Val set RMSE = 0.00686604
#
#
#  Epoch: 448  Val set RMSE = 0.00684784
#
#
#  Epoch: 449  Val set RMSE = 0.00682989
#
#
#  Epoch: 450  Val set RMSE = 0.00681204
#
#
#  Epoch: 451  Val set RMSE = 0.00679435
#
#
#  Epoch: 452  Val set RMSE = 0.00677684
#
#
#  Epoch: 453  Val set RMSE = 0.00675950
#
#
#  Epoch: 454  Val set RMSE = 0.00674229
#
#
#  Epoch: 455  Val set RMSE = 0.00672523
#
#
#  Epoch: 456  Val set RMSE = 0.00670835
#
#
#  Epoch: 457  Val set RMSE = 0.00669161
#
#
#  Epoch: 458  Val set RMSE = 0.00667505
#
#
#  Epoch: 459  Val set RMSE = 0.00665861
#
#
#  Epoch: 460  Val set RMSE = 0.00664228
#
#
#  Epoch: 461  Val set RMSE = 0.00662613
#
#
#  Epoch: 462  Val set RMSE = 0.00661014
#
#
#  Epoch: 463  Val set RMSE = 0.00659431
#
#
#  Epoch: 464  Val set RMSE = 0.00657854
#
#
#  Epoch: 465  Val set RMSE = 0.00656295
#
#
#  Epoch: 466  Val set RMSE = 0.00654746
#
#
#  Epoch: 467  Val set RMSE = 0.00653211
#
#
#  Epoch: 468  Val set RMSE = 0.00651690
#
#
#  Epoch: 469  Val set RMSE = 0.00650181
#
#
#  Epoch: 470  Val set RMSE = 0.00648679
#
#
#  Epoch: 471  Val set RMSE = 0.00647195
#
#
#  Epoch: 472  Val set RMSE = 0.00645715
#
#
#  Epoch: 473  Val set RMSE = 0.00644250
#
#
#  Epoch: 474  Val set RMSE = 0.00642796
#
#
#  Epoch: 475  Val set RMSE = 0.00641347
#
#
#  Epoch: 476  Val set RMSE = 0.00639910
#
#
#  Epoch: 477  Val set RMSE = 0.00638476
#
#
#  Epoch: 478  Val set RMSE = 0.00637058
#
#
#  Epoch: 479  Val set RMSE = 0.00635646
#
#
#  Epoch: 480  Val set RMSE = 0.00634240
#
#
#  Epoch: 481  Val set RMSE = 0.00632838
#
#
#  Epoch: 482  Val set RMSE = 0.00631448
#
#
#  Epoch: 483  Val set RMSE = 0.00630058
#
#
#  Epoch: 484  Val set RMSE = 0.00628678
#
#
#  Epoch: 485  Val set RMSE = 0.00627300
#
#
#  Epoch: 486  Val set RMSE = 0.00625921
#
#
#  Epoch: 487  Val set RMSE = 0.00624547
#
#
#  Epoch: 488  Val set RMSE = 0.00623181
#
#
#  Epoch: 489  Val set RMSE = 0.00621815
#
#
#  Epoch: 490  Val set RMSE = 0.00620446
#
#
#  Epoch: 491  Val set RMSE = 0.00619080
#
#
#  Epoch: 492  Val set RMSE = 0.00617717
#
#
#  Epoch: 493  Val set RMSE = 0.00616348
#
#
#  Epoch: 494  Val set RMSE = 0.00614978
#
#
#  Epoch: 495  Val set RMSE = 0.00613606
#
#
#  Epoch: 496  Val set RMSE = 0.00612227
#
#
#  Epoch: 497  Val set RMSE = 0.00610850
#
#
#  Epoch: 498  Val set RMSE = 0.00609465
#
#
#  Epoch: 499  Val set RMSE = 0.00608081
#
#
#  Epoch: 500  Val set RMSE = 0.00606682
#
#
#  Epoch: 501  Val set RMSE = 0.00605282
#
#
#  Epoch: 502  Val set RMSE = 0.00603873
#
#
#  Epoch: 503  Val set RMSE = 0.00602458
#
#
#  Epoch: 504  Val set RMSE = 0.00601036
#
#
#  Epoch: 505  Val set RMSE = 0.00599607
#
#
#  Epoch: 506  Val set RMSE = 0.00598168
#
#
#  Epoch: 507  Val set RMSE = 0.00596728
#
#
#  Epoch: 508  Val set RMSE = 0.00595275
#
#
#  Epoch: 509  Val set RMSE = 0.00593812
#
#
#  Epoch: 510  Val set RMSE = 0.00592341
#
#
#  Epoch: 511  Val set RMSE = 0.00590864
#
#
#  Epoch: 512  Val set RMSE = 0.00589381
#
#
#  Epoch: 513  Val set RMSE = 0.00587891
#
#
#  Epoch: 514  Val set RMSE = 0.00586387
#
#
#  Epoch: 515  Val set RMSE = 0.00584883
#
#
#  Epoch: 516  Val set RMSE = 0.00583367
#
#
#  Epoch: 517  Val set RMSE = 0.00581850
#
#
#  Epoch: 518  Val set RMSE = 0.00580328
#
#
#  Epoch: 519  Val set RMSE = 0.00578796
#
#
#  Epoch: 520  Val set RMSE = 0.00577262
#
#
#  Epoch: 521  Val set RMSE = 0.00575722
#
#
#  Epoch: 522  Val set RMSE = 0.00574182
#
#
#  Epoch: 523  Val set RMSE = 0.00572638
#
#
#  Epoch: 524  Val set RMSE = 0.00571088
#
#
#  Epoch: 525  Val set RMSE = 0.00569535
#
#
#  Epoch: 526  Val set RMSE = 0.00567985
#
#
#  Epoch: 527  Val set RMSE = 0.00566430
#
#
#  Epoch: 528  Val set RMSE = 0.00564884
#
#
#  Epoch: 529  Val set RMSE = 0.00563331
#
#
#  Epoch: 530  Val set RMSE = 0.00561775
#
#
#  Epoch: 531  Val set RMSE = 0.00560223
#
#
#  Epoch: 532  Val set RMSE = 0.00558681
#
#
#  Epoch: 533  Val set RMSE = 0.00557134
#
#
#  Epoch: 534  Val set RMSE = 0.00555590
#
#
#  Epoch: 535  Val set RMSE = 0.00554054
#
#
#  Epoch: 536  Val set RMSE = 0.00552520
#
#
#  Epoch: 537  Val set RMSE = 0.00550994
#
#
#  Epoch: 538  Val set RMSE = 0.00549476
#
#
#  Epoch: 539  Val set RMSE = 0.00547963
#
#
#  Epoch: 540  Val set RMSE = 0.00546456
#
#
#  Epoch: 541  Val set RMSE = 0.00544956
#
#
#  Epoch: 542  Val set RMSE = 0.00543468
#
#
#  Epoch: 543  Val set RMSE = 0.00541979
#
#
#  Epoch: 544  Val set RMSE = 0.00540508
#
#
#  Epoch: 545  Val set RMSE = 0.00539031
#
#
#  Epoch: 546  Val set RMSE = 0.00537571
#
#
#  Epoch: 547  Val set RMSE = 0.00536106
#
#
#  Epoch: 548  Val set RMSE = 0.00534643
#
#
#  Epoch: 549  Val set RMSE = 0.00533182
#
#
#  Epoch: 550  Val set RMSE = 0.00531720
#
#
#  Epoch: 551  Val set RMSE = 0.00530252
#
#
#  Epoch: 552  Val set RMSE = 0.00528777
#
#
#  Epoch: 553  Val set RMSE = 0.00527287
#
#
#  Epoch: 554  Val set RMSE = 0.00525791
#
#
#  Epoch: 555  Val set RMSE = 0.00524277
#
#
#  Epoch: 556  Val set RMSE = 0.00522752
#
#
#  Epoch: 557  Val set RMSE = 0.00521200
#
#
#  Epoch: 558  Val set RMSE = 0.00519633
#
#
#  Epoch: 559  Val set RMSE = 0.00518054
#
#
#  Epoch: 560  Val set RMSE = 0.00516457
#
#
#  Epoch: 561  Val set RMSE = 0.00514839
#
#
#  Epoch: 562  Val set RMSE = 0.00513215
#
#
#  Epoch: 563  Val set RMSE = 0.00511578
#
#
#  Epoch: 564  Val set RMSE = 0.00509936
#
#
#  Epoch: 565  Val set RMSE = 0.00508285
#
#
#  Epoch: 566  Val set RMSE = 0.00506648
#
#
#  Epoch: 567  Val set RMSE = 0.00505008
#
#
#  Epoch: 568  Val set RMSE = 0.00503381
#
#
#  Epoch: 569  Val set RMSE = 0.00501753
#
#
#  Epoch: 570  Val set RMSE = 0.00500148
#
#
#  Epoch: 571  Val set RMSE = 0.00498556
#
#
#  Epoch: 572  Val set RMSE = 0.00496981
#
#
#  Epoch: 573  Val set RMSE = 0.00495429
#
#
#  Epoch: 574  Val set RMSE = 0.00493893
#
#
#  Epoch: 575  Val set RMSE = 0.00492383
#
#
#  Epoch: 576  Val set RMSE = 0.00490898
#
#
#  Epoch: 577  Val set RMSE = 0.00489436
#
#
#  Epoch: 578  Val set RMSE = 0.00487990
#
#
#  Epoch: 579  Val set RMSE = 0.00486581
#
#
#  Epoch: 580  Val set RMSE = 0.00485186
#
#
#  Epoch: 581  Val set RMSE = 0.00483817
#
#
#  Epoch: 582  Val set RMSE = 0.00482472
#
#
#  Epoch: 583  Val set RMSE = 0.00481151
#
#
#  Epoch: 584  Val set RMSE = 0.00479846
#
#
#  Epoch: 585  Val set RMSE = 0.00478548
#
#
#  Epoch: 586  Val set RMSE = 0.00477276
#
#
#  Epoch: 587  Val set RMSE = 0.00476012
#
#
#  Epoch: 588  Val set RMSE = 0.00474750
#
#
#  Epoch: 589  Val set RMSE = 0.00473502
#
#
#  Epoch: 590  Val set RMSE = 0.00472254
#
#
#  Epoch: 591  Val set RMSE = 0.00471007
#
#
#  Epoch: 592  Val set RMSE = 0.00469743
#
#
#  Epoch: 593  Val set RMSE = 0.00468471
#
#
#  Epoch: 594  Val set RMSE = 0.00467176
#
#
#  Epoch: 595  Val set RMSE = 0.00465857
#
#
#  Epoch: 596  Val set RMSE = 0.00464493
#
#
#  Epoch: 597  Val set RMSE = 0.00463078
#
#
#  Epoch: 598  Val set RMSE = 0.00461605
#
#
#  Epoch: 599  Val set RMSE = 0.00460035
#
#
#  Epoch: 600  Val set RMSE = 0.00458374
#
#
#  Epoch: 601  Val set RMSE = 0.00456587
#
#
#  Epoch: 602  Val set RMSE = 0.00454666
#
#
#  Epoch: 603  Val set RMSE = 0.00452602
#
#
#  Epoch: 604  Val set RMSE = 0.00450401
#
#
#  Epoch: 605  Val set RMSE = 0.00448085
#
#
#  Epoch: 606  Val set RMSE = 0.00445693
#
#
#  Epoch: 607  Val set RMSE = 0.00443285
#
#
#  Epoch: 608  Val set RMSE = 0.00440939
#
#
#  Epoch: 609  Val set RMSE = 0.00438704
#
#
#  Epoch: 610  Val set RMSE = 0.00436626
#
#
#  Epoch: 611  Val set RMSE = 0.00434735
#
#
#  Epoch: 612  Val set RMSE = 0.00433018
#
#
#  Epoch: 613  Val set RMSE = 0.00431465
#
#
#  Epoch: 614  Val set RMSE = 0.00430056
#
#
#  Epoch: 615  Val set RMSE = 0.00428761
#
#
#  Epoch: 616  Val set RMSE = 0.00427556
#
#
#  Epoch: 617  Val set RMSE = 0.00426415
#
#
#  Epoch: 618  Val set RMSE = 0.00425315
#
#
#  Epoch: 619  Val set RMSE = 0.00424243
#
#
#  Epoch: 620  Val set RMSE = 0.00423190
#
#
#  Epoch: 621  Val set RMSE = 0.00422155
#
#
#  Epoch: 622  Val set RMSE = 0.00421141
#
#
#  Epoch: 623  Val set RMSE = 0.00420145
#
#
#  Epoch: 624  Val set RMSE = 0.00419169
#
#
#  Epoch: 625  Val set RMSE = 0.00418211
#
#
#  Epoch: 626  Val set RMSE = 0.00417269
#
#
#  Epoch: 627  Val set RMSE = 0.00416342
#
#
#  Epoch: 628  Val set RMSE = 0.00415429
#
#
#  Epoch: 629  Val set RMSE = 0.00414528
#
#
#  Epoch: 630  Val set RMSE = 0.00413636
#
#
#  Epoch: 631  Val set RMSE = 0.00412757
#
#
#  Epoch: 632  Val set RMSE = 0.00411886
#
#
#  Epoch: 633  Val set RMSE = 0.00411023
#
#
#  Epoch: 634  Val set RMSE = 0.00410168
#
#
#  Epoch: 635  Val set RMSE = 0.00409321
#
#
#  Epoch: 636  Val set RMSE = 0.00408483
#
#
#  Epoch: 637  Val set RMSE = 0.00407651
#
#
#  Epoch: 638  Val set RMSE = 0.00406826
#
#
#  Epoch: 639  Val set RMSE = 0.00406008
#
#
#  Epoch: 640  Val set RMSE = 0.00405197
#
#
#  Epoch: 641  Val set RMSE = 0.00404391
#
#
#  Epoch: 642  Val set RMSE = 0.00403591
#
#
#  Epoch: 643  Val set RMSE = 0.00402798
#
#
#  Epoch: 644  Val set RMSE = 0.00402011
#
#
#  Epoch: 645  Val set RMSE = 0.00401229
#
#
#  Epoch: 646  Val set RMSE = 0.00400453
#
#
#  Epoch: 647  Val set RMSE = 0.00399681
#
#
#  Epoch: 648  Val set RMSE = 0.00398917
#
#
#  Epoch: 649  Val set RMSE = 0.00398156
#
#
#  Epoch: 650  Val set RMSE = 0.00397401
#
#
#  Epoch: 651  Val set RMSE = 0.00396650
#
#
#  Epoch: 652  Val set RMSE = 0.00395906
#
#
#  Epoch: 653  Val set RMSE = 0.00395165
#
#
#  Epoch: 654  Val set RMSE = 0.00394429
#
#
#  Epoch: 655  Val set RMSE = 0.00393700
#
#
#  Epoch: 656  Val set RMSE = 0.00392973
#
#
#  Epoch: 657  Val set RMSE = 0.00392252
#
#
#  Epoch: 658  Val set RMSE = 0.00391537
#
#
#  Epoch: 659  Val set RMSE = 0.00390825
#
#
#  Epoch: 660  Val set RMSE = 0.00390117
#
#
#  Epoch: 661  Val set RMSE = 0.00389416
#
#
#  Epoch: 662  Val set RMSE = 0.00388717
#
#
#  Epoch: 663  Val set RMSE = 0.00388025
#
#
#  Epoch: 664  Val set RMSE = 0.00387335
#
#
#  Epoch: 665  Val set RMSE = 0.00386652
#
#
#  Epoch: 666  Val set RMSE = 0.00385972
#
#
#  Epoch: 667  Val set RMSE = 0.00385297
#
#
#  Epoch: 668  Val set RMSE = 0.00384627
#
#
#  Epoch: 669  Val set RMSE = 0.00383961
#
#
#  Epoch: 670  Val set RMSE = 0.00383298
#
#
#  Epoch: 671  Val set RMSE = 0.00382642
#
#
#  Epoch: 672  Val set RMSE = 0.00381989
#
#
#  Epoch: 673  Val set RMSE = 0.00381341
#
#
#  Epoch: 674  Val set RMSE = 0.00380696
#
#
#  Epoch: 675  Val set RMSE = 0.00380056
#
#
#  Epoch: 676  Val set RMSE = 0.00379422
#
#
#  Epoch: 677  Val set RMSE = 0.00378790
#
#
#  Epoch: 678  Val set RMSE = 0.00378163
#
#
#  Epoch: 679  Val set RMSE = 0.00377539
#
#
#  Epoch: 680  Val set RMSE = 0.00376921
#
#
#  Epoch: 681  Val set RMSE = 0.00376306
#
#
#  Epoch: 682  Val set RMSE = 0.00375694
#
#
#  Epoch: 683  Val set RMSE = 0.00375089
#
#
#  Epoch: 684  Val set RMSE = 0.00374485
#
#
#  Epoch: 685  Val set RMSE = 0.00373886
#
#
#  Epoch: 686  Val set RMSE = 0.00373290
#
#
#  Epoch: 687  Val set RMSE = 0.00372698
#
#
#  Epoch: 688  Val set RMSE = 0.00372110
#
#
#  Epoch: 689  Val set RMSE = 0.00371525
#
#
#  Epoch: 690  Val set RMSE = 0.00370947
#
#
#  Epoch: 691  Val set RMSE = 0.00370367
#
#
#  Epoch: 692  Val set RMSE = 0.00369794
#
#
#  Epoch: 693  Val set RMSE = 0.00369224
#
#
#  Epoch: 694  Val set RMSE = 0.00368658
#
#
#  Epoch: 695  Val set RMSE = 0.00368095
#
#
#  Epoch: 696  Val set RMSE = 0.00367534
#
#
#  Epoch: 697  Val set RMSE = 0.00366977
#
#
#  Epoch: 698  Val set RMSE = 0.00366422
#
#
#  Epoch: 699  Val set RMSE = 0.00365873
#
#
#  Epoch: 700  Val set RMSE = 0.00365326
#
#
#  Epoch: 701  Val set RMSE = 0.00364783
#
#
#  Epoch: 702  Val set RMSE = 0.00364241
#
#
#  Epoch: 703  Val set RMSE = 0.00363704
#
#
#  Epoch: 704  Val set RMSE = 0.00363168
#
#
#  Epoch: 705  Val set RMSE = 0.00362638
#
#
#  Epoch: 706  Val set RMSE = 0.00362108
#
#
#  Epoch: 707  Val set RMSE = 0.00361582
#
#
#  Epoch: 708  Val set RMSE = 0.00361058
#
#
#  Epoch: 709  Val set RMSE = 0.00360538
#
#
#  Epoch: 710  Val set RMSE = 0.00360019
#
#
#  Epoch: 711  Val set RMSE = 0.00359506
#
#
#  Epoch: 712  Val set RMSE = 0.00358994
#
#
#  Epoch: 713  Val set RMSE = 0.00358483
#
#
#  Epoch: 714  Val set RMSE = 0.00357977
#
#
#  Epoch: 715  Val set RMSE = 0.00357472
#
#
#  Epoch: 716  Val set RMSE = 0.00356969
#
#
#  Epoch: 717  Val set RMSE = 0.00356473
#
#
#  Epoch: 718  Val set RMSE = 0.00355974
#
#
#  Epoch: 719  Val set RMSE = 0.00355479
#
#
#  Epoch: 720  Val set RMSE = 0.00354987
#
#
#  Epoch: 721  Val set RMSE = 0.00354499
#
#
#  Epoch: 722  Val set RMSE = 0.00354015
#
#
#  Epoch: 723  Val set RMSE = 0.00353528
#
#
#  Epoch: 724  Val set RMSE = 0.00353046
#
#
#  Epoch: 725  Val set RMSE = 0.00352568
#
#
#  Epoch: 726  Val set RMSE = 0.00352089
#
#
#  Epoch: 727  Val set RMSE = 0.00351614
#
#
#  Epoch: 728  Val set RMSE = 0.00351141
#
#
#  Epoch: 729  Val set RMSE = 0.00350672
#
#
#  Epoch: 730  Val set RMSE = 0.00350202
#
#
#  Epoch: 731  Val set RMSE = 0.00349735
#
#
#  Epoch: 732  Val set RMSE = 0.00349274
#
#
#  Epoch: 733  Val set RMSE = 0.00348811
#
#
#  Epoch: 734  Val set RMSE = 0.00348354
#
#
#  Epoch: 735  Val set RMSE = 0.00347893
#
#
#  Epoch: 736  Val set RMSE = 0.00347440
#
#
#  Epoch: 737  Val set RMSE = 0.00346989
#
#
#  Epoch: 738  Val set RMSE = 0.00346536
#
#
#  Epoch: 739  Val set RMSE = 0.00346087
#
#
#  Epoch: 740  Val set RMSE = 0.00345644
#
#
#  Epoch: 741  Val set RMSE = 0.00345199
#
#
#  Epoch: 742  Val set RMSE = 0.00344756
#
#
#  Epoch: 743  Val set RMSE = 0.00344317
#
#
#  Epoch: 744  Val set RMSE = 0.00343876
#
#
#  Epoch: 745  Val set RMSE = 0.00343442
#
#
#  Epoch: 746  Val set RMSE = 0.00343005
#
#
#  Epoch: 747  Val set RMSE = 0.00342572
#
#
#  Epoch: 748  Val set RMSE = 0.00342145
#
#
#  Epoch: 749  Val set RMSE = 0.00341716
#
#
#  Epoch: 750  Val set RMSE = 0.00341290
#
#
#  Epoch: 751  Val set RMSE = 0.00340867
#
#
#  Epoch: 752  Val set RMSE = 0.00340440
#
#
#  Epoch: 753  Val set RMSE = 0.00340021
#
#
#  Epoch: 754  Val set RMSE = 0.00339603
#
#
#  Epoch: 755  Val set RMSE = 0.00339187
#
#
#  Epoch: 756  Val set RMSE = 0.00338768
#
#
#  Epoch: 757  Val set RMSE = 0.00338355
#
#
#  Epoch: 758  Val set RMSE = 0.00337943
#
#
#  Epoch: 759  Val set RMSE = 0.00337536
#
#
#  Epoch: 760  Val set RMSE = 0.00337123
#
#
#  Epoch: 761  Val set RMSE = 0.00336721
#
#
#  Epoch: 762  Val set RMSE = 0.00336314
#
#
#  Epoch: 763  Val set RMSE = 0.00335913
#
#
#  Epoch: 764  Val set RMSE = 0.00335513
#
#
#  Epoch: 765  Val set RMSE = 0.00335112
#
#
#  Epoch: 766  Val set RMSE = 0.00334711
#
#
#  Epoch: 767  Val set RMSE = 0.00334319
#
#
#  Epoch: 768  Val set RMSE = 0.00333924
#
#
#  Epoch: 769  Val set RMSE = 0.00333530
#
#
#  Epoch: 770  Val set RMSE = 0.00333139
#
#
#  Epoch: 771  Val set RMSE = 0.00332749
#
#
#  Epoch: 772  Val set RMSE = 0.00332360
#
#
#  Epoch: 773  Val set RMSE = 0.00331973
#
#
#  Epoch: 774  Val set RMSE = 0.00331592
#
#
#  Epoch: 775  Val set RMSE = 0.00331204
#
#
#  Epoch: 776  Val set RMSE = 0.00330827
#
#
#  Epoch: 777  Val set RMSE = 0.00330447
#
#
#  Epoch: 778  Val set RMSE = 0.00330067
#
#
#  Epoch: 779  Val set RMSE = 0.00329690
#
#
#  Epoch: 780  Val set RMSE = 0.00329312
#
#
#  Epoch: 781  Val set RMSE = 0.00328942
#
#
#  Epoch: 782  Val set RMSE = 0.00328566
#
#
#  Epoch: 783  Val set RMSE = 0.00328201
#
#
#  Epoch: 784  Val set RMSE = 0.00327827
#
#
#  Epoch: 785  Val set RMSE = 0.00327461
#
#
#  Epoch: 786  Val set RMSE = 0.00327096
#
#
#  Epoch: 787  Val set RMSE = 0.00326728
#
#
#  Epoch: 788  Val set RMSE = 0.00326366
#
#
#  Epoch: 789  Val set RMSE = 0.00326006
#
#
#  Epoch: 790  Val set RMSE = 0.00325647
#
#
#  Epoch: 791  Val set RMSE = 0.00325290
#
#
#  Epoch: 792  Val set RMSE = 0.00324930
#
#
#  Epoch: 793  Val set RMSE = 0.00324576
#
#
#  Epoch: 794  Val set RMSE = 0.00324220
#
#
#  Epoch: 795  Val set RMSE = 0.00323871
#
#
#  Epoch: 796  Val set RMSE = 0.00323519
#
#
#  Epoch: 797  Val set RMSE = 0.00323168
#
#
#  Epoch: 798  Val set RMSE = 0.00322824
#
#
#  Epoch: 799  Val set RMSE = 0.00322477
#
#
#  Epoch: 800  Val set RMSE = 0.00322132
#
#
#  Epoch: 801  Val set RMSE = 0.00321792
#
#
#  Epoch: 802  Val set RMSE = 0.00321448
#
#
#  Epoch: 803  Val set RMSE = 0.00321110
#
#
#  Epoch: 804  Val set RMSE = 0.00320773
#
#
#  Epoch: 805  Val set RMSE = 0.00320436
#
#
#  Epoch: 806  Val set RMSE = 0.00320101
#
#
#  Epoch: 807  Val set RMSE = 0.00319764
#
#
#  Epoch: 808  Val set RMSE = 0.00319436
#
#
#  Epoch: 809  Val set RMSE = 0.00319106
#
#
#  Epoch: 810  Val set RMSE = 0.00318775
#
#
#  Epoch: 811  Val set RMSE = 0.00318452
#
#
#  Epoch: 812  Val set RMSE = 0.00318125
#
#
#  Epoch: 813  Val set RMSE = 0.00317803
#
#
#  Epoch: 814  Val set RMSE = 0.00317482
#
#
#  Epoch: 815  Val set RMSE = 0.00317155
#
#
#  Epoch: 816  Val set RMSE = 0.00316840
#
#
#  Epoch: 817  Val set RMSE = 0.00316524
#
#
#  Epoch: 818  Val set RMSE = 0.00316206
#
#
#  Epoch: 819  Val set RMSE = 0.00315894
#
#
#  Epoch: 820  Val set RMSE = 0.00315581
#
#
#  Epoch: 821  Val set RMSE = 0.00315268
#
#
#  Epoch: 822  Val set RMSE = 0.00314961
#
#
#  Epoch: 823  Val set RMSE = 0.00314652
#
#
#  Epoch: 824  Val set RMSE = 0.00314346
#
#
#  Epoch: 825  Val set RMSE = 0.00314044
#
#
#  Epoch: 826  Val set RMSE = 0.00313740
#
#
#  Epoch: 827  Val set RMSE = 0.00313438
#
#
#  Epoch: 828  Val set RMSE = 0.00313139
#
#
#  Epoch: 829  Val set RMSE = 0.00312841
#
#
#  Epoch: 830  Val set RMSE = 0.00312546
#
#
#  Epoch: 831  Val set RMSE = 0.00312251
#
#
#  Epoch: 832  Val set RMSE = 0.00311954
#
#
#  Epoch: 833  Val set RMSE = 0.00311662
#
#
#  Epoch: 834  Val set RMSE = 0.00311368
#
#
#  Epoch: 835  Val set RMSE = 0.00311083
#
#
#  Epoch: 836  Val set RMSE = 0.00310795
#
#
#  Epoch: 837  Val set RMSE = 0.00310507
#
#
#  Epoch: 838  Val set RMSE = 0.00310227
#
#
#  Epoch: 839  Val set RMSE = 0.00309943
#
#
#  Epoch: 840  Val set RMSE = 0.00309657
#
#
#  Epoch: 841  Val set RMSE = 0.00309379
#
#
#  Epoch: 842  Val set RMSE = 0.00309098
#
#
#  Epoch: 843  Val set RMSE = 0.00308819
#
#
#  Epoch: 844  Val set RMSE = 0.00308545
#
#
#  Epoch: 845  Val set RMSE = 0.00308271
#
#
#  Epoch: 846  Val set RMSE = 0.00307999
#
#
#  Epoch: 847  Val set RMSE = 0.00307724
#
#
#  Epoch: 848  Val set RMSE = 0.00307456
#
#
#  Epoch: 849  Val set RMSE = 0.00307185
#
#
#  Epoch: 850  Val set RMSE = 0.00306921
#
#
#  Epoch: 851  Val set RMSE = 0.00306651
#
#
#  Epoch: 852  Val set RMSE = 0.00306388
#
#
#  Epoch: 853  Val set RMSE = 0.00306123
#
#
#  Epoch: 854  Val set RMSE = 0.00305859
#
#
#  Epoch: 855  Val set RMSE = 0.00305599
#
#
#  Epoch: 856  Val set RMSE = 0.00305340
#
#
#  Epoch: 857  Val set RMSE = 0.00305079
#
#
#  Epoch: 858  Val set RMSE = 0.00304821
#
#
#  Epoch: 859  Val set RMSE = 0.00304564
#
#
#  Epoch: 860  Val set RMSE = 0.00304311
#
#
#  Epoch: 861  Val set RMSE = 0.00304055
#
#
#  Epoch: 862  Val set RMSE = 0.00303805
#
#
#  Epoch: 863  Val set RMSE = 0.00303551
#
#
#  Epoch: 864  Val set RMSE = 0.00303304
#
#
#  Epoch: 865  Val set RMSE = 0.00303053
#
#
#  Epoch: 866  Val set RMSE = 0.00302805
#
#
#  Epoch: 867  Val set RMSE = 0.00302558
#
#
#  Epoch: 868  Val set RMSE = 0.00302313
#
#
#  Epoch: 869  Val set RMSE = 0.00302070
#
#
#  Epoch: 870  Val set RMSE = 0.00301826
#
#
#  Epoch: 871  Val set RMSE = 0.00301580
#
#
#  Epoch: 872  Val set RMSE = 0.00301340
#
#
#  Epoch: 873  Val set RMSE = 0.00301106
#
#
#  Epoch: 874  Val set RMSE = 0.00300865
#
#
#  Epoch: 875  Val set RMSE = 0.00300629
#
#
#  Epoch: 876  Val set RMSE = 0.00300390
#
#
#  Epoch: 877  Val set RMSE = 0.00300156
#
#
#  Epoch: 878  Val set RMSE = 0.00299919
#
#
#  Epoch: 879  Val set RMSE = 0.00299687
#
#
#  Epoch: 880  Val set RMSE = 0.00299456
#
#
#  Epoch: 881  Val set RMSE = 0.00299225
#
#
#  Epoch: 882  Val set RMSE = 0.00298995
#
#
#  Epoch: 883  Val set RMSE = 0.00298763
#
#
#  Epoch: 884  Val set RMSE = 0.00298534
#
#
#  Epoch: 885  Val set RMSE = 0.00298306
#
#
#  Epoch: 886  Val set RMSE = 0.00298082
#
#
#  Epoch: 887  Val set RMSE = 0.00297853
#
#
#  Epoch: 888  Val set RMSE = 0.00297631
#
#
#  Epoch: 889  Val set RMSE = 0.00297408
#
#
#  Epoch: 890  Val set RMSE = 0.00297184
#
#
#  Epoch: 891  Val set RMSE = 0.00296964
#
#
#  Epoch: 892  Val set RMSE = 0.00296740
#
#
#  Epoch: 893  Val set RMSE = 0.00296522
#
#
#  Epoch: 894  Val set RMSE = 0.00296307
#
#
#  Epoch: 895  Val set RMSE = 0.00296092
#
#
#  Epoch: 896  Val set RMSE = 0.00295870
#
#
#  Epoch: 897  Val set RMSE = 0.00295659
#
#
#  Epoch: 898  Val set RMSE = 0.00295444
#
#
#  Epoch: 899  Val set RMSE = 0.00295221
#
#
#  Epoch: 900  Val set RMSE = 0.00295013
#
#
#  Epoch: 901  Val set RMSE = 0.00294799
#
#
#  Epoch: 902  Val set RMSE = 0.00294591
#
#
#  Epoch: 903  Val set RMSE = 0.00294380
#
#
#  Epoch: 904  Val set RMSE = 0.00294171
#
#
#  Epoch: 905  Val set RMSE = 0.00293957
#
#
#  Epoch: 906  Val set RMSE = 0.00293751
#
#
#  Epoch: 907  Val set RMSE = 0.00293544
#
#
#  Epoch: 908  Val set RMSE = 0.00293339
#
#
#  Epoch: 909  Val set RMSE = 0.00293134
#
#
#  Epoch: 910  Val set RMSE = 0.00292932
#
#
#  Epoch: 911  Val set RMSE = 0.00292726
#
#
#  Epoch: 912  Val set RMSE = 0.00292521
#
#
#  Epoch: 913  Val set RMSE = 0.00292322
#
#
#  Epoch: 914  Val set RMSE = 0.00292119
#
#
#  Epoch: 915  Val set RMSE = 0.00291922
#
#
#  Epoch: 916  Val set RMSE = 0.00291718
#
#
#  Epoch: 917  Val set RMSE = 0.00291526
#
#
#  Epoch: 918  Val set RMSE = 0.00291327
#
#
#  Epoch: 919  Val set RMSE = 0.00291129
#
#
#  Epoch: 920  Val set RMSE = 0.00290931
#
#
#  Epoch: 921  Val set RMSE = 0.00290737
#
#
#  Epoch: 922  Val set RMSE = 0.00290544
#
#
#  Epoch: 923  Val set RMSE = 0.00290353
#
#
#  Epoch: 924  Val set RMSE = 0.00290157
#
#
#  Epoch: 925  Val set RMSE = 0.00289964
#
#
#  Epoch: 926  Val set RMSE = 0.00289776
#
#
#  Epoch: 927  Val set RMSE = 0.00289585
#
#
#  Epoch: 928  Val set RMSE = 0.00289396
#
#
#  Epoch: 929  Val set RMSE = 0.00289207
#
#
#  Epoch: 930  Val set RMSE = 0.00289018
#
#
#  Epoch: 931  Val set RMSE = 0.00288834
#
#
#  Epoch: 932  Val set RMSE = 0.00288644
#
#
#  Epoch: 933  Val set RMSE = 0.00288465
#
#
#  Epoch: 934  Val set RMSE = 0.00288278
#
#
#  Epoch: 935  Val set RMSE = 0.00288095
#
#
#  Epoch: 936  Val set RMSE = 0.00287911
#
#
#  Epoch: 937  Val set RMSE = 0.00287730
#
#
#  Epoch: 938  Val set RMSE = 0.00287551
#
#
#  Epoch: 939  Val set RMSE = 0.00287366
#
#
#  Epoch: 940  Val set RMSE = 0.00287188
#
#
#  Epoch: 941  Val set RMSE = 0.00287009
#
#
#  Epoch: 942  Val set RMSE = 0.00286833
#
#
#  Epoch: 943  Val set RMSE = 0.00286658
#
#
#  Epoch: 944  Val set RMSE = 0.00286479
#
#
#  Epoch: 945  Val set RMSE = 0.00286305
#
#
#  Epoch: 946  Val set RMSE = 0.00286130
#
#
#  Epoch: 947  Val set RMSE = 0.00285952
#
#
#  Epoch: 948  Val set RMSE = 0.00285780
#
#
#  Epoch: 949  Val set RMSE = 0.00285611
#
#
#  Epoch: 950  Val set RMSE = 0.00285443
#
#
#  Epoch: 951  Val set RMSE = 0.00285268
#
#
#  Epoch: 952  Val set RMSE = 0.00285099
#
#
#  Epoch: 953  Val set RMSE = 0.00284929
#
#
#  Epoch: 954  Val set RMSE = 0.00284763
#
#
#  Epoch: 955  Val set RMSE = 0.00284597
#
#
#  Epoch: 956  Val set RMSE = 0.00284427
#
#
#  Epoch: 957  Val set RMSE = 0.00284262
#
#
#  Epoch: 958  Val set RMSE = 0.00284097
#
#
#  Epoch: 959  Val set RMSE = 0.00283936
#
#
#  Epoch: 960  Val set RMSE = 0.00283773
#
#
#  Epoch: 961  Val set RMSE = 0.00283612
#
#
#  Epoch: 962  Val set RMSE = 0.00283445
#
#
#  Epoch: 963  Val set RMSE = 0.00283283
#
#
#  Epoch: 964  Val set RMSE = 0.00283128
#
#
#  Epoch: 965  Val set RMSE = 0.00282968
#
#
#  Epoch: 966  Val set RMSE = 0.00282808
#
#
#  Epoch: 967  Val set RMSE = 0.00282649
#
#
#  Epoch: 968  Val set RMSE = 0.00282496
#
#
#  Epoch: 969  Val set RMSE = 0.00282341
#
#
#  Epoch: 970  Val set RMSE = 0.00282186
#
#
#  Epoch: 971  Val set RMSE = 0.00282031
#
#
#  Epoch: 972  Val set RMSE = 0.00281879
#
#
#  Epoch: 973  Val set RMSE = 0.00281724
#
#
#  Epoch: 974  Val set RMSE = 0.00281571
#
#
#  Epoch: 975  Val set RMSE = 0.00281424
#
#
#  Epoch: 976  Val set RMSE = 0.00281270
#
#
#  Epoch: 977  Val set RMSE = 0.00281124
#
#
#  Epoch: 978  Val set RMSE = 0.00280971
#
#
#  Epoch: 979  Val set RMSE = 0.00280824
#
#
#  Epoch: 980  Val set RMSE = 0.00280679
#
#
#  Epoch: 981  Val set RMSE = 0.00280531
#
#
#  Epoch: 982  Val set RMSE = 0.00280386
#
#
#  Epoch: 983  Val set RMSE = 0.00280240
#
#
#  Epoch: 984  Val set RMSE = 0.00280096
#
#
#  Epoch: 985  Val set RMSE = 0.00279953
#
#
#  Epoch: 986  Val set RMSE = 0.00279814
#
#
#  Epoch: 987  Val set RMSE = 0.00279670
#
#
#  Epoch: 988  Val set RMSE = 0.00279532
#
#
#  Epoch: 989  Val set RMSE = 0.00279390
#
#
#  Epoch: 990  Val set RMSE = 0.00279250
#
#
#  Epoch: 991  Val set RMSE = 0.00279109
#
#
#  Epoch: 992  Val set RMSE = 0.00278969
#
#
#  Epoch: 993  Val set RMSE = 0.00278835
#
#
#  Epoch: 994  Val set RMSE = 0.00278698
#
#
#  Epoch: 995  Val set RMSE = 0.00278558
#
#
#  Epoch: 996  Val set RMSE = 0.00278431
#
#
#  Epoch: 997  Val set RMSE = 0.00278296
#
#
#  Epoch: 998  Val set RMSE = 0.00278162
#
#
#  Epoch: 999  Val set RMSE = 0.00278028
#
# Average time taken for a single epoch is 4.805369 seconds.
#
#  Test set RMSE = 0.00985726
#
# 0.0005526133
#
#  Epoch: 1  Val set RMSE = 0.12480950
#
#
#  Epoch: 2  Val set RMSE = 0.12170290
#
#
#  Epoch: 3  Val set RMSE = 0.12136217
#
#
#  Epoch: 4  Val set RMSE = 0.12130937
#
#
#  Epoch: 5  Val set RMSE = 0.12126492
#
#
#  Epoch: 6  Val set RMSE = 0.12121714
#
#
#  Epoch: 7  Val set RMSE = 0.12116535
#
#
#  Epoch: 8  Val set RMSE = 0.12110824
#
#
#  Epoch: 9  Val set RMSE = 0.12104317
#
#
#  Epoch: 10  Val set RMSE = 0.12096663
#
#
#  Epoch: 11  Val set RMSE = 0.12087269
#
#
#  Epoch: 12  Val set RMSE = 0.12074983
#
#
#  Epoch: 13  Val set RMSE = 0.12058503
#
#
#  Epoch: 14  Val set RMSE = 0.12036794
#
#
#  Epoch: 15  Val set RMSE = 0.12009210
#
#
#  Epoch: 16  Val set RMSE = 0.11975354
#
#
#  Epoch: 17  Val set RMSE = 0.11936185
#
#
#  Epoch: 18  Val set RMSE = 0.11897825
#
#
#  Epoch: 19  Val set RMSE = 0.11868064
#
#
#  Epoch: 20  Val set RMSE = 0.11846980
#
#
#  Epoch: 21  Val set RMSE = 0.11830086
#
#
#  Epoch: 22  Val set RMSE = 0.11814932
#
#
#  Epoch: 23  Val set RMSE = 0.11800614
#
#
#  Epoch: 24  Val set RMSE = 0.11786508
#
#
#  Epoch: 25  Val set RMSE = 0.11771675
#
#
#  Epoch: 26  Val set RMSE = 0.11754814
#
#
#  Epoch: 27  Val set RMSE = 0.11733970
#
#
#  Epoch: 28  Val set RMSE = 0.11705633
#
#
#  Epoch: 29  Val set RMSE = 0.11662765
#
#
#  Epoch: 30  Val set RMSE = 0.11589569
#
#
#  Epoch: 31  Val set RMSE = 0.11447082
#
#
#  Epoch: 32  Val set RMSE = 0.11134124
#
#
#  Epoch: 33  Val set RMSE = 0.10426333
#
#
#  Epoch: 34  Val set RMSE = 0.09261759
#
#
#  Epoch: 35  Val set RMSE = 0.08359850
#
#
#  Epoch: 36  Val set RMSE = 0.07777332
#
#
#  Epoch: 37  Val set RMSE = 0.07244073
#
#
#  Epoch: 38  Val set RMSE = 0.06696353
#
#
#  Epoch: 39  Val set RMSE = 0.06131017
#
#
#  Epoch: 40  Val set RMSE = 0.05592364
#
#
#  Epoch: 41  Val set RMSE = 0.05115871
#
#
#  Epoch: 42  Val set RMSE = 0.04715604
#
#
#  Epoch: 43  Val set RMSE = 0.04389843
#
#
#  Epoch: 44  Val set RMSE = 0.04123822
#
#
#  Epoch: 45  Val set RMSE = 0.03901606
#
#
#  Epoch: 46  Val set RMSE = 0.03714562
#
#
#  Epoch: 47  Val set RMSE = 0.03560287
#
#
#  Epoch: 48  Val set RMSE = 0.03438555
#
#
#  Epoch: 49  Val set RMSE = 0.03345047
#
#
#  Epoch: 50  Val set RMSE = 0.03271221
#
#
#  Epoch: 51  Val set RMSE = 0.03208254
#
#
#  Epoch: 52  Val set RMSE = 0.03150084
#
#
#  Epoch: 53  Val set RMSE = 0.03093219
#
#
#  Epoch: 54  Val set RMSE = 0.03035543
#
#
#  Epoch: 55  Val set RMSE = 0.02975443
#
#
#  Epoch: 56  Val set RMSE = 0.02911004
#
#
#  Epoch: 57  Val set RMSE = 0.02840145
#
#
#  Epoch: 58  Val set RMSE = 0.02763814
#
#
#  Epoch: 59  Val set RMSE = 0.02687637
#
#
#  Epoch: 60  Val set RMSE = 0.02619517
#
#
#  Epoch: 61  Val set RMSE = 0.02563907
#
#
#  Epoch: 62  Val set RMSE = 0.02520337
#
#
#  Epoch: 63  Val set RMSE = 0.02486331
#
#
#  Epoch: 64  Val set RMSE = 0.02459288
#
#
#  Epoch: 65  Val set RMSE = 0.02436929
#
#
#  Epoch: 66  Val set RMSE = 0.02417360
#
#
#  Epoch: 67  Val set RMSE = 0.02399085
#
#
#  Epoch: 68  Val set RMSE = 0.02380978
#
#
#  Epoch: 69  Val set RMSE = 0.02362244
#
#
#  Epoch: 70  Val set RMSE = 0.02342404
#
#
#  Epoch: 71  Val set RMSE = 0.02321258
#
#
#  Epoch: 72  Val set RMSE = 0.02298753
#
#
#  Epoch: 73  Val set RMSE = 0.02274820
#
#
#  Epoch: 74  Val set RMSE = 0.02249291
#
#
#  Epoch: 75  Val set RMSE = 0.02221907
#
#
#  Epoch: 76  Val set RMSE = 0.02192383
#
#
#  Epoch: 77  Val set RMSE = 0.02160474
#
#
#  Epoch: 78  Val set RMSE = 0.02126137
#
#
#  Epoch: 79  Val set RMSE = 0.02089713
#
#
#  Epoch: 80  Val set RMSE = 0.02052146
#
#
#  Epoch: 81  Val set RMSE = 0.02014975
#
#
#  Epoch: 82  Val set RMSE = 0.01980028
#
#
#  Epoch: 83  Val set RMSE = 0.01948764
#
#
#  Epoch: 84  Val set RMSE = 0.01921791
#
#
#  Epoch: 85  Val set RMSE = 0.01898835
#
#
#  Epoch: 86  Val set RMSE = 0.01879159
#
#
#  Epoch: 87  Val set RMSE = 0.01861973
#
#
#  Epoch: 88  Val set RMSE = 0.01846650
#
#
#  Epoch: 89  Val set RMSE = 0.01832757
#
#
#  Epoch: 90  Val set RMSE = 0.01820000
#
#
#  Epoch: 91  Val set RMSE = 0.01808194
#
#
#  Epoch: 92  Val set RMSE = 0.01797207
#
#
#  Epoch: 93  Val set RMSE = 0.01786947
#
#
#  Epoch: 94  Val set RMSE = 0.01777326
#
#
#  Epoch: 95  Val set RMSE = 0.01768279
#
#
#  Epoch: 96  Val set RMSE = 0.01759724
#
#
#  Epoch: 97  Val set RMSE = 0.01751601
#
#
#  Epoch: 98  Val set RMSE = 0.01743837
#
#
#  Epoch: 99  Val set RMSE = 0.01736372
#
#
#  Epoch: 100  Val set RMSE = 0.01729156
#
#
#  Epoch: 101  Val set RMSE = 0.01722147
#
#
#  Epoch: 102  Val set RMSE = 0.01715295
#
#
#  Epoch: 103  Val set RMSE = 0.01708579
#
#
#  Epoch: 104  Val set RMSE = 0.01701974
#
#
#  Epoch: 105  Val set RMSE = 0.01695461
#
#
#  Epoch: 106  Val set RMSE = 0.01689025
#
#
#  Epoch: 107  Val set RMSE = 0.01682661
#
#
#  Epoch: 108  Val set RMSE = 0.01676360
#
#
#  Epoch: 109  Val set RMSE = 0.01670124
#
#
#  Epoch: 110  Val set RMSE = 0.01663949
#
#
#  Epoch: 111  Val set RMSE = 0.01657836
#
#
#  Epoch: 112  Val set RMSE = 0.01651789
#
#
#  Epoch: 113  Val set RMSE = 0.01645814
#
#
#  Epoch: 114  Val set RMSE = 0.01639906
#
#
#  Epoch: 115  Val set RMSE = 0.01634074
#
#
#  Epoch: 116  Val set RMSE = 0.01628325
#
#
#  Epoch: 117  Val set RMSE = 0.01622658
#
#
#  Epoch: 118  Val set RMSE = 0.01617070
#
#
#  Epoch: 119  Val set RMSE = 0.01611566
#
#
#  Epoch: 120  Val set RMSE = 0.01606147
#
#
#  Epoch: 121  Val set RMSE = 0.01600810
#
#
#  Epoch: 122  Val set RMSE = 0.01595552
#
#
#  Epoch: 123  Val set RMSE = 0.01590374
#
#
#  Epoch: 124  Val set RMSE = 0.01585270
#
#
#  Epoch: 125  Val set RMSE = 0.01580239
#
#
#  Epoch: 126  Val set RMSE = 0.01575278
#
#
#  Epoch: 127  Val set RMSE = 0.01570382
#
#
#  Epoch: 128  Val set RMSE = 0.01565550
#
#
#  Epoch: 129  Val set RMSE = 0.01560774
#
#
#  Epoch: 130  Val set RMSE = 0.01556059
#
#
#  Epoch: 131  Val set RMSE = 0.01551396
#
#
#  Epoch: 132  Val set RMSE = 0.01546790
#
#
#  Epoch: 133  Val set RMSE = 0.01542237
#
#
#  Epoch: 134  Val set RMSE = 0.01537738
#
#
#  Epoch: 135  Val set RMSE = 0.01533286
#
#
#  Epoch: 136  Val set RMSE = 0.01528888
#
#
#  Epoch: 137  Val set RMSE = 0.01524543
#
#
#  Epoch: 138  Val set RMSE = 0.01520249
#
#
#  Epoch: 139  Val set RMSE = 0.01516008
#
#
#  Epoch: 140  Val set RMSE = 0.01511823
#
#
#  Epoch: 141  Val set RMSE = 0.01507691
#
#
#  Epoch: 142  Val set RMSE = 0.01503615
#
#
#  Epoch: 143  Val set RMSE = 0.01499596
#
#
#  Epoch: 144  Val set RMSE = 0.01495635
#
#
#  Epoch: 145  Val set RMSE = 0.01491731
#
#
#  Epoch: 146  Val set RMSE = 0.01487887
#
#
# ...
#
#
#  Epoch: 622  Val set RMSE = 0.49988973
#
#
#  Epoch: 623  Val set RMSE = 0.49989014
#
#
#  Epoch: 624  Val set RMSE = 0.49989048
#
#
#  Epoch: 625  Val set RMSE = 0.49989031
#
#
#  Epoch: 626  Val set RMSE = 0.49988977
#
#
#  Epoch: 627  Val set RMSE = 0.49988925
#
#
#  Epoch: 628  Val set RMSE = 0.49988904
#
#
#  Epoch: 629  Val set RMSE = 0.49988894
#
#
#  Epoch: 630  Val set RMSE = 0.49988839
#
#
#  Epoch: 631  Val set RMSE = 0.49988732
#
#
#  Epoch: 632  Val set RMSE = 0.49988667
#
#
#  Epoch: 633  Val set RMSE = 0.49988626
#
#
#  Epoch: 634  Val set RMSE = 0.49988602
#
#
#  Epoch: 635  Val set RMSE = 0.49988639
#
#
#  Epoch: 636  Val set RMSE = 0.49988681
#
#
#  Epoch: 637  Val set RMSE = 0.49988676
#
#
#  Epoch: 638  Val set RMSE = 0.49988625
#
#
#  Epoch: 639  Val set RMSE = 0.49988572
#
#
#  Epoch: 640  Val set RMSE = 0.49988555
#
#
#  Epoch: 641  Val set RMSE = 0.49988551
#
#
#  Epoch: 642  Val set RMSE = 0.49988500
#
#
#  Epoch: 643  Val set RMSE = 0.49988391
#
#
#  Epoch: 644  Val set RMSE = 0.49988316
#
#
#  Epoch: 645  Val set RMSE = 0.49988282
#
#
#  Epoch: 646  Val set RMSE = 0.49988270
#
#
#  Epoch: 647  Val set RMSE = 0.49988308
#
#
#  Epoch: 648  Val set RMSE = 0.49988347
#
#
#  Epoch: 649  Val set RMSE = 0.49988341
#
#
#  Epoch: 650  Val set RMSE = 0.49988289
#
#
#  Epoch: 651  Val set RMSE = 0.49988240
#
#
#  Epoch: 652  Val set RMSE = 0.49988228
#
#
#  Epoch: 653  Val set RMSE = 0.49988222
#
#
#  Epoch: 654  Val set RMSE = 0.49988164
#
#
#  Epoch: 655  Val set RMSE = 0.49988053
#
#
#  Epoch: 656  Val set RMSE = 0.49987987
#
#
#  Epoch: 657  Val set RMSE = 0.49987956
#
#
#  Epoch: 658  Val set RMSE = 0.49987955
#
#
#  Epoch: 659  Val set RMSE = 0.49987999
#
#
#  Epoch: 660  Val set RMSE = 0.49988034
#
#
#  Epoch: 661  Val set RMSE = 0.49988020
#
#
#  Epoch: 662  Val set RMSE = 0.49987971
#
#
#  Epoch: 663  Val set RMSE = 0.49987935
#
#
#  Epoch: 664  Val set RMSE = 0.49987926
#
#
#  Epoch: 665  Val set RMSE = 0.49987909
#
#
#  Epoch: 666  Val set RMSE = 0.49987831
#
#
#  Epoch: 667  Val set RMSE = 0.49987727
#
#
#  Epoch: 668  Val set RMSE = 0.49987682
#
#
#  Epoch: 669  Val set RMSE = 0.49987652
#
#
#  Epoch: 670  Val set RMSE = 0.49987663
#
#
#  Epoch: 671  Val set RMSE = 0.49987711
#
#
#  Epoch: 672  Val set RMSE = 0.49987734
#
#
#  Epoch: 673  Val set RMSE = 0.49987709
#
#
#  Epoch: 674  Val set RMSE = 0.49987670
#
#
#  Epoch: 675  Val set RMSE = 0.49987648
#
#
#  Epoch: 676  Val set RMSE = 0.49987638
#
#
#  Epoch: 677  Val set RMSE = 0.49987596
#
#
#  Epoch: 678  Val set RMSE = 0.49987497
#
#
#  Epoch: 679  Val set RMSE = 0.49987426
#
#
#  Epoch: 680  Val set RMSE = 0.49987394
#
#
#  Epoch: 681  Val set RMSE = 0.49987371
#
#
#  Epoch: 682  Val set RMSE = 0.49987398
#
#
#  Epoch: 683  Val set RMSE = 0.49987440
#
#
#  Epoch: 684  Val set RMSE = 0.49987442
#
#
#  Epoch: 685  Val set RMSE = 0.49987416
#
#
#  Epoch: 686  Val set RMSE = 0.49987393
#
#
#  Epoch: 687  Val set RMSE = 0.49987376
#
#
#  Epoch: 688  Val set RMSE = 0.49987351
#
#
#  Epoch: 689  Val set RMSE = 0.49987274
#
#
#  Epoch: 690  Val set RMSE = 0.49987187
#
#
#  Epoch: 691  Val set RMSE = 0.49987152
#
#
#  Epoch: 692  Val set RMSE = 0.49987117
#
#
#  Epoch: 693  Val set RMSE = 0.49987109
#
#
#  Epoch: 694  Val set RMSE = 0.49987149
#
#
#  Epoch: 695  Val set RMSE = 0.49987173
#
#
#  Epoch: 696  Val set RMSE = 0.49987163
#
#
#  Epoch: 697  Val set RMSE = 0.49987151
#
#
#  Epoch: 698  Val set RMSE = 0.49987133
#
#
#  Epoch: 699  Val set RMSE = 0.49987107
#
#
#  Epoch: 700  Val set RMSE = 0.49987048
#
#
#  Epoch: 701  Val set RMSE = 0.49986962
#
#
#  Epoch: 702  Val set RMSE = 0.49986921
#
#
#  Epoch: 703  Val set RMSE = 0.49986887
#
#
#  Epoch: 704  Val set RMSE = 0.49986852
#
#
#  Epoch: 705  Val set RMSE = 0.49986870
#
#
#  Epoch: 706  Val set RMSE = 0.49986904
#
#
#  Epoch: 707  Val set RMSE = 0.49986910
#
#
#  Epoch: 708  Val set RMSE = 0.49986912
#
#
#  Epoch: 709  Val set RMSE = 0.49986905
#
#
#  Epoch: 710  Val set RMSE = 0.49986873
#
#
#  Epoch: 711  Val set RMSE = 0.49986821
#
#
#  Epoch: 712  Val set RMSE = 0.49986743
#
#
#  Epoch: 713  Val set RMSE = 0.49986698
#
#
#  Epoch: 714  Val set RMSE = 0.49986670
#
#
#  Epoch: 715  Val set RMSE = 0.49986624
#
#
#  Epoch: 716  Val set RMSE = 0.49986613
#
#
#  Epoch: 717  Val set RMSE = 0.49986642
#
#
#  Epoch: 718  Val set RMSE = 0.49986659
#
#
#  Epoch: 719  Val set RMSE = 0.49986673
#
#
#  Epoch: 720  Val set RMSE = 0.49986682
#
#
#  Epoch: 721  Val set RMSE = 0.49986652
#
#
#  Epoch: 722  Val set RMSE = 0.49986598
#
#
#  Epoch: 723  Val set RMSE = 0.49986528
#
#
#  Epoch: 724  Val set RMSE = 0.49986483
#
#
#  Epoch: 725  Val set RMSE = 0.49986460
#
#
#  Epoch: 726  Val set RMSE = 0.49986414
#
#
#  Epoch: 727  Val set RMSE = 0.49986378
#
#
#  Epoch: 728  Val set RMSE = 0.49986390
#
#
#  Epoch: 729  Val set RMSE = 0.49986411
#
#
#  Epoch: 730  Val set RMSE = 0.49986436
#
#
#  Epoch: 731  Val set RMSE = 0.49986461
#
#
#  Epoch: 732  Val set RMSE = 0.49986443
#
#
#  Epoch: 733  Val set RMSE = 0.49986384
#
#
#  Epoch: 734  Val set RMSE = 0.49986317
#
#
#  Epoch: 735  Val set RMSE = 0.49986276
#
#
#  Epoch: 736  Val set RMSE = 0.49986257
#
#
#  Epoch: 737  Val set RMSE = 0.49986218
#
#
#  Epoch: 738  Val set RMSE = 0.49986166
#
#
#  Epoch: 739  Val set RMSE = 0.49986152
#
#
#  Epoch: 740  Val set RMSE = 0.49986168
#
#
#  Epoch: 741  Val set RMSE = 0.49986198
#
#
#  Epoch: 742  Val set RMSE = 0.49986238
#
#
#  Epoch: 743  Val set RMSE = 0.49986239
#
#
#  Epoch: 744  Val set RMSE = 0.49986181
#
#
#  Epoch: 745  Val set RMSE = 0.49986110
#
#
#  Epoch: 746  Val set RMSE = 0.49986075
#
#
#  Epoch: 747  Val set RMSE = 0.49986062
#
#
#  Epoch: 748  Val set RMSE = 0.49986029
#
#
#  Epoch: 749  Val set RMSE = 0.49985975
#
#
#  Epoch: 750  Val set RMSE = 0.49985934
#
#
#  Epoch: 751  Val set RMSE = 0.49985929
#
#
#  Epoch: 752  Val set RMSE = 0.49985958
#
#
#  Epoch: 753  Val set RMSE = 0.49986009
#
#
#  Epoch: 754  Val set RMSE = 0.49986032
#
#
#  Epoch: 755  Val set RMSE = 0.49985989
#
#
#  Epoch: 756  Val set RMSE = 0.49985911
#
#
#  Epoch: 757  Val set RMSE = 0.49985879
#
#
#  Epoch: 758  Val set RMSE = 0.49985874
#
#
#  Epoch: 759  Val set RMSE = 0.49985850
#
#
#  Epoch: 760  Val set RMSE = 0.49985800
#
#
#  Epoch: 761  Val set RMSE = 0.49985742
#
#
#  Epoch: 762  Val set RMSE = 0.49985704
#
#
#  Epoch: 763  Val set RMSE = 0.49985715
#
#
#  Epoch: 764  Val set RMSE = 0.49985768
#
#
#  Epoch: 765  Val set RMSE = 0.49985812
#
#
#  Epoch: 766  Val set RMSE = 0.49985795
#
#
#  Epoch: 767  Val set RMSE = 0.49985722
#
#
#  Epoch: 768  Val set RMSE = 0.49985689
#
#
#  Epoch: 769  Val set RMSE = 0.49985695
#
#
#  Epoch: 770  Val set RMSE = 0.49985680
#
#
#  Epoch: 771  Val set RMSE = 0.49985636
#
#
#  Epoch: 772  Val set RMSE = 0.49985573
#
#
#  Epoch: 773  Val set RMSE = 0.49985505
#
#
#  Epoch: 774  Val set RMSE = 0.49985479
#
#
#  Epoch: 775  Val set RMSE = 0.49985516
#
#
#  Epoch: 776  Val set RMSE = 0.49985567
#
#
#  Epoch: 777  Val set RMSE = 0.49985578
#
#
#  Epoch: 778  Val set RMSE = 0.49985528
#
#
#  Epoch: 779  Val set RMSE = 0.49985510
#
#
#  Epoch: 780  Val set RMSE = 0.49985525
#
#
#  Epoch: 781  Val set RMSE = 0.49985516
#
#
#  Epoch: 782  Val set RMSE = 0.49985476
#
#
#  Epoch: 783  Val set RMSE = 0.49985411
#
#
#  Epoch: 784  Val set RMSE = 0.49985330
#
#
#  Epoch: 785  Val set RMSE = 0.49985280
#
#
#  Epoch: 786  Val set RMSE = 0.49985282
#
#
#  Epoch: 787  Val set RMSE = 0.49985308
#
#
#  Epoch: 788  Val set RMSE = 0.49985317
#
#
#  Epoch: 789  Val set RMSE = 0.49985301
#
#
#  Epoch: 790  Val set RMSE = 0.49985325
#
#
#  Epoch: 791  Val set RMSE = 0.49985355
#
#
#  Epoch: 792  Val set RMSE = 0.49985347
#
#
#  Epoch: 793  Val set RMSE = 0.49985308
#
#
#  Epoch: 794  Val set RMSE = 0.49985243
#
#
#  Epoch: 795  Val set RMSE = 0.49985173
#
#
#  Epoch: 796  Val set RMSE = 0.49985135
#
#
#  Epoch: 797  Val set RMSE = 0.49985118
#
#
#  Epoch: 798  Val set RMSE = 0.49985101
#
#
#  Epoch: 799  Val set RMSE = 0.49985069
#
#
#  Epoch: 800  Val set RMSE = 0.49985064
#
#
#  Epoch: 801  Val set RMSE = 0.49985109
#
#
#  Epoch: 802  Val set RMSE = 0.49985143
#
#
#  Epoch: 803  Val set RMSE = 0.49985142
#
#
#  Epoch: 804  Val set RMSE = 0.49985110
#
#
#  Epoch: 805  Val set RMSE = 0.49985054
#
#
#  Epoch: 806  Val set RMSE = 0.49985012
#
#
#  Epoch: 807  Val set RMSE = 0.49984996
#
#
#  Epoch: 808  Val set RMSE = 0.49984977
#
#
#  Epoch: 809  Val set RMSE = 0.49984934
#
#
#  Epoch: 810  Val set RMSE = 0.49984873
#
#
#  Epoch: 811  Val set RMSE = 0.49984873
#
#
#  Epoch: 812  Val set RMSE = 0.49984902
#
#
#  Epoch: 813  Val set RMSE = 0.49984915
#
#
#  Epoch: 814  Val set RMSE = 0.49984903
#
#
#  Epoch: 815  Val set RMSE = 0.49984865
#
#
#  Epoch: 816  Val set RMSE = 0.49984825
#
#
#  Epoch: 817  Val set RMSE = 0.49984816
#
#
#  Epoch: 818  Val set RMSE = 0.49984815
#
#
#  Epoch: 819  Val set RMSE = 0.49984791
#
#
#  Epoch: 820  Val set RMSE = 0.49984731
#
#
#  Epoch: 821  Val set RMSE = 0.49984695
#
#
#  Epoch: 822  Val set RMSE = 0.49984709
#
#
#  Epoch: 823  Val set RMSE = 0.49984716
#
#
#  Epoch: 824  Val set RMSE = 0.49984702
#
#
#  Epoch: 825  Val set RMSE = 0.49984665
#
#
#  Epoch: 826  Val set RMSE = 0.49984613
#
#
#  Epoch: 827  Val set RMSE = 0.49984588
#
#
#  Epoch: 828  Val set RMSE = 0.49984589
#
#
#  Epoch: 829  Val set RMSE = 0.49984583
#
#
#  Epoch: 830  Val set RMSE = 0.49984538
#
#
#  Epoch: 831  Val set RMSE = 0.49984482
#
#
#  Epoch: 832  Val set RMSE = 0.49984482
#
#
#  Epoch: 833  Val set RMSE = 0.49984496
#
#
#  Epoch: 834  Val set RMSE = 0.49984490
#
#
#  Epoch: 835  Val set RMSE = 0.49984459
#
#
#  Epoch: 836  Val set RMSE = 0.49984407
#
#
#  Epoch: 837  Val set RMSE = 0.49984366
#
#
#  Epoch: 838  Val set RMSE = 0.49984361
#
#
#  Epoch: 839  Val set RMSE = 0.49984360
#
#
#  Epoch: 840  Val set RMSE = 0.49984329
#
#
#  Epoch: 841  Val set RMSE = 0.49984261
#
#
#  Epoch: 842  Val set RMSE = 0.49984236
#
#
#  Epoch: 843  Val set RMSE = 0.49984252
#
#
#  Epoch: 844  Val set RMSE = 0.49984253
#
#
#  Epoch: 845  Val set RMSE = 0.49984230
#
#
#  Epoch: 846  Val set RMSE = 0.49984183
#
#
#  Epoch: 847  Val set RMSE = 0.49984133
#
#
#  Epoch: 848  Val set RMSE = 0.49984118
#
#
#  Epoch: 849  Val set RMSE = 0.49984120
#
#
#  Epoch: 850  Val set RMSE = 0.49984104
#
#
#  Epoch: 851  Val set RMSE = 0.49984043
#
#
#  Epoch: 852  Val set RMSE = 0.49983994
#
#
#  Epoch: 853  Val set RMSE = 0.49984003
#
#
#  Epoch: 854  Val set RMSE = 0.49984012
#
#
#  Epoch: 855  Val set RMSE = 0.49983998
#
#
#  Epoch: 856  Val set RMSE = 0.49983961
#
#
#  Epoch: 857  Val set RMSE = 0.49983908
#
#
#  Epoch: 858  Val set RMSE = 0.49983880
#
#
#  Epoch: 859  Val set RMSE = 0.49983883
#
#
#  Epoch: 860  Val set RMSE = 0.49983879
#
#
#  Epoch: 861  Val set RMSE = 0.49983837
#
#
#  Epoch: 862  Val set RMSE = 0.49983771
#
#
#  Epoch: 863  Val set RMSE = 0.49983764
#
#
#  Epoch: 864  Val set RMSE = 0.49983780
#
#
#  Epoch: 865  Val set RMSE = 0.49983776
#
#
#  Epoch: 866  Val set RMSE = 0.49983750
#
#
#  Epoch: 867  Val set RMSE = 0.49983701
#
#
#  Epoch: 868  Val set RMSE = 0.49983661
#
#
#  Epoch: 869  Val set RMSE = 0.49983658
#
#
#  Epoch: 870  Val set RMSE = 0.49983663
#
#
#  Epoch: 871  Val set RMSE = 0.49983643
#
#
#  Epoch: 872  Val set RMSE = 0.49983579
#
#
#  Epoch: 873  Val set RMSE = 0.49983546
#
#
#  Epoch: 874  Val set RMSE = 0.49983562
#
#
#  Epoch: 875  Val set RMSE = 0.49983570
#
#
#  Epoch: 876  Val set RMSE = 0.49983555
#
#
#  Epoch: 877  Val set RMSE = 0.49983516
#
#
#  Epoch: 878  Val set RMSE = 0.49983468
#
#
#  Epoch: 879  Val set RMSE = 0.49983451
#
#
#  Epoch: 880  Val set RMSE = 0.49983460
#
#
#  Epoch: 881  Val set RMSE = 0.49983458
#
#
#  Epoch: 882  Val set RMSE = 0.49983416
#
#
#  Epoch: 883  Val set RMSE = 0.49983357
#
#
#  Epoch: 884  Val set RMSE = 0.49983358
#
#
#  Epoch: 885  Val set RMSE = 0.49983376
#
#
#  Epoch: 886  Val set RMSE = 0.49983373
#
#
#  Epoch: 887  Val set RMSE = 0.49983348
#
#
#  Epoch: 888  Val set RMSE = 0.49983302
#
#
#  Epoch: 889  Val set RMSE = 0.49983267
#
#
#  Epoch: 890  Val set RMSE = 0.49983269
#
#
#  Epoch: 891  Val set RMSE = 0.49983278
#
#
#  Epoch: 892  Val set RMSE = 0.49983263
#
#
#  Epoch: 893  Val set RMSE = 0.49983206
#
#
#  Epoch: 894  Val set RMSE = 0.49983174
#
#
#  Epoch: 895  Val set RMSE = 0.49983191
#
#
#  Epoch: 896  Val set RMSE = 0.49983203
#
#
#  Epoch: 897  Val set RMSE = 0.49983191
#
#
#  Epoch: 898  Val set RMSE = 0.49983157
#
#
#  Epoch: 899  Val set RMSE = 0.49983111
#
#
#  Epoch: 900  Val set RMSE = 0.49983094
#
#
#  Epoch: 901  Val set RMSE = 0.49983104
#
#
#  Epoch: 902  Val set RMSE = 0.49983109
#
#
#  Epoch: 903  Val set RMSE = 0.49983079
#
#
#  Epoch: 904  Val set RMSE = 0.49983021
#
#
#  Epoch: 905  Val set RMSE = 0.49983017
#
#
#  Epoch: 906  Val set RMSE = 0.49983037
#
#
#  Epoch: 907  Val set RMSE = 0.49983040
#
#
#  Epoch: 908  Val set RMSE = 0.49983020
#
#
#  Epoch: 909  Val set RMSE = 0.49982980
#
#
#  Epoch: 910  Val set RMSE = 0.49982942
#
#
#  Epoch: 911  Val set RMSE = 0.49982940
#
#
#  Epoch: 912  Val set RMSE = 0.49982953
#
#
#  Epoch: 913  Val set RMSE = 0.49982950
#
#
#  Epoch: 914  Val set RMSE = 0.49982905
#
#
#  Epoch: 915  Val set RMSE = 0.49982862
#
#
#  Epoch: 916  Val set RMSE = 0.49982876
#
#
#  Epoch: 917  Val set RMSE = 0.49982893
#
#
#  Epoch: 918  Val set RMSE = 0.49982888
#
#
#  Epoch: 919  Val set RMSE = 0.49982861
#
#
#  Epoch: 920  Val set RMSE = 0.49982818
#
#
#  Epoch: 921  Val set RMSE = 0.49982793
#
#
#  Epoch: 922  Val set RMSE = 0.49982801
#
#
#  Epoch: 923  Val set RMSE = 0.49982812
#
#
#  Epoch: 924  Val set RMSE = 0.49982797
#
#
#  Epoch: 925  Val set RMSE = 0.49982745
#
#
#  Epoch: 926  Val set RMSE = 0.49982725
#
#
#  Epoch: 927  Val set RMSE = 0.49982745
#
#
#  Epoch: 928  Val set RMSE = 0.49982755
#
#
#  Epoch: 929  Val set RMSE = 0.49982744
#
#
#  Epoch: 930  Val set RMSE = 0.49982711
#
#
#  Epoch: 931  Val set RMSE = 0.49982670
#
#
#  Epoch: 932  Val set RMSE = 0.49982659
#
#
#  Epoch: 933  Val set RMSE = 0.49982673
#
#
#  Epoch: 934  Val set RMSE = 0.49982678
#
#
#  Epoch: 935  Val set RMSE = 0.49982651
#
#
#  Epoch: 936  Val set RMSE = 0.49982601
#
#
#  Epoch: 937  Val set RMSE = 0.49982601
#
#
#  Epoch: 938  Val set RMSE = 0.49982623
#
#
#  Epoch: 939  Val set RMSE = 0.49982627
#
#
#  Epoch: 940  Val set RMSE = 0.49982609
#
#
#  Epoch: 941  Val set RMSE = 0.49982571
#
#
#  Epoch: 942  Val set RMSE = 0.49982537
#
#
#  Epoch: 943  Val set RMSE = 0.49982538
#
#
#  Epoch: 944  Val set RMSE = 0.49982553
#
#
#  Epoch: 945  Val set RMSE = 0.49982551
#
#
#  Epoch: 946  Val set RMSE = 0.49982511
#
#
#  Epoch: 947  Val set RMSE = 0.49982474
#
#
#  Epoch: 948  Val set RMSE = 0.49982489
#
#
#  Epoch: 949  Val set RMSE = 0.49982507
#
#
#  Epoch: 950  Val set RMSE = 0.49982504
#
#
#  Epoch: 951  Val set RMSE = 0.49982480
#
#
#  Epoch: 952  Val set RMSE = 0.49982439
#
#
#  Epoch: 953  Val set RMSE = 0.49982418
#
#
#  Epoch: 954  Val set RMSE = 0.49982428
#
#
#  Epoch: 955  Val set RMSE = 0.49982439
#
#
#  Epoch: 956  Val set RMSE = 0.49982427
#
#
#  Epoch: 957  Val set RMSE = 0.49982380
#
#
#  Epoch: 958  Val set RMSE = 0.49982362
#
#
#  Epoch: 959  Val set RMSE = 0.49982384
#
#
#  Epoch: 960  Val set RMSE = 0.49982396
#
#
#  Epoch: 961  Val set RMSE = 0.49982386
#
#
#  Epoch: 962  Val set RMSE = 0.49982355
#
#
#  Epoch: 963  Val set RMSE = 0.49982317
#
#
#  Epoch: 964  Val set RMSE = 0.49982309
#
#
#  Epoch: 965  Val set RMSE = 0.49982323
#
#
#  Epoch: 966  Val set RMSE = 0.49982330
#
#
#  Epoch: 967  Val set RMSE = 0.49982306
#
#
#  Epoch: 968  Val set RMSE = 0.49982259
#
#
#  Epoch: 969  Val set RMSE = 0.49982262
#
#
#  Epoch: 970  Val set RMSE = 0.49982285
#
#
#  Epoch: 971  Val set RMSE = 0.49982289
#
#
#  Epoch: 972  Val set RMSE = 0.49982273
#
#
#  Epoch: 973  Val set RMSE = 0.49982236
#
#
#  Epoch: 974  Val set RMSE = 0.49982207
#
#
#  Epoch: 975  Val set RMSE = 0.49982210
#
#
#  Epoch: 976  Val set RMSE = 0.49982224
#
#
#  Epoch: 977  Val set RMSE = 0.49982223
#
#
#  Epoch: 978  Val set RMSE = 0.49982186
#
#
#  Epoch: 979  Val set RMSE = 0.49982153
#
#
#  Epoch: 980  Val set RMSE = 0.49982170
#
#
#  Epoch: 981  Val set RMSE = 0.49982188
#
#
#  Epoch: 982  Val set RMSE = 0.49982185
#
#
#  Epoch: 983  Val set RMSE = 0.49982161
#
#
#  Epoch: 984  Val set RMSE = 0.49982123
#
#
#  Epoch: 985  Val set RMSE = 0.49982106
#
#
#  Epoch: 986  Val set RMSE = 0.49982118
#
#
#  Epoch: 987  Val set RMSE = 0.49982128
#
#
#  Epoch: 988  Val set RMSE = 0.49982117
#
#
#  Epoch: 989  Val set RMSE = 0.49982071
#
#
#  Epoch: 990  Val set RMSE = 0.49982060
#
#
#  Epoch: 991  Val set RMSE = 0.49982083
#
#
#  Epoch: 992  Val set RMSE = 0.49982094
#
#
#  Epoch: 993  Val set RMSE = 0.49982083
#
#
#  Epoch: 994  Val set RMSE = 0.49982052
#
#
#  Epoch: 995  Val set RMSE = 0.49982018
#
#
#  Epoch: 996  Val set RMSE = 0.49982016
#
#
#  Epoch: 997  Val set RMSE = 0.49982030
#
#
#  Epoch: 998  Val set RMSE = 0.49982034
#
#
#  Epoch: 999  Val set RMSE = 0.49982007
#
# Average time taken for a single epoch is 5.368591 seconds.
#
#  Test set RMSE = 0.02385132
#
# 0.0013371417
